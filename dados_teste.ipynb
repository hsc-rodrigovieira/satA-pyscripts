# %%
import pandas as pd
import random

def gerar_dados_hospitalares():
    # Configuração básica
    anos = [2023,2024]
    # meses = ["Jan", "Fev", "Mar", "Abr", "Maio", "Jun", "Jul", "Ago", "Set", "Out", "Nov", "Dez"]
    meses = list(range(1,13))
    hospitais = [{"$oid":"6745d7873f4e39e161319575"}, {"$oid":"6745d7d93f4e39e161319576"}]
    faixas_etarias = ["neo_precoce", "neo_tardio", "pedi", "ad", "idoso"]
    faixas_etarias2 = ["neo", "pedi", "ad"]
    tipos_internacao = ["cli", "cir"]
    tipos_unidades = ["ui", "uti"]
    tipos_pacientes = ["cli", "cir_orto", "cir_nao_orto"]
    dados = []

    for hospital in hospitais:
        for ano in anos:
            for mes in meses:
                # Indicador 1: Taxa de partos
                partos_vaginais = random.randint(50, 150)
                partos_cesareos = random.randint(50, 100)

                # Indicador 2: Reinternações
                saidas_clinicas_anterior = random.randint(300, 600)
                saidas_cirurgicas_anterior = random.randint(200, 400)
                reinternacoes_clinicas = random.randint(10, 50)
                reinternacoes_cirurgicas = random.randint(5, 30)            

                # Indicador 3: Taxa PCR
                pacientes_dia = random.randint(4000, 6000)
                pcr_eventos = random.randint(0, 5)

                # Indicador 4: Taxa de Mortalidade
                # Indicador 5: Tempo médio de internação
                dados_estratificados = {}
                for tipo in tipos_internacao:
                    for faixa_etaria in faixas_etarias:                
                        saidas = random.randint(100, 300)
                        obitos = random.randint(1, 30)
                        pacientes_dia = random.randint(500, 1000)

                        dados_estratificados[f"{tipo}_{faixa_etaria}_saidas"] = saidas
                        dados_estratificados[f"{tipo}_{faixa_etaria}_obitos"] = obitos    
                        dados_estratificados[f"{tipo}_{faixa_etaria}_pacientes_dia"] = pacientes_dia

                # Indicador 6: Tempo médio de permanência na emergência
                total_pacientes_emergencia = random.randint(100, 300)
                total_tempo_permanencia_emergencia_hr = random.randint(300, 900)  # Em horas 

                # Indicador 7: Tempo médio de espera na emergência para 1º atendimento
                pacientes_emergencia_nivel2 = random.randint(20, 100)
                pacientes_emergencia_nivel3 = random.randint(50, 150)
                tempo_total_emergencia_nivel2_min = random.randint(200, 600)  # Em minutos
                tempo_total_emergencia_nivel3_min = random.randint(1500, 3000)  # Em minutos  

                # Indicador 8: Taxa de início de antibiótico intravenoso profilático
                total_cirurgias_limpas = random.randint(50, 150)
                cirurgias_com_antibiotico = random.randint(40, total_cirurgias_limpas)   

                # Indicador 9: Taxa de infecção de sítio cirúrgico em cirurgia limpa
                total_cirurgias_limpas_mes_anterior = random.randint(50, 150)
                total_infeccoes = random.randint(0, 5)

                # Indicador 10: Densidade de incidência de infecção de corrente sanguínea
                dados_infeccao = {}
                for faixa in faixas_etarias2:
                    for tipo in tipos_unidades:
                        cvc_dia = random.randint(200, 500)
                        infeccoes_cvc = random.randint(0, 10)                    
                        dados_infeccao[f"{tipo}_{faixa}_cvc_dia"] = cvc_dia
                        dados_infeccao[f"{tipo}_{faixa}_infec"] = infeccoes_cvc      

                # Indicador 11: ITU associada a CVD
                dados_itu = {}
                for faixa in faixas_etarias2:
                    for unidade in tipos_unidades:
                        cvd_dia = random.randint(50, 300)
                        itu_cvd = random.randint(0, 10)                    
                        dados_itu[f"{unidade}_{faixa}_cvd_dia"] = cvd_dia
                        dados_itu[f"{unidade}_{faixa}_itu"] = itu_cvd                    

                # Indicador 12: Profilaxia de TEV
                dados_tev = {}
                for tipo in tipos_pacientes:
                    total_pacientes = random.randint(50, 200)
                    pacientes_profilaxia = random.randint(40, total_pacientes)
                    dados_tev[f"{tipo}_total_pacientes"] = total_pacientes
                    dados_tev[f"{tipo}_profilaxia"] = pacientes_profilaxia

                # Indicador 13: Quedas com lesão
                # pacientes_dia = random.randint(4000, 6000)
                quedas_com_dano = random.randint(0, 10)

                # Indicador 14: Eventos sentinela
                # pacientes_dia = random.randint(4000, 6000)
                eventos_sentinela = random.randint(0, 5)

                # Consolidar os dados
                dados.append({
                    "organization_id": hospital,
                    "year": ano,
                    "month": mes,
                    "partos_vaginais": partos_vaginais,
                    "partos_cesareos": partos_cesareos,
                    "saidas_clinicas_anterior": saidas_clinicas_anterior,
                    "saidas_cirurgicas_anterior": saidas_cirurgicas_anterior,
                    "reinternacoes_clinicas": reinternacoes_clinicas,
                    "reinternacoes_cirurgicas": reinternacoes_cirurgicas,  
                    "pacientes_dia": pacientes_dia,
                    "pcr_eventos": pcr_eventos,
                    **dados_estratificados,
                    "total_pacientes_emergencia": total_pacientes_emergencia,
                    "total_tempo_permanencia_emergencia_hr": total_tempo_permanencia_emergencia_hr,
                    "pacientes_emergencia_nivel2": pacientes_emergencia_nivel2,
                    "pacientes_emergencia_nivel3": pacientes_emergencia_nivel3,
                    "tempo_total_emergencia_nivel2_min": tempo_total_emergencia_nivel2_min,
                    "tempo_total_emergencia_nivel3_min": tempo_total_emergencia_nivel3_min,
                    "total_cirurgias_limpas": total_cirurgias_limpas,
                    "cirurgias_com_antibiotico": cirurgias_com_antibiotico,
                    "total_cirurgias_limpas_anterior": total_cirurgias_limpas_mes_anterior,
                    "total_infeccoes": total_infeccoes,
                    **dados_infeccao,
                    **dados_itu,
                    **dados_tev,
                    "quedas_com_dano": quedas_com_dano,
                    "eventos_sentinela": eventos_sentinela
                })

    return pd.DataFrame(dados)

# Gerar os dados e salvar em CSV
dados_completos = gerar_dados_hospitalares()
caminho_arquivo = "dados_hospitalares_completos.csv"
dados_completos.to_csv(caminho_arquivo, index=False)

print(f"Dados gerados e salvos em: {caminho_arquivo}")
dados_completos.head()
# Out:
# Dados gerados e salvos em: dados_hospitalares_completos.csv
#                         organization_id  year  month  partos_vaginais  \
# 0  {'$oid': '6745d7873f4e39e161319575'}  2023      1               98
# 1  {'$oid': '6745d7873f4e39e161319575'}  2023      2              112
# 2  {'$oid': '6745d7873f4e39e161319575'}  2023      3               61
# 3  {'$oid': '6745d7873f4e39e161319575'}  2023      4              126
# 4  {'$oid': '6745d7873f4e39e161319575'}  2023      5              140
#
#    partos_cesareos  saidas_clinicas_anterior  saidas_cirurgicas_anterior  \
# 0               97                       406                         347
# 1               78                       373                         376
# 2               97                       498                         261
# 3              100                       563                         292
# 4               94                       436                         352
#
#    reinternacoes_clinicas  reinternacoes_cirurgicas  pacientes_dia  ...  \
# 0                      44                        25            816  ...
# 1                      18                        26            961  ...
# 2                      42                        17            756  ...
# 3                      50                        17            578  ...
# 4                      43                         5            772  ...
#
#    uti_ad_cvd_dia  uti_ad_itu  cli_total_pacientes  cli_profilaxia  \
# 0             181           2                  156             104
# 1              68           0                  160             146
# 2             276          10                   69              53
# 3              70           8                   70              53
# 4             273           1                   90              88
#
#    cir_orto_total_pacientes  cir_orto_profilaxia  \
# 0                       112                   41
# 1                       198                  119
# 2                        68                   52
# 3                        95                   46
# 4                       177                  175
#
#    cir_nao_orto_total_pacientes  cir_nao_orto_profilaxia  quedas_com_dano  \
# 0                           118                       71                7
# 1                            58                       51               10
# 2                           123                      121                6
# 3                            95                       64                2
# 4                            56                       46                1
#
#    eventos_sentinela
# 0                  4
# 1                  5
# 2                  2
# 3                  4
# 4                  1
#
# [5 rows x 83 columns]

# %%
import json
json.loads(dados_completos.to_json(orient='records'))
# Out:
# [{'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 1,
#   'partos_vaginais': 98,
#   'partos_cesareos': 97,
#   'saidas_clinicas_anterior': 406,
#   'saidas_cirurgicas_anterior': 347,
#   'reinternacoes_clinicas': 44,
#   'reinternacoes_cirurgicas': 25,
#   'pacientes_dia': 816,
#   'pcr_eventos': 4,
#   'cli_neo_precoce_saidas': 174,
#   'cli_neo_precoce_obitos': 21,
#   'cli_neo_precoce_pacientes_dia': 538,
#   'cli_neo_tardio_saidas': 266,
#   'cli_neo_tardio_obitos': 18,
#   'cli_neo_tardio_pacientes_dia': 586,
#   'cli_pedi_saidas': 272,
#   'cli_pedi_obitos': 9,
#   'cli_pedi_pacientes_dia': 806,
#   'cli_ad_saidas': 170,
#   'cli_ad_obitos': 20,
#   'cli_ad_pacientes_dia': 909,
#   'cli_idoso_saidas': 272,
#   'cli_idoso_obitos': 8,
#   'cli_idoso_pacientes_dia': 508,
#   'cir_neo_precoce_saidas': 182,
#   'cir_neo_precoce_obitos': 7,
#   'cir_neo_precoce_pacientes_dia': 685,
#   'cir_neo_tardio_saidas': 110,
#   'cir_neo_tardio_obitos': 4,
#   'cir_neo_tardio_pacientes_dia': 501,
#   'cir_pedi_saidas': 166,
#   'cir_pedi_obitos': 15,
#   'cir_pedi_pacientes_dia': 676,
#   'cir_ad_saidas': 176,
#   'cir_ad_obitos': 11,
#   'cir_ad_pacientes_dia': 698,
#   'cir_idoso_saidas': 128,
#   'cir_idoso_obitos': 20,
#   'cir_idoso_pacientes_dia': 816,
#   'total_pacientes_emergencia': 218,
#   'total_tempo_permanencia_emergencia_hr': 681,
#   'pacientes_emergencia_nivel2': 41,
#   'pacientes_emergencia_nivel3': 143,
#   'tempo_total_emergencia_nivel2_min': 492,
#   'tempo_total_emergencia_nivel3_min': 1870,
#   'total_cirurgias_limpas': 59,
#   'cirurgias_com_antibiotico': 41,
#   'total_cirurgias_limpas_anterior': 109,
#   'total_infeccoes': 2,
#   'ui_neo_cvc_dia': 358,
#   'ui_neo_infec': 3,
#   'uti_neo_cvc_dia': 235,
#   'uti_neo_infec': 2,
#   'ui_pedi_cvc_dia': 259,
#   'ui_pedi_infec': 4,
#   'uti_pedi_cvc_dia': 200,
#   'uti_pedi_infec': 9,
#   'ui_ad_cvc_dia': 270,
#   'ui_ad_infec': 3,
#   'uti_ad_cvc_dia': 467,
#   'uti_ad_infec': 7,
#   'ui_neo_cvd_dia': 82,
#   'ui_neo_itu': 3,
#   'uti_neo_cvd_dia': 288,
#   'uti_neo_itu': 7,
#   'ui_pedi_cvd_dia': 160,
#   'ui_pedi_itu': 3,
#   'uti_pedi_cvd_dia': 151,
#   'uti_pedi_itu': 5,
#   'ui_ad_cvd_dia': 101,
#   'ui_ad_itu': 2,
#   'uti_ad_cvd_dia': 181,
#   'uti_ad_itu': 2,
#   'cli_total_pacientes': 156,
#   'cli_profilaxia': 104,
#   'cir_orto_total_pacientes': 112,
#   'cir_orto_profilaxia': 41,
#   'cir_nao_orto_total_pacientes': 118,
#   'cir_nao_orto_profilaxia': 71,
#   'quedas_com_dano': 7,
#   'eventos_sentinela': 4},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 2,
#   'partos_vaginais': 112,
#   'partos_cesareos': 78,
#   'saidas_clinicas_anterior': 373,
#   'saidas_cirurgicas_anterior': 376,
#   'reinternacoes_clinicas': 18,
#   'reinternacoes_cirurgicas': 26,
#   'pacientes_dia': 961,
#   'pcr_eventos': 4,
#   'cli_neo_precoce_saidas': 172,
#   'cli_neo_precoce_obitos': 21,
#   'cli_neo_precoce_pacientes_dia': 903,
#   'cli_neo_tardio_saidas': 217,
#   'cli_neo_tardio_obitos': 19,
#   'cli_neo_tardio_pacientes_dia': 1000,
#   'cli_pedi_saidas': 156,
#   'cli_pedi_obitos': 13,
#   'cli_pedi_pacientes_dia': 654,
#   'cli_ad_saidas': 115,
#   'cli_ad_obitos': 1,
#   'cli_ad_pacientes_dia': 859,
#   'cli_idoso_saidas': 200,
#   'cli_idoso_obitos': 16,
#   'cli_idoso_pacientes_dia': 872,
#   'cir_neo_precoce_saidas': 152,
#   'cir_neo_precoce_obitos': 1,
#   'cir_neo_precoce_pacientes_dia': 770,
#   'cir_neo_tardio_saidas': 136,
#   'cir_neo_tardio_obitos': 18,
#   'cir_neo_tardio_pacientes_dia': 789,
#   'cir_pedi_saidas': 124,
#   'cir_pedi_obitos': 14,
#   'cir_pedi_pacientes_dia': 749,
#   'cir_ad_saidas': 184,
#   'cir_ad_obitos': 12,
#   'cir_ad_pacientes_dia': 639,
#   'cir_idoso_saidas': 140,
#   'cir_idoso_obitos': 8,
#   'cir_idoso_pacientes_dia': 961,
#   'total_pacientes_emergencia': 272,
#   'total_tempo_permanencia_emergencia_hr': 325,
#   'pacientes_emergencia_nivel2': 75,
#   'pacientes_emergencia_nivel3': 112,
#   'tempo_total_emergencia_nivel2_min': 232,
#   'tempo_total_emergencia_nivel3_min': 2020,
#   'total_cirurgias_limpas': 75,
#   'cirurgias_com_antibiotico': 75,
#   'total_cirurgias_limpas_anterior': 142,
#   'total_infeccoes': 4,
#   'ui_neo_cvc_dia': 237,
#   'ui_neo_infec': 6,
#   'uti_neo_cvc_dia': 467,
#   'uti_neo_infec': 8,
#   'ui_pedi_cvc_dia': 436,
#   'ui_pedi_infec': 5,
#   'uti_pedi_cvc_dia': 387,
#   'uti_pedi_infec': 5,
#   'ui_ad_cvc_dia': 464,
#   'ui_ad_infec': 0,
#   'uti_ad_cvc_dia': 350,
#   'uti_ad_infec': 5,
#   'ui_neo_cvd_dia': 115,
#   'ui_neo_itu': 4,
#   'uti_neo_cvd_dia': 78,
#   'uti_neo_itu': 0,
#   'ui_pedi_cvd_dia': 162,
#   'ui_pedi_itu': 4,
#   'uti_pedi_cvd_dia': 203,
#   'uti_pedi_itu': 9,
#   'ui_ad_cvd_dia': 294,
#   'ui_ad_itu': 0,
#   'uti_ad_cvd_dia': 68,
#   'uti_ad_itu': 0,
#   'cli_total_pacientes': 160,
#   'cli_profilaxia': 146,
#   'cir_orto_total_pacientes': 198,
#   'cir_orto_profilaxia': 119,
#   'cir_nao_orto_total_pacientes': 58,
#   'cir_nao_orto_profilaxia': 51,
#   'quedas_com_dano': 10,
#   'eventos_sentinela': 5},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 3,
#   'partos_vaginais': 61,
#   'partos_cesareos': 97,
#   'saidas_clinicas_anterior': 498,
#   'saidas_cirurgicas_anterior': 261,
#   'reinternacoes_clinicas': 42,
#   'reinternacoes_cirurgicas': 17,
#   'pacientes_dia': 756,
#   'pcr_eventos': 1,
#   'cli_neo_precoce_saidas': 162,
#   'cli_neo_precoce_obitos': 15,
#   'cli_neo_precoce_pacientes_dia': 961,
#   'cli_neo_tardio_saidas': 245,
#   'cli_neo_tardio_obitos': 19,
#   'cli_neo_tardio_pacientes_dia': 558,
#   'cli_pedi_saidas': 182,
#   'cli_pedi_obitos': 16,
#   'cli_pedi_pacientes_dia': 509,
#   'cli_ad_saidas': 222,
#   'cli_ad_obitos': 29,
#   'cli_ad_pacientes_dia': 678,
#   'cli_idoso_saidas': 224,
#   'cli_idoso_obitos': 25,
#   'cli_idoso_pacientes_dia': 783,
#   'cir_neo_precoce_saidas': 225,
#   'cir_neo_precoce_obitos': 6,
#   'cir_neo_precoce_pacientes_dia': 801,
#   'cir_neo_tardio_saidas': 136,
#   'cir_neo_tardio_obitos': 7,
#   'cir_neo_tardio_pacientes_dia': 608,
#   'cir_pedi_saidas': 136,
#   'cir_pedi_obitos': 25,
#   'cir_pedi_pacientes_dia': 934,
#   'cir_ad_saidas': 177,
#   'cir_ad_obitos': 13,
#   'cir_ad_pacientes_dia': 626,
#   'cir_idoso_saidas': 202,
#   'cir_idoso_obitos': 27,
#   'cir_idoso_pacientes_dia': 756,
#   'total_pacientes_emergencia': 120,
#   'total_tempo_permanencia_emergencia_hr': 680,
#   'pacientes_emergencia_nivel2': 76,
#   'pacientes_emergencia_nivel3': 119,
#   'tempo_total_emergencia_nivel2_min': 441,
#   'tempo_total_emergencia_nivel3_min': 2519,
#   'total_cirurgias_limpas': 139,
#   'cirurgias_com_antibiotico': 83,
#   'total_cirurgias_limpas_anterior': 87,
#   'total_infeccoes': 1,
#   'ui_neo_cvc_dia': 462,
#   'ui_neo_infec': 3,
#   'uti_neo_cvc_dia': 479,
#   'uti_neo_infec': 2,
#   'ui_pedi_cvc_dia': 312,
#   'ui_pedi_infec': 6,
#   'uti_pedi_cvc_dia': 448,
#   'uti_pedi_infec': 5,
#   'ui_ad_cvc_dia': 235,
#   'ui_ad_infec': 6,
#   'uti_ad_cvc_dia': 414,
#   'uti_ad_infec': 1,
#   'ui_neo_cvd_dia': 90,
#   'ui_neo_itu': 1,
#   'uti_neo_cvd_dia': 247,
#   'uti_neo_itu': 2,
#   'ui_pedi_cvd_dia': 277,
#   'ui_pedi_itu': 6,
#   'uti_pedi_cvd_dia': 256,
#   'uti_pedi_itu': 3,
#   'ui_ad_cvd_dia': 90,
#   'ui_ad_itu': 3,
#   'uti_ad_cvd_dia': 276,
#   'uti_ad_itu': 10,
#   'cli_total_pacientes': 69,
#   'cli_profilaxia': 53,
#   'cir_orto_total_pacientes': 68,
#   'cir_orto_profilaxia': 52,
#   'cir_nao_orto_total_pacientes': 123,
#   'cir_nao_orto_profilaxia': 121,
#   'quedas_com_dano': 6,
#   'eventos_sentinela': 2},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 4,
#   'partos_vaginais': 126,
#   'partos_cesareos': 100,
#   'saidas_clinicas_anterior': 563,
#   'saidas_cirurgicas_anterior': 292,
#   'reinternacoes_clinicas': 50,
#   'reinternacoes_cirurgicas': 17,
#   'pacientes_dia': 578,
#   'pcr_eventos': 3,
#   'cli_neo_precoce_saidas': 276,
#   'cli_neo_precoce_obitos': 17,
#   'cli_neo_precoce_pacientes_dia': 995,
#   'cli_neo_tardio_saidas': 245,
#   'cli_neo_tardio_obitos': 9,
#   'cli_neo_tardio_pacientes_dia': 759,
#   'cli_pedi_saidas': 186,
#   'cli_pedi_obitos': 29,
#   'cli_pedi_pacientes_dia': 848,
#   'cli_ad_saidas': 182,
#   'cli_ad_obitos': 9,
#   'cli_ad_pacientes_dia': 922,
#   'cli_idoso_saidas': 193,
#   'cli_idoso_obitos': 25,
#   'cli_idoso_pacientes_dia': 642,
#   'cir_neo_precoce_saidas': 220,
#   'cir_neo_precoce_obitos': 29,
#   'cir_neo_precoce_pacientes_dia': 711,
#   'cir_neo_tardio_saidas': 113,
#   'cir_neo_tardio_obitos': 19,
#   'cir_neo_tardio_pacientes_dia': 753,
#   'cir_pedi_saidas': 129,
#   'cir_pedi_obitos': 22,
#   'cir_pedi_pacientes_dia': 668,
#   'cir_ad_saidas': 134,
#   'cir_ad_obitos': 22,
#   'cir_ad_pacientes_dia': 640,
#   'cir_idoso_saidas': 205,
#   'cir_idoso_obitos': 26,
#   'cir_idoso_pacientes_dia': 578,
#   'total_pacientes_emergencia': 239,
#   'total_tempo_permanencia_emergencia_hr': 577,
#   'pacientes_emergencia_nivel2': 69,
#   'pacientes_emergencia_nivel3': 114,
#   'tempo_total_emergencia_nivel2_min': 211,
#   'tempo_total_emergencia_nivel3_min': 2557,
#   'total_cirurgias_limpas': 118,
#   'cirurgias_com_antibiotico': 78,
#   'total_cirurgias_limpas_anterior': 81,
#   'total_infeccoes': 1,
#   'ui_neo_cvc_dia': 415,
#   'ui_neo_infec': 7,
#   'uti_neo_cvc_dia': 310,
#   'uti_neo_infec': 8,
#   'ui_pedi_cvc_dia': 420,
#   'ui_pedi_infec': 2,
#   'uti_pedi_cvc_dia': 264,
#   'uti_pedi_infec': 1,
#   'ui_ad_cvc_dia': 258,
#   'ui_ad_infec': 6,
#   'uti_ad_cvc_dia': 407,
#   'uti_ad_infec': 0,
#   'ui_neo_cvd_dia': 218,
#   'ui_neo_itu': 5,
#   'uti_neo_cvd_dia': 228,
#   'uti_neo_itu': 5,
#   'ui_pedi_cvd_dia': 173,
#   'ui_pedi_itu': 0,
#   'uti_pedi_cvd_dia': 99,
#   'uti_pedi_itu': 2,
#   'ui_ad_cvd_dia': 53,
#   'ui_ad_itu': 8,
#   'uti_ad_cvd_dia': 70,
#   'uti_ad_itu': 8,
#   'cli_total_pacientes': 70,
#   'cli_profilaxia': 53,
#   'cir_orto_total_pacientes': 95,
#   'cir_orto_profilaxia': 46,
#   'cir_nao_orto_total_pacientes': 95,
#   'cir_nao_orto_profilaxia': 64,
#   'quedas_com_dano': 2,
#   'eventos_sentinela': 4},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 5,
#   'partos_vaginais': 140,
#   'partos_cesareos': 94,
#   'saidas_clinicas_anterior': 436,
#   'saidas_cirurgicas_anterior': 352,
#   'reinternacoes_clinicas': 43,
#   'reinternacoes_cirurgicas': 5,
#   'pacientes_dia': 772,
#   'pcr_eventos': 1,
#   'cli_neo_precoce_saidas': 120,
#   'cli_neo_precoce_obitos': 11,
#   'cli_neo_precoce_pacientes_dia': 629,
#   'cli_neo_tardio_saidas': 279,
#   'cli_neo_tardio_obitos': 19,
#   'cli_neo_tardio_pacientes_dia': 699,
#   'cli_pedi_saidas': 162,
#   'cli_pedi_obitos': 13,
#   'cli_pedi_pacientes_dia': 991,
#   'cli_ad_saidas': 259,
#   'cli_ad_obitos': 21,
#   'cli_ad_pacientes_dia': 750,
#   'cli_idoso_saidas': 212,
#   'cli_idoso_obitos': 25,
#   'cli_idoso_pacientes_dia': 707,
#   'cir_neo_precoce_saidas': 161,
#   'cir_neo_precoce_obitos': 17,
#   'cir_neo_precoce_pacientes_dia': 979,
#   'cir_neo_tardio_saidas': 239,
#   'cir_neo_tardio_obitos': 28,
#   'cir_neo_tardio_pacientes_dia': 760,
#   'cir_pedi_saidas': 109,
#   'cir_pedi_obitos': 28,
#   'cir_pedi_pacientes_dia': 849,
#   'cir_ad_saidas': 103,
#   'cir_ad_obitos': 24,
#   'cir_ad_pacientes_dia': 844,
#   'cir_idoso_saidas': 246,
#   'cir_idoso_obitos': 20,
#   'cir_idoso_pacientes_dia': 772,
#   'total_pacientes_emergencia': 150,
#   'total_tempo_permanencia_emergencia_hr': 587,
#   'pacientes_emergencia_nivel2': 57,
#   'pacientes_emergencia_nivel3': 72,
#   'tempo_total_emergencia_nivel2_min': 358,
#   'tempo_total_emergencia_nivel3_min': 2255,
#   'total_cirurgias_limpas': 79,
#   'cirurgias_com_antibiotico': 63,
#   'total_cirurgias_limpas_anterior': 56,
#   'total_infeccoes': 4,
#   'ui_neo_cvc_dia': 431,
#   'ui_neo_infec': 9,
#   'uti_neo_cvc_dia': 305,
#   'uti_neo_infec': 9,
#   'ui_pedi_cvc_dia': 222,
#   'ui_pedi_infec': 5,
#   'uti_pedi_cvc_dia': 296,
#   'uti_pedi_infec': 5,
#   'ui_ad_cvc_dia': 429,
#   'ui_ad_infec': 8,
#   'uti_ad_cvc_dia': 236,
#   'uti_ad_infec': 5,
#   'ui_neo_cvd_dia': 61,
#   'ui_neo_itu': 6,
#   'uti_neo_cvd_dia': 248,
#   'uti_neo_itu': 6,
#   'ui_pedi_cvd_dia': 294,
#   'ui_pedi_itu': 2,
#   'uti_pedi_cvd_dia': 179,
#   'uti_pedi_itu': 8,
#   'ui_ad_cvd_dia': 260,
#   'ui_ad_itu': 1,
#   'uti_ad_cvd_dia': 273,
#   'uti_ad_itu': 1,
#   'cli_total_pacientes': 90,
#   'cli_profilaxia': 88,
#   'cir_orto_total_pacientes': 177,
#   'cir_orto_profilaxia': 175,
#   'cir_nao_orto_total_pacientes': 56,
#   'cir_nao_orto_profilaxia': 46,
#   'quedas_com_dano': 1,
#   'eventos_sentinela': 1},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 6,
#   'partos_vaginais': 60,
#   'partos_cesareos': 80,
#   'saidas_clinicas_anterior': 518,
#   'saidas_cirurgicas_anterior': 255,
#   'reinternacoes_clinicas': 43,
#   'reinternacoes_cirurgicas': 19,
#   'pacientes_dia': 766,
#   'pcr_eventos': 4,
#   'cli_neo_precoce_saidas': 287,
#   'cli_neo_precoce_obitos': 30,
#   'cli_neo_precoce_pacientes_dia': 617,
#   'cli_neo_tardio_saidas': 137,
#   'cli_neo_tardio_obitos': 29,
#   'cli_neo_tardio_pacientes_dia': 589,
#   'cli_pedi_saidas': 108,
#   'cli_pedi_obitos': 5,
#   'cli_pedi_pacientes_dia': 752,
#   'cli_ad_saidas': 219,
#   'cli_ad_obitos': 15,
#   'cli_ad_pacientes_dia': 903,
#   'cli_idoso_saidas': 117,
#   'cli_idoso_obitos': 6,
#   'cli_idoso_pacientes_dia': 906,
#   'cir_neo_precoce_saidas': 167,
#   'cir_neo_precoce_obitos': 15,
#   'cir_neo_precoce_pacientes_dia': 701,
#   'cir_neo_tardio_saidas': 280,
#   'cir_neo_tardio_obitos': 26,
#   'cir_neo_tardio_pacientes_dia': 921,
#   'cir_pedi_saidas': 250,
#   'cir_pedi_obitos': 20,
#   'cir_pedi_pacientes_dia': 587,
#   'cir_ad_saidas': 180,
#   'cir_ad_obitos': 12,
#   'cir_ad_pacientes_dia': 754,
#   'cir_idoso_saidas': 242,
#   'cir_idoso_obitos': 10,
#   'cir_idoso_pacientes_dia': 766,
#   'total_pacientes_emergencia': 297,
#   'total_tempo_permanencia_emergencia_hr': 412,
#   'pacientes_emergencia_nivel2': 31,
#   'pacientes_emergencia_nivel3': 141,
#   'tempo_total_emergencia_nivel2_min': 525,
#   'tempo_total_emergencia_nivel3_min': 2037,
#   'total_cirurgias_limpas': 139,
#   'cirurgias_com_antibiotico': 87,
#   'total_cirurgias_limpas_anterior': 123,
#   'total_infeccoes': 5,
#   'ui_neo_cvc_dia': 254,
#   'ui_neo_infec': 0,
#   'uti_neo_cvc_dia': 500,
#   'uti_neo_infec': 5,
#   'ui_pedi_cvc_dia': 311,
#   'ui_pedi_infec': 6,
#   'uti_pedi_cvc_dia': 347,
#   'uti_pedi_infec': 9,
#   'ui_ad_cvc_dia': 294,
#   'ui_ad_infec': 4,
#   'uti_ad_cvc_dia': 315,
#   'uti_ad_infec': 2,
#   'ui_neo_cvd_dia': 222,
#   'ui_neo_itu': 3,
#   'uti_neo_cvd_dia': 69,
#   'uti_neo_itu': 5,
#   'ui_pedi_cvd_dia': 73,
#   'ui_pedi_itu': 7,
#   'uti_pedi_cvd_dia': 79,
#   'uti_pedi_itu': 10,
#   'ui_ad_cvd_dia': 249,
#   'ui_ad_itu': 0,
#   'uti_ad_cvd_dia': 140,
#   'uti_ad_itu': 3,
#   'cli_total_pacientes': 52,
#   'cli_profilaxia': 49,
#   'cir_orto_total_pacientes': 135,
#   'cir_orto_profilaxia': 121,
#   'cir_nao_orto_total_pacientes': 112,
#   'cir_nao_orto_profilaxia': 60,
#   'quedas_com_dano': 5,
#   'eventos_sentinela': 3},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 7,
#   'partos_vaginais': 96,
#   'partos_cesareos': 90,
#   'saidas_clinicas_anterior': 429,
#   'saidas_cirurgicas_anterior': 248,
#   'reinternacoes_clinicas': 11,
#   'reinternacoes_cirurgicas': 8,
#   'pacientes_dia': 819,
#   'pcr_eventos': 5,
#   'cli_neo_precoce_saidas': 281,
#   'cli_neo_precoce_obitos': 1,
#   'cli_neo_precoce_pacientes_dia': 804,
#   'cli_neo_tardio_saidas': 268,
#   'cli_neo_tardio_obitos': 13,
#   'cli_neo_tardio_pacientes_dia': 709,
#   'cli_pedi_saidas': 257,
#   'cli_pedi_obitos': 17,
#   'cli_pedi_pacientes_dia': 712,
#   'cli_ad_saidas': 161,
#   'cli_ad_obitos': 4,
#   'cli_ad_pacientes_dia': 528,
#   'cli_idoso_saidas': 247,
#   'cli_idoso_obitos': 8,
#   'cli_idoso_pacientes_dia': 768,
#   'cir_neo_precoce_saidas': 240,
#   'cir_neo_precoce_obitos': 6,
#   'cir_neo_precoce_pacientes_dia': 673,
#   'cir_neo_tardio_saidas': 111,
#   'cir_neo_tardio_obitos': 11,
#   'cir_neo_tardio_pacientes_dia': 542,
#   'cir_pedi_saidas': 150,
#   'cir_pedi_obitos': 21,
#   'cir_pedi_pacientes_dia': 753,
#   'cir_ad_saidas': 282,
#   'cir_ad_obitos': 26,
#   'cir_ad_pacientes_dia': 721,
#   'cir_idoso_saidas': 243,
#   'cir_idoso_obitos': 29,
#   'cir_idoso_pacientes_dia': 819,
#   'total_pacientes_emergencia': 120,
#   'total_tempo_permanencia_emergencia_hr': 791,
#   'pacientes_emergencia_nivel2': 93,
#   'pacientes_emergencia_nivel3': 99,
#   'tempo_total_emergencia_nivel2_min': 298,
#   'tempo_total_emergencia_nivel3_min': 1594,
#   'total_cirurgias_limpas': 135,
#   'cirurgias_com_antibiotico': 53,
#   'total_cirurgias_limpas_anterior': 99,
#   'total_infeccoes': 2,
#   'ui_neo_cvc_dia': 401,
#   'ui_neo_infec': 8,
#   'uti_neo_cvc_dia': 321,
#   'uti_neo_infec': 7,
#   'ui_pedi_cvc_dia': 227,
#   'ui_pedi_infec': 8,
#   'uti_pedi_cvc_dia': 439,
#   'uti_pedi_infec': 7,
#   'ui_ad_cvc_dia': 446,
#   'ui_ad_infec': 4,
#   'uti_ad_cvc_dia': 298,
#   'uti_ad_infec': 8,
#   'ui_neo_cvd_dia': 280,
#   'ui_neo_itu': 7,
#   'uti_neo_cvd_dia': 230,
#   'uti_neo_itu': 0,
#   'ui_pedi_cvd_dia': 137,
#   'ui_pedi_itu': 4,
#   'uti_pedi_cvd_dia': 127,
#   'uti_pedi_itu': 0,
#   'ui_ad_cvd_dia': 51,
#   'ui_ad_itu': 8,
#   'uti_ad_cvd_dia': 124,
#   'uti_ad_itu': 4,
#   'cli_total_pacientes': 83,
#   'cli_profilaxia': 42,
#   'cir_orto_total_pacientes': 67,
#   'cir_orto_profilaxia': 59,
#   'cir_nao_orto_total_pacientes': 186,
#   'cir_nao_orto_profilaxia': 137,
#   'quedas_com_dano': 6,
#   'eventos_sentinela': 5},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 8,
#   'partos_vaginais': 116,
#   'partos_cesareos': 75,
#   'saidas_clinicas_anterior': 476,
#   'saidas_cirurgicas_anterior': 271,
#   'reinternacoes_clinicas': 21,
#   'reinternacoes_cirurgicas': 25,
#   'pacientes_dia': 621,
#   'pcr_eventos': 1,
#   'cli_neo_precoce_saidas': 135,
#   'cli_neo_precoce_obitos': 14,
#   'cli_neo_precoce_pacientes_dia': 656,
#   'cli_neo_tardio_saidas': 158,
#   'cli_neo_tardio_obitos': 19,
#   'cli_neo_tardio_pacientes_dia': 634,
#   'cli_pedi_saidas': 103,
#   'cli_pedi_obitos': 9,
#   'cli_pedi_pacientes_dia': 831,
#   'cli_ad_saidas': 286,
#   'cli_ad_obitos': 23,
#   'cli_ad_pacientes_dia': 560,
#   'cli_idoso_saidas': 259,
#   'cli_idoso_obitos': 12,
#   'cli_idoso_pacientes_dia': 834,
#   'cir_neo_precoce_saidas': 168,
#   'cir_neo_precoce_obitos': 14,
#   'cir_neo_precoce_pacientes_dia': 694,
#   'cir_neo_tardio_saidas': 131,
#   'cir_neo_tardio_obitos': 12,
#   'cir_neo_tardio_pacientes_dia': 885,
#   'cir_pedi_saidas': 146,
#   'cir_pedi_obitos': 4,
#   'cir_pedi_pacientes_dia': 588,
#   'cir_ad_saidas': 193,
#   'cir_ad_obitos': 6,
#   'cir_ad_pacientes_dia': 561,
#   'cir_idoso_saidas': 216,
#   'cir_idoso_obitos': 3,
#   'cir_idoso_pacientes_dia': 621,
#   'total_pacientes_emergencia': 214,
#   'total_tempo_permanencia_emergencia_hr': 400,
#   'pacientes_emergencia_nivel2': 38,
#   'pacientes_emergencia_nivel3': 101,
#   'tempo_total_emergencia_nivel2_min': 538,
#   'tempo_total_emergencia_nivel3_min': 2931,
#   'total_cirurgias_limpas': 145,
#   'cirurgias_com_antibiotico': 61,
#   'total_cirurgias_limpas_anterior': 92,
#   'total_infeccoes': 0,
#   'ui_neo_cvc_dia': 238,
#   'ui_neo_infec': 3,
#   'uti_neo_cvc_dia': 259,
#   'uti_neo_infec': 4,
#   'ui_pedi_cvc_dia': 480,
#   'ui_pedi_infec': 3,
#   'uti_pedi_cvc_dia': 296,
#   'uti_pedi_infec': 1,
#   'ui_ad_cvc_dia': 339,
#   'ui_ad_infec': 10,
#   'uti_ad_cvc_dia': 433,
#   'uti_ad_infec': 9,
#   'ui_neo_cvd_dia': 300,
#   'ui_neo_itu': 7,
#   'uti_neo_cvd_dia': 138,
#   'uti_neo_itu': 5,
#   'ui_pedi_cvd_dia': 174,
#   'ui_pedi_itu': 9,
#   'uti_pedi_cvd_dia': 122,
#   'uti_pedi_itu': 4,
#   'ui_ad_cvd_dia': 99,
#   'ui_ad_itu': 4,
#   'uti_ad_cvd_dia': 159,
#   'uti_ad_itu': 9,
#   'cli_total_pacientes': 117,
#   'cli_profilaxia': 88,
#   'cir_orto_total_pacientes': 53,
#   'cir_orto_profilaxia': 49,
#   'cir_nao_orto_total_pacientes': 107,
#   'cir_nao_orto_profilaxia': 47,
#   'quedas_com_dano': 1,
#   'eventos_sentinela': 0},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 9,
#   'partos_vaginais': 112,
#   'partos_cesareos': 53,
#   'saidas_clinicas_anterior': 530,
#   'saidas_cirurgicas_anterior': 373,
#   'reinternacoes_clinicas': 32,
#   'reinternacoes_cirurgicas': 9,
#   'pacientes_dia': 867,
#   'pcr_eventos': 5,
#   'cli_neo_precoce_saidas': 144,
#   'cli_neo_precoce_obitos': 28,
#   'cli_neo_precoce_pacientes_dia': 648,
#   'cli_neo_tardio_saidas': 117,
#   'cli_neo_tardio_obitos': 29,
#   'cli_neo_tardio_pacientes_dia': 636,
#   'cli_pedi_saidas': 134,
#   'cli_pedi_obitos': 26,
#   'cli_pedi_pacientes_dia': 704,
#   'cli_ad_saidas': 178,
#   'cli_ad_obitos': 3,
#   'cli_ad_pacientes_dia': 543,
#   'cli_idoso_saidas': 232,
#   'cli_idoso_obitos': 17,
#   'cli_idoso_pacientes_dia': 509,
#   'cir_neo_precoce_saidas': 103,
#   'cir_neo_precoce_obitos': 15,
#   'cir_neo_precoce_pacientes_dia': 622,
#   'cir_neo_tardio_saidas': 122,
#   'cir_neo_tardio_obitos': 28,
#   'cir_neo_tardio_pacientes_dia': 939,
#   'cir_pedi_saidas': 146,
#   'cir_pedi_obitos': 10,
#   'cir_pedi_pacientes_dia': 609,
#   'cir_ad_saidas': 266,
#   'cir_ad_obitos': 25,
#   'cir_ad_pacientes_dia': 821,
#   'cir_idoso_saidas': 180,
#   'cir_idoso_obitos': 16,
#   'cir_idoso_pacientes_dia': 867,
#   'total_pacientes_emergencia': 290,
#   'total_tempo_permanencia_emergencia_hr': 497,
#   'pacientes_emergencia_nivel2': 48,
#   'pacientes_emergencia_nivel3': 72,
#   'tempo_total_emergencia_nivel2_min': 543,
#   'tempo_total_emergencia_nivel3_min': 2681,
#   'total_cirurgias_limpas': 119,
#   'cirurgias_com_antibiotico': 115,
#   'total_cirurgias_limpas_anterior': 53,
#   'total_infeccoes': 4,
#   'ui_neo_cvc_dia': 340,
#   'ui_neo_infec': 0,
#   'uti_neo_cvc_dia': 285,
#   'uti_neo_infec': 4,
#   'ui_pedi_cvc_dia': 269,
#   'ui_pedi_infec': 5,
#   'uti_pedi_cvc_dia': 305,
#   'uti_pedi_infec': 5,
#   'ui_ad_cvc_dia': 218,
#   'ui_ad_infec': 4,
#   'uti_ad_cvc_dia': 303,
#   'uti_ad_infec': 8,
#   'ui_neo_cvd_dia': 227,
#   'ui_neo_itu': 5,
#   'uti_neo_cvd_dia': 171,
#   'uti_neo_itu': 3,
#   'ui_pedi_cvd_dia': 296,
#   'ui_pedi_itu': 3,
#   'uti_pedi_cvd_dia': 153,
#   'uti_pedi_itu': 0,
#   'ui_ad_cvd_dia': 134,
#   'ui_ad_itu': 1,
#   'uti_ad_cvd_dia': 88,
#   'uti_ad_itu': 6,
#   'cli_total_pacientes': 191,
#   'cli_profilaxia': 148,
#   'cir_orto_total_pacientes': 119,
#   'cir_orto_profilaxia': 97,
#   'cir_nao_orto_total_pacientes': 188,
#   'cir_nao_orto_profilaxia': 81,
#   'quedas_com_dano': 1,
#   'eventos_sentinela': 0},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 10,
#   'partos_vaginais': 51,
#   'partos_cesareos': 72,
#   'saidas_clinicas_anterior': 488,
#   'saidas_cirurgicas_anterior': 248,
#   'reinternacoes_clinicas': 12,
#   'reinternacoes_cirurgicas': 20,
#   'pacientes_dia': 519,
#   'pcr_eventos': 1,
#   'cli_neo_precoce_saidas': 127,
#   'cli_neo_precoce_obitos': 29,
#   'cli_neo_precoce_pacientes_dia': 567,
#   'cli_neo_tardio_saidas': 194,
#   'cli_neo_tardio_obitos': 28,
#   'cli_neo_tardio_pacientes_dia': 650,
#   'cli_pedi_saidas': 256,
#   'cli_pedi_obitos': 24,
#   'cli_pedi_pacientes_dia': 803,
#   'cli_ad_saidas': 217,
#   'cli_ad_obitos': 1,
#   'cli_ad_pacientes_dia': 633,
#   'cli_idoso_saidas': 228,
#   'cli_idoso_obitos': 19,
#   'cli_idoso_pacientes_dia': 663,
#   'cir_neo_precoce_saidas': 251,
#   'cir_neo_precoce_obitos': 5,
#   'cir_neo_precoce_pacientes_dia': 983,
#   'cir_neo_tardio_saidas': 294,
#   'cir_neo_tardio_obitos': 17,
#   'cir_neo_tardio_pacientes_dia': 866,
#   'cir_pedi_saidas': 218,
#   'cir_pedi_obitos': 18,
#   'cir_pedi_pacientes_dia': 604,
#   'cir_ad_saidas': 195,
#   'cir_ad_obitos': 6,
#   'cir_ad_pacientes_dia': 591,
#   'cir_idoso_saidas': 186,
#   'cir_idoso_obitos': 22,
#   'cir_idoso_pacientes_dia': 519,
#   'total_pacientes_emergencia': 129,
#   'total_tempo_permanencia_emergencia_hr': 828,
#   'pacientes_emergencia_nivel2': 89,
#   'pacientes_emergencia_nivel3': 107,
#   'tempo_total_emergencia_nivel2_min': 334,
#   'tempo_total_emergencia_nivel3_min': 2708,
#   'total_cirurgias_limpas': 67,
#   'cirurgias_com_antibiotico': 65,
#   'total_cirurgias_limpas_anterior': 97,
#   'total_infeccoes': 4,
#   'ui_neo_cvc_dia': 332,
#   'ui_neo_infec': 0,
#   'uti_neo_cvc_dia': 351,
#   'uti_neo_infec': 3,
#   'ui_pedi_cvc_dia': 298,
#   'ui_pedi_infec': 2,
#   'uti_pedi_cvc_dia': 227,
#   'uti_pedi_infec': 6,
#   'ui_ad_cvc_dia': 285,
#   'ui_ad_infec': 7,
#   'uti_ad_cvc_dia': 287,
#   'uti_ad_infec': 6,
#   'ui_neo_cvd_dia': 101,
#   'ui_neo_itu': 4,
#   'uti_neo_cvd_dia': 229,
#   'uti_neo_itu': 0,
#   'ui_pedi_cvd_dia': 127,
#   'ui_pedi_itu': 0,
#   'uti_pedi_cvd_dia': 164,
#   'uti_pedi_itu': 3,
#   'ui_ad_cvd_dia': 172,
#   'ui_ad_itu': 9,
#   'uti_ad_cvd_dia': 193,
#   'uti_ad_itu': 10,
#   'cli_total_pacientes': 69,
#   'cli_profilaxia': 40,
#   'cir_orto_total_pacientes': 60,
#   'cir_orto_profilaxia': 60,
#   'cir_nao_orto_total_pacientes': 83,
#   'cir_nao_orto_profilaxia': 68,
#   'quedas_com_dano': 10,
#   'eventos_sentinela': 5},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 11,
#   'partos_vaginais': 98,
#   'partos_cesareos': 52,
#   'saidas_clinicas_anterior': 509,
#   'saidas_cirurgicas_anterior': 321,
#   'reinternacoes_clinicas': 15,
#   'reinternacoes_cirurgicas': 17,
#   'pacientes_dia': 785,
#   'pcr_eventos': 4,
#   'cli_neo_precoce_saidas': 222,
#   'cli_neo_precoce_obitos': 29,
#   'cli_neo_precoce_pacientes_dia': 880,
#   'cli_neo_tardio_saidas': 105,
#   'cli_neo_tardio_obitos': 18,
#   'cli_neo_tardio_pacientes_dia': 553,
#   'cli_pedi_saidas': 134,
#   'cli_pedi_obitos': 30,
#   'cli_pedi_pacientes_dia': 886,
#   'cli_ad_saidas': 225,
#   'cli_ad_obitos': 16,
#   'cli_ad_pacientes_dia': 684,
#   'cli_idoso_saidas': 238,
#   'cli_idoso_obitos': 3,
#   'cli_idoso_pacientes_dia': 599,
#   'cir_neo_precoce_saidas': 223,
#   'cir_neo_precoce_obitos': 17,
#   'cir_neo_precoce_pacientes_dia': 645,
#   'cir_neo_tardio_saidas': 156,
#   'cir_neo_tardio_obitos': 8,
#   'cir_neo_tardio_pacientes_dia': 916,
#   'cir_pedi_saidas': 149,
#   'cir_pedi_obitos': 3,
#   'cir_pedi_pacientes_dia': 905,
#   'cir_ad_saidas': 204,
#   'cir_ad_obitos': 26,
#   'cir_ad_pacientes_dia': 887,
#   'cir_idoso_saidas': 135,
#   'cir_idoso_obitos': 9,
#   'cir_idoso_pacientes_dia': 785,
#   'total_pacientes_emergencia': 100,
#   'total_tempo_permanencia_emergencia_hr': 824,
#   'pacientes_emergencia_nivel2': 65,
#   'pacientes_emergencia_nivel3': 54,
#   'tempo_total_emergencia_nivel2_min': 491,
#   'tempo_total_emergencia_nivel3_min': 2483,
#   'total_cirurgias_limpas': 132,
#   'cirurgias_com_antibiotico': 79,
#   'total_cirurgias_limpas_anterior': 63,
#   'total_infeccoes': 5,
#   'ui_neo_cvc_dia': 402,
#   'ui_neo_infec': 5,
#   'uti_neo_cvc_dia': 279,
#   'uti_neo_infec': 7,
#   'ui_pedi_cvc_dia': 308,
#   'ui_pedi_infec': 5,
#   'uti_pedi_cvc_dia': 293,
#   'uti_pedi_infec': 1,
#   'ui_ad_cvc_dia': 458,
#   'ui_ad_infec': 9,
#   'uti_ad_cvc_dia': 411,
#   'uti_ad_infec': 10,
#   'ui_neo_cvd_dia': 131,
#   'ui_neo_itu': 6,
#   'uti_neo_cvd_dia': 105,
#   'uti_neo_itu': 9,
#   'ui_pedi_cvd_dia': 297,
#   'ui_pedi_itu': 7,
#   'uti_pedi_cvd_dia': 175,
#   'uti_pedi_itu': 5,
#   'ui_ad_cvd_dia': 141,
#   'ui_ad_itu': 4,
#   'uti_ad_cvd_dia': 143,
#   'uti_ad_itu': 3,
#   'cli_total_pacientes': 111,
#   'cli_profilaxia': 105,
#   'cir_orto_total_pacientes': 97,
#   'cir_orto_profilaxia': 76,
#   'cir_nao_orto_total_pacientes': 172,
#   'cir_nao_orto_profilaxia': 57,
#   'quedas_com_dano': 7,
#   'eventos_sentinela': 5},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 12,
#   'partos_vaginais': 128,
#   'partos_cesareos': 87,
#   'saidas_clinicas_anterior': 528,
#   'saidas_cirurgicas_anterior': 369,
#   'reinternacoes_clinicas': 15,
#   'reinternacoes_cirurgicas': 14,
#   'pacientes_dia': 941,
#   'pcr_eventos': 3,
#   'cli_neo_precoce_saidas': 222,
#   'cli_neo_precoce_obitos': 22,
#   'cli_neo_precoce_pacientes_dia': 641,
#   'cli_neo_tardio_saidas': 251,
#   'cli_neo_tardio_obitos': 26,
#   'cli_neo_tardio_pacientes_dia': 799,
#   'cli_pedi_saidas': 149,
#   'cli_pedi_obitos': 23,
#   'cli_pedi_pacientes_dia': 995,
#   'cli_ad_saidas': 188,
#   'cli_ad_obitos': 22,
#   'cli_ad_pacientes_dia': 781,
#   'cli_idoso_saidas': 158,
#   'cli_idoso_obitos': 9,
#   'cli_idoso_pacientes_dia': 786,
#   'cir_neo_precoce_saidas': 300,
#   'cir_neo_precoce_obitos': 30,
#   'cir_neo_precoce_pacientes_dia': 964,
#   'cir_neo_tardio_saidas': 290,
#   'cir_neo_tardio_obitos': 6,
#   'cir_neo_tardio_pacientes_dia': 704,
#   'cir_pedi_saidas': 199,
#   'cir_pedi_obitos': 8,
#   'cir_pedi_pacientes_dia': 771,
#   'cir_ad_saidas': 207,
#   'cir_ad_obitos': 18,
#   'cir_ad_pacientes_dia': 692,
#   'cir_idoso_saidas': 117,
#   'cir_idoso_obitos': 30,
#   'cir_idoso_pacientes_dia': 941,
#   'total_pacientes_emergencia': 216,
#   'total_tempo_permanencia_emergencia_hr': 425,
#   'pacientes_emergencia_nivel2': 27,
#   'pacientes_emergencia_nivel3': 130,
#   'tempo_total_emergencia_nivel2_min': 368,
#   'tempo_total_emergencia_nivel3_min': 2641,
#   'total_cirurgias_limpas': 136,
#   'cirurgias_com_antibiotico': 59,
#   'total_cirurgias_limpas_anterior': 88,
#   'total_infeccoes': 3,
#   'ui_neo_cvc_dia': 461,
#   'ui_neo_infec': 0,
#   'uti_neo_cvc_dia': 265,
#   'uti_neo_infec': 2,
#   'ui_pedi_cvc_dia': 380,
#   'ui_pedi_infec': 4,
#   'uti_pedi_cvc_dia': 485,
#   'uti_pedi_infec': 2,
#   'ui_ad_cvc_dia': 252,
#   'ui_ad_infec': 5,
#   'uti_ad_cvc_dia': 222,
#   'uti_ad_infec': 10,
#   'ui_neo_cvd_dia': 128,
#   'ui_neo_itu': 1,
#   'uti_neo_cvd_dia': 289,
#   'uti_neo_itu': 8,
#   'ui_pedi_cvd_dia': 79,
#   'ui_pedi_itu': 3,
#   'uti_pedi_cvd_dia': 208,
#   'uti_pedi_itu': 8,
#   'ui_ad_cvd_dia': 75,
#   'ui_ad_itu': 10,
#   'uti_ad_cvd_dia': 298,
#   'uti_ad_itu': 3,
#   'cli_total_pacientes': 186,
#   'cli_profilaxia': 151,
#   'cir_orto_total_pacientes': 168,
#   'cir_orto_profilaxia': 52,
#   'cir_nao_orto_total_pacientes': 163,
#   'cir_nao_orto_profilaxia': 75,
#   'quedas_com_dano': 7,
#   'eventos_sentinela': 0},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2024,
#   'month': 1,
#   'partos_vaginais': 62,
#   'partos_cesareos': 69,
#   'saidas_clinicas_anterior': 402,
#   'saidas_cirurgicas_anterior': 388,
#   'reinternacoes_clinicas': 25,
#   'reinternacoes_cirurgicas': 10,
#   'pacientes_dia': 759,
#   'pcr_eventos': 3,
#   'cli_neo_precoce_saidas': 241,
#   'cli_neo_precoce_obitos': 24,
#   'cli_neo_precoce_pacientes_dia': 635,
#   'cli_neo_tardio_saidas': 281,
#   'cli_neo_tardio_obitos': 12,
#   'cli_neo_tardio_pacientes_dia': 573,
#   'cli_pedi_saidas': 137,
#   'cli_pedi_obitos': 27,
#   'cli_pedi_pacientes_dia': 530,
#   'cli_ad_saidas': 270,
#   'cli_ad_obitos': 11,
#   'cli_ad_pacientes_dia': 819,
#   'cli_idoso_saidas': 217,
#   'cli_idoso_obitos': 2,
#   'cli_idoso_pacientes_dia': 942,
#   'cir_neo_precoce_saidas': 172,
#   'cir_neo_precoce_obitos': 18,
#   'cir_neo_precoce_pacientes_dia': 690,
#   'cir_neo_tardio_saidas': 232,
#   'cir_neo_tardio_obitos': 24,
#   'cir_neo_tardio_pacientes_dia': 843,
#   'cir_pedi_saidas': 182,
#   'cir_pedi_obitos': 1,
#   'cir_pedi_pacientes_dia': 905,
#   'cir_ad_saidas': 266,
#   'cir_ad_obitos': 7,
#   'cir_ad_pacientes_dia': 620,
#   'cir_idoso_saidas': 109,
#   'cir_idoso_obitos': 5,
#   'cir_idoso_pacientes_dia': 759,
#   'total_pacientes_emergencia': 279,
#   'total_tempo_permanencia_emergencia_hr': 442,
#   'pacientes_emergencia_nivel2': 71,
#   'pacientes_emergencia_nivel3': 71,
#   'tempo_total_emergencia_nivel2_min': 252,
#   'tempo_total_emergencia_nivel3_min': 2457,
#   'total_cirurgias_limpas': 113,
#   'cirurgias_com_antibiotico': 75,
#   'total_cirurgias_limpas_anterior': 90,
#   'total_infeccoes': 0,
#   'ui_neo_cvc_dia': 359,
#   'ui_neo_infec': 1,
#   'uti_neo_cvc_dia': 275,
#   'uti_neo_infec': 10,
#   'ui_pedi_cvc_dia': 387,
#   'ui_pedi_infec': 4,
#   'uti_pedi_cvc_dia': 230,
#   'uti_pedi_infec': 4,
#   'ui_ad_cvc_dia': 401,
#   'ui_ad_infec': 2,
#   'uti_ad_cvc_dia': 481,
#   'uti_ad_infec': 2,
#   'ui_neo_cvd_dia': 144,
#   'ui_neo_itu': 1,
#   'uti_neo_cvd_dia': 218,
#   'uti_neo_itu': 9,
#   'ui_pedi_cvd_dia': 119,
#   'ui_pedi_itu': 7,
#   'uti_pedi_cvd_dia': 288,
#   'uti_pedi_itu': 8,
#   'ui_ad_cvd_dia': 109,
#   'ui_ad_itu': 5,
#   'uti_ad_cvd_dia': 78,
#   'uti_ad_itu': 8,
#   'cli_total_pacientes': 57,
#   'cli_profilaxia': 49,
#   'cir_orto_total_pacientes': 182,
#   'cir_orto_profilaxia': 59,
#   'cir_nao_orto_total_pacientes': 75,
#   'cir_nao_orto_profilaxia': 73,
#   'quedas_com_dano': 9,
#   'eventos_sentinela': 4},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2024,
#   'month': 2,
#   'partos_vaginais': 148,
#   'partos_cesareos': 92,
#   'saidas_clinicas_anterior': 523,
#   'saidas_cirurgicas_anterior': 376,
#   'reinternacoes_clinicas': 18,
#   'reinternacoes_cirurgicas': 5,
#   'pacientes_dia': 581,
#   'pcr_eventos': 2,
#   'cli_neo_precoce_saidas': 205,
#   'cli_neo_precoce_obitos': 25,
#   'cli_neo_precoce_pacientes_dia': 639,
#   'cli_neo_tardio_saidas': 282,
#   'cli_neo_tardio_obitos': 2,
#   'cli_neo_tardio_pacientes_dia': 594,
#   'cli_pedi_saidas': 216,
#   'cli_pedi_obitos': 20,
#   'cli_pedi_pacientes_dia': 585,
#   'cli_ad_saidas': 298,
#   'cli_ad_obitos': 13,
#   'cli_ad_pacientes_dia': 641,
#   'cli_idoso_saidas': 136,
#   'cli_idoso_obitos': 13,
#   'cli_idoso_pacientes_dia': 932,
#   'cir_neo_precoce_saidas': 267,
#   'cir_neo_precoce_obitos': 4,
#   'cir_neo_precoce_pacientes_dia': 824,
#   'cir_neo_tardio_saidas': 230,
#   'cir_neo_tardio_obitos': 5,
#   'cir_neo_tardio_pacientes_dia': 704,
#   'cir_pedi_saidas': 130,
#   'cir_pedi_obitos': 19,
#   'cir_pedi_pacientes_dia': 606,
#   'cir_ad_saidas': 219,
#   'cir_ad_obitos': 4,
#   'cir_ad_pacientes_dia': 762,
#   'cir_idoso_saidas': 160,
#   'cir_idoso_obitos': 10,
#   'cir_idoso_pacientes_dia': 581,
#   'total_pacientes_emergencia': 184,
#   'total_tempo_permanencia_emergencia_hr': 453,
#   'pacientes_emergencia_nivel2': 55,
#   'pacientes_emergencia_nivel3': 127,
#   'tempo_total_emergencia_nivel2_min': 400,
#   'tempo_total_emergencia_nivel3_min': 2137,
#   'total_cirurgias_limpas': 100,
#   'cirurgias_com_antibiotico': 42,
#   'total_cirurgias_limpas_anterior': 79,
#   'total_infeccoes': 1,
#   'ui_neo_cvc_dia': 373,
#   'ui_neo_infec': 9,
#   'uti_neo_cvc_dia': 493,
#   'uti_neo_infec': 8,
#   'ui_pedi_cvc_dia': 305,
#   'ui_pedi_infec': 9,
#   'uti_pedi_cvc_dia': 488,
#   'uti_pedi_infec': 6,
#   'ui_ad_cvc_dia': 252,
#   'ui_ad_infec': 0,
#   'uti_ad_cvc_dia': 415,
#   'uti_ad_infec': 5,
#   'ui_neo_cvd_dia': 59,
#   'ui_neo_itu': 10,
#   'uti_neo_cvd_dia': 262,
#   'uti_neo_itu': 4,
#   'ui_pedi_cvd_dia': 77,
#   'ui_pedi_itu': 3,
#   'uti_pedi_cvd_dia': 141,
#   'uti_pedi_itu': 8,
#   'ui_ad_cvd_dia': 295,
#   'ui_ad_itu': 7,
#   'uti_ad_cvd_dia': 136,
#   'uti_ad_itu': 4,
#   'cli_total_pacientes': 65,
#   'cli_profilaxia': 64,
#   'cir_orto_total_pacientes': 74,
#   'cir_orto_profilaxia': 51,
#   'cir_nao_orto_total_pacientes': 192,
#   'cir_nao_orto_profilaxia': 109,
#   'quedas_com_dano': 7,
#   'eventos_sentinela': 4},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2024,
#   'month': 3,
#   'partos_vaginais': 55,
#   'partos_cesareos': 60,
#   'saidas_clinicas_anterior': 415,
#   'saidas_cirurgicas_anterior': 322,
#   'reinternacoes_clinicas': 47,
#   'reinternacoes_cirurgicas': 20,
#   'pacientes_dia': 921,
#   'pcr_eventos': 2,
#   'cli_neo_precoce_saidas': 240,
#   'cli_neo_precoce_obitos': 25,
#   'cli_neo_precoce_pacientes_dia': 915,
#   'cli_neo_tardio_saidas': 211,
#   'cli_neo_tardio_obitos': 7,
#   'cli_neo_tardio_pacientes_dia': 892,
#   'cli_pedi_saidas': 266,
#   'cli_pedi_obitos': 5,
#   'cli_pedi_pacientes_dia': 671,
#   'cli_ad_saidas': 237,
#   'cli_ad_obitos': 12,
#   'cli_ad_pacientes_dia': 928,
#   'cli_idoso_saidas': 188,
#   'cli_idoso_obitos': 7,
#   'cli_idoso_pacientes_dia': 818,
#   'cir_neo_precoce_saidas': 123,
#   'cir_neo_precoce_obitos': 5,
#   'cir_neo_precoce_pacientes_dia': 984,
#   'cir_neo_tardio_saidas': 201,
#   'cir_neo_tardio_obitos': 6,
#   'cir_neo_tardio_pacientes_dia': 743,
#   'cir_pedi_saidas': 136,
#   'cir_pedi_obitos': 18,
#   'cir_pedi_pacientes_dia': 720,
#   'cir_ad_saidas': 276,
#   'cir_ad_obitos': 19,
#   'cir_ad_pacientes_dia': 855,
#   'cir_idoso_saidas': 154,
#   'cir_idoso_obitos': 19,
#   'cir_idoso_pacientes_dia': 921,
#   'total_pacientes_emergencia': 137,
#   'total_tempo_permanencia_emergencia_hr': 802,
#   'pacientes_emergencia_nivel2': 98,
#   'pacientes_emergencia_nivel3': 93,
#   'tempo_total_emergencia_nivel2_min': 480,
#   'tempo_total_emergencia_nivel3_min': 1530,
#   'total_cirurgias_limpas': 62,
#   'cirurgias_com_antibiotico': 47,
#   'total_cirurgias_limpas_anterior': 51,
#   'total_infeccoes': 3,
#   'ui_neo_cvc_dia': 405,
#   'ui_neo_infec': 8,
#   'uti_neo_cvc_dia': 373,
#   'uti_neo_infec': 9,
#   'ui_pedi_cvc_dia': 205,
#   'ui_pedi_infec': 6,
#   'uti_pedi_cvc_dia': 234,
#   'uti_pedi_infec': 5,
#   'ui_ad_cvc_dia': 264,
#   'ui_ad_infec': 5,
#   'uti_ad_cvc_dia': 282,
#   'uti_ad_infec': 0,
#   'ui_neo_cvd_dia': 280,
#   'ui_neo_itu': 2,
#   'uti_neo_cvd_dia': 276,
#   'uti_neo_itu': 4,
#   'ui_pedi_cvd_dia': 294,
#   'ui_pedi_itu': 1,
#   'uti_pedi_cvd_dia': 110,
#   'uti_pedi_itu': 7,
#   'ui_ad_cvd_dia': 113,
#   'ui_ad_itu': 3,
#   'uti_ad_cvd_dia': 75,
#   'uti_ad_itu': 0,
#   'cli_total_pacientes': 132,
#   'cli_profilaxia': 126,
#   'cir_orto_total_pacientes': 158,
#   'cir_orto_profilaxia': 149,
#   'cir_nao_orto_total_pacientes': 129,
#   'cir_nao_orto_profilaxia': 73,
#   'quedas_com_dano': 4,
#   'eventos_sentinela': 0},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2024,
#   'month': 4,
#   'partos_vaginais': 135,
#   'partos_cesareos': 75,
#   'saidas_clinicas_anterior': 440,
#   'saidas_cirurgicas_anterior': 250,
#   'reinternacoes_clinicas': 23,
#   'reinternacoes_cirurgicas': 11,
#   'pacientes_dia': 919,
#   'pcr_eventos': 2,
#   'cli_neo_precoce_saidas': 159,
#   'cli_neo_precoce_obitos': 26,
#   'cli_neo_precoce_pacientes_dia': 682,
#   'cli_neo_tardio_saidas': 195,
#   'cli_neo_tardio_obitos': 10,
#   'cli_neo_tardio_pacientes_dia': 743,
#   'cli_pedi_saidas': 244,
#   'cli_pedi_obitos': 22,
#   'cli_pedi_pacientes_dia': 666,
#   'cli_ad_saidas': 138,
#   'cli_ad_obitos': 15,
#   'cli_ad_pacientes_dia': 844,
#   'cli_idoso_saidas': 284,
#   'cli_idoso_obitos': 7,
#   'cli_idoso_pacientes_dia': 533,
#   'cir_neo_precoce_saidas': 125,
#   'cir_neo_precoce_obitos': 10,
#   'cir_neo_precoce_pacientes_dia': 767,
#   'cir_neo_tardio_saidas': 252,
#   'cir_neo_tardio_obitos': 29,
#   'cir_neo_tardio_pacientes_dia': 747,
#   'cir_pedi_saidas': 181,
#   'cir_pedi_obitos': 25,
#   'cir_pedi_pacientes_dia': 889,
#   'cir_ad_saidas': 168,
#   'cir_ad_obitos': 19,
#   'cir_ad_pacientes_dia': 551,
#   'cir_idoso_saidas': 172,
#   'cir_idoso_obitos': 13,
#   'cir_idoso_pacientes_dia': 919,
#   'total_pacientes_emergencia': 288,
#   'total_tempo_permanencia_emergencia_hr': 844,
#   'pacientes_emergencia_nivel2': 62,
#   'pacientes_emergencia_nivel3': 131,
#   'tempo_total_emergencia_nivel2_min': 497,
#   'tempo_total_emergencia_nivel3_min': 1597,
#   'total_cirurgias_limpas': 59,
#   'cirurgias_com_antibiotico': 54,
#   'total_cirurgias_limpas_anterior': 102,
#   'total_infeccoes': 1,
#   'ui_neo_cvc_dia': 229,
#   'ui_neo_infec': 0,
#   'uti_neo_cvc_dia': 208,
#   'uti_neo_infec': 6,
#   'ui_pedi_cvc_dia': 454,
#   'ui_pedi_infec': 8,
#   'uti_pedi_cvc_dia': 257,
#   'uti_pedi_infec': 3,
#   'ui_ad_cvc_dia': 218,
#   'ui_ad_infec': 10,
#   'uti_ad_cvc_dia': 341,
#   'uti_ad_infec': 5,
#   'ui_neo_cvd_dia': 84,
#   'ui_neo_itu': 9,
#   'uti_neo_cvd_dia': 90,
#   'uti_neo_itu': 4,
#   'ui_pedi_cvd_dia': 82,
#   'ui_pedi_itu': 8,
#   'uti_pedi_cvd_dia': 68,
#   'uti_pedi_itu': 1,
#   'ui_ad_cvd_dia': 132,
#   'ui_ad_itu': 0,
#   'uti_ad_cvd_dia': 215,
#   'uti_ad_itu': 0,
#   'cli_total_pacientes': 149,
#   'cli_profilaxia': 137,
#   'cir_orto_total_pacientes': 195,
#   'cir_orto_profilaxia': 111,
#   'cir_nao_orto_total_pacientes': 107,
#   'cir_nao_orto_profilaxia': 55,
#   'quedas_com_dano': 7,
#   'eventos_sentinela': 4},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2024,
#   'month': 5,
#   'partos_vaginais': 78,
#   'partos_cesareos': 56,
#   'saidas_clinicas_anterior': 523,
#   'saidas_cirurgicas_anterior': 390,
#   'reinternacoes_clinicas': 25,
#   'reinternacoes_cirurgicas': 18,
#   'pacientes_dia': 917,
#   'pcr_eventos': 3,
#   'cli_neo_precoce_saidas': 108,
#   'cli_neo_precoce_obitos': 8,
#   'cli_neo_precoce_pacientes_dia': 862,
#   'cli_neo_tardio_saidas': 225,
#   'cli_neo_tardio_obitos': 2,
#   'cli_neo_tardio_pacientes_dia': 894,
#   'cli_pedi_saidas': 282,
#   'cli_pedi_obitos': 14,
#   'cli_pedi_pacientes_dia': 739,
#   'cli_ad_saidas': 219,
#   'cli_ad_obitos': 4,
#   'cli_ad_pacientes_dia': 589,
#   'cli_idoso_saidas': 210,
#   'cli_idoso_obitos': 7,
#   'cli_idoso_pacientes_dia': 538,
#   'cir_neo_precoce_saidas': 297,
#   'cir_neo_precoce_obitos': 10,
#   'cir_neo_precoce_pacientes_dia': 620,
#   'cir_neo_tardio_saidas': 149,
#   'cir_neo_tardio_obitos': 27,
#   'cir_neo_tardio_pacientes_dia': 737,
#   'cir_pedi_saidas': 172,
#   'cir_pedi_obitos': 2,
#   'cir_pedi_pacientes_dia': 807,
#   'cir_ad_saidas': 254,
#   'cir_ad_obitos': 6,
#   'cir_ad_pacientes_dia': 899,
#   'cir_idoso_saidas': 210,
#   'cir_idoso_obitos': 23,
#   'cir_idoso_pacientes_dia': 917,
#   'total_pacientes_emergencia': 275,
#   'total_tempo_permanencia_emergencia_hr': 838,
#   'pacientes_emergencia_nivel2': 23,
#   'pacientes_emergencia_nivel3': 81,
#   'tempo_total_emergencia_nivel2_min': 584,
#   'tempo_total_emergencia_nivel3_min': 1932,
#   'total_cirurgias_limpas': 141,
#   'cirurgias_com_antibiotico': 55,
#   'total_cirurgias_limpas_anterior': 93,
#   'total_infeccoes': 1,
#   'ui_neo_cvc_dia': 313,
#   'ui_neo_infec': 1,
#   'uti_neo_cvc_dia': 267,
#   'uti_neo_infec': 0,
#   'ui_pedi_cvc_dia': 476,
#   'ui_pedi_infec': 10,
#   'uti_pedi_cvc_dia': 224,
#   'uti_pedi_infec': 10,
#   'ui_ad_cvc_dia': 372,
#   'ui_ad_infec': 9,
#   'uti_ad_cvc_dia': 295,
#   'uti_ad_infec': 3,
#   'ui_neo_cvd_dia': 229,
#   'ui_neo_itu': 7,
#   'uti_neo_cvd_dia': 173,
#   'uti_neo_itu': 8,
#   'ui_pedi_cvd_dia': 83,
#   'ui_pedi_itu': 10,
#   'uti_pedi_cvd_dia': 210,
#   'uti_pedi_itu': 6,
#   'ui_ad_cvd_dia': 163,
#   'ui_ad_itu': 4,
#   'uti_ad_cvd_dia': 138,
#   'uti_ad_itu': 1,
#   'cli_total_pacientes': 115,
#   'cli_profilaxia': 49,
#   'cir_orto_total_pacientes': 184,
#   'cir_orto_profilaxia': 65,
#   'cir_nao_orto_total_pacientes': 195,
#   'cir_nao_orto_profilaxia': 179,
#   'quedas_com_dano': 6,
#   'eventos_sentinela': 4},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2024,
#   'month': 6,
#   'partos_vaginais': 137,
#   'partos_cesareos': 58,
#   'saidas_clinicas_anterior': 323,
#   'saidas_cirurgicas_anterior': 379,
#   'reinternacoes_clinicas': 17,
#   'reinternacoes_cirurgicas': 25,
#   'pacientes_dia': 973,
#   'pcr_eventos': 4,
#   'cli_neo_precoce_saidas': 174,
#   'cli_neo_precoce_obitos': 28,
#   'cli_neo_precoce_pacientes_dia': 749,
#   'cli_neo_tardio_saidas': 145,
#   'cli_neo_tardio_obitos': 9,
#   'cli_neo_tardio_pacientes_dia': 814,
#   'cli_pedi_saidas': 218,
#   'cli_pedi_obitos': 29,
#   'cli_pedi_pacientes_dia': 708,
#   'cli_ad_saidas': 183,
#   'cli_ad_obitos': 24,
#   'cli_ad_pacientes_dia': 569,
#   'cli_idoso_saidas': 271,
#   'cli_idoso_obitos': 23,
#   'cli_idoso_pacientes_dia': 723,
#   'cir_neo_precoce_saidas': 246,
#   'cir_neo_precoce_obitos': 26,
#   'cir_neo_precoce_pacientes_dia': 618,
#   'cir_neo_tardio_saidas': 209,
#   'cir_neo_tardio_obitos': 3,
#   'cir_neo_tardio_pacientes_dia': 976,
#   'cir_pedi_saidas': 234,
#   'cir_pedi_obitos': 15,
#   'cir_pedi_pacientes_dia': 513,
#   'cir_ad_saidas': 206,
#   'cir_ad_obitos': 16,
#   'cir_ad_pacientes_dia': 638,
#   'cir_idoso_saidas': 134,
#   'cir_idoso_obitos': 1,
#   'cir_idoso_pacientes_dia': 973,
#   'total_pacientes_emergencia': 253,
#   'total_tempo_permanencia_emergencia_hr': 779,
#   'pacientes_emergencia_nivel2': 34,
#   'pacientes_emergencia_nivel3': 148,
#   'tempo_total_emergencia_nivel2_min': 462,
#   'tempo_total_emergencia_nivel3_min': 2956,
#   'total_cirurgias_limpas': 123,
#   'cirurgias_com_antibiotico': 54,
#   'total_cirurgias_limpas_anterior': 120,
#   'total_infeccoes': 0,
#   'ui_neo_cvc_dia': 386,
#   'ui_neo_infec': 1,
#   'uti_neo_cvc_dia': 220,
#   'uti_neo_infec': 10,
#   'ui_pedi_cvc_dia': 492,
#   'ui_pedi_infec': 8,
#   'uti_pedi_cvc_dia': 361,
#   'uti_pedi_infec': 9,
#   'ui_ad_cvc_dia': 379,
#   'ui_ad_infec': 8,
#   'uti_ad_cvc_dia': 346,
#   'uti_ad_infec': 2,
#   'ui_neo_cvd_dia': 280,
#   'ui_neo_itu': 7,
#   'uti_neo_cvd_dia': 215,
#   'uti_neo_itu': 10,
#   'ui_pedi_cvd_dia': 138,
#   'ui_pedi_itu': 6,
#   'uti_pedi_cvd_dia': 192,
#   'uti_pedi_itu': 3,
#   'ui_ad_cvd_dia': 260,
#   'ui_ad_itu': 4,
#   'uti_ad_cvd_dia': 175,
#   'uti_ad_itu': 0,
#   'cli_total_pacientes': 129,
#   'cli_profilaxia': 100,
#   'cir_orto_total_pacientes': 134,
#   'cir_orto_profilaxia': 44,
#   'cir_nao_orto_total_pacientes': 89,
#   'cir_nao_orto_profilaxia': 63,
#   'quedas_com_dano': 0,
#   'eventos_sentinela': 0},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2024,
#   'month': 7,
#   'partos_vaginais': 142,
#   'partos_cesareos': 76,
#   'saidas_clinicas_anterior': 460,
#   'saidas_cirurgicas_anterior': 353,
#   'reinternacoes_clinicas': 11,
#   'reinternacoes_cirurgicas': 7,
#   'pacientes_dia': 589,
#   'pcr_eventos': 1,
#   'cli_neo_precoce_saidas': 224,
#   'cli_neo_precoce_obitos': 13,
#   'cli_neo_precoce_pacientes_dia': 720,
#   'cli_neo_tardio_saidas': 234,
#   'cli_neo_tardio_obitos': 7,
#   'cli_neo_tardio_pacientes_dia': 904,
#   'cli_pedi_saidas': 118,
#   'cli_pedi_obitos': 17,
#   'cli_pedi_pacientes_dia': 977,
#   'cli_ad_saidas': 233,
#   'cli_ad_obitos': 17,
#   'cli_ad_pacientes_dia': 915,
#   'cli_idoso_saidas': 145,
#   'cli_idoso_obitos': 5,
#   'cli_idoso_pacientes_dia': 922,
#   'cir_neo_precoce_saidas': 171,
#   'cir_neo_precoce_obitos': 18,
#   'cir_neo_precoce_pacientes_dia': 755,
#   'cir_neo_tardio_saidas': 188,
#   'cir_neo_tardio_obitos': 28,
#   'cir_neo_tardio_pacientes_dia': 680,
#   'cir_pedi_saidas': 258,
#   'cir_pedi_obitos': 16,
#   'cir_pedi_pacientes_dia': 612,
#   'cir_ad_saidas': 261,
#   'cir_ad_obitos': 12,
#   'cir_ad_pacientes_dia': 613,
#   'cir_idoso_saidas': 225,
#   'cir_idoso_obitos': 12,
#   'cir_idoso_pacientes_dia': 589,
#   'total_pacientes_emergencia': 268,
#   'total_tempo_permanencia_emergencia_hr': 557,
#   'pacientes_emergencia_nivel2': 43,
#   'pacientes_emergencia_nivel3': 92,
#   'tempo_total_emergencia_nivel2_min': 567,
#   'tempo_total_emergencia_nivel3_min': 1957,
#   'total_cirurgias_limpas': 127,
#   'cirurgias_com_antibiotico': 104,
#   'total_cirurgias_limpas_anterior': 134,
#   'total_infeccoes': 2,
#   'ui_neo_cvc_dia': 382,
#   'ui_neo_infec': 10,
#   'uti_neo_cvc_dia': 360,
#   'uti_neo_infec': 3,
#   'ui_pedi_cvc_dia': 285,
#   'ui_pedi_infec': 8,
#   'uti_pedi_cvc_dia': 395,
#   'uti_pedi_infec': 8,
#   'ui_ad_cvc_dia': 277,
#   'ui_ad_infec': 10,
#   'uti_ad_cvc_dia': 226,
#   'uti_ad_infec': 6,
#   'ui_neo_cvd_dia': 192,
#   'ui_neo_itu': 1,
#   'uti_neo_cvd_dia': 87,
#   'uti_neo_itu': 2,
#   'ui_pedi_cvd_dia': 138,
#   'ui_pedi_itu': 10,
#   'uti_pedi_cvd_dia': 284,
#   'uti_pedi_itu': 4,
#   'ui_ad_cvd_dia': 164,
#   'ui_ad_itu': 1,
#   'uti_ad_cvd_dia': 244,
#   'uti_ad_itu': 10,
#   'cli_total_pacientes': 55,
#   'cli_profilaxia': 40,
#   'cir_orto_total_pacientes': 142,
#   'cir_orto_profilaxia': 140,
#   'cir_nao_orto_total_pacientes': 133,
#   'cir_nao_orto_profilaxia': 63,
#   'quedas_com_dano': 7,
#   'eventos_sentinela': 2},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2024,
#   'month': 8,
#   'partos_vaginais': 93,
#   'partos_cesareos': 88,
#   'saidas_clinicas_anterior': 515,
#   'saidas_cirurgicas_anterior': 204,
#   'reinternacoes_clinicas': 16,
#   'reinternacoes_cirurgicas': 19,
#   'pacientes_dia': 701,
#   'pcr_eventos': 0,
#   'cli_neo_precoce_saidas': 126,
#   'cli_neo_precoce_obitos': 27,
#   'cli_neo_precoce_pacientes_dia': 742,
#   'cli_neo_tardio_saidas': 283,
#   'cli_neo_tardio_obitos': 13,
#   'cli_neo_tardio_pacientes_dia': 739,
#   'cli_pedi_saidas': 249,
#   'cli_pedi_obitos': 20,
#   'cli_pedi_pacientes_dia': 939,
#   'cli_ad_saidas': 188,
#   'cli_ad_obitos': 9,
#   'cli_ad_pacientes_dia': 627,
#   'cli_idoso_saidas': 176,
#   'cli_idoso_obitos': 20,
#   'cli_idoso_pacientes_dia': 733,
#   'cir_neo_precoce_saidas': 208,
#   'cir_neo_precoce_obitos': 16,
#   'cir_neo_precoce_pacientes_dia': 908,
#   'cir_neo_tardio_saidas': 121,
#   'cir_neo_tardio_obitos': 5,
#   'cir_neo_tardio_pacientes_dia': 701,
#   'cir_pedi_saidas': 257,
#   'cir_pedi_obitos': 23,
#   'cir_pedi_pacientes_dia': 590,
#   'cir_ad_saidas': 208,
#   'cir_ad_obitos': 3,
#   'cir_ad_pacientes_dia': 853,
#   'cir_idoso_saidas': 181,
#   'cir_idoso_obitos': 15,
#   'cir_idoso_pacientes_dia': 701,
#   'total_pacientes_emergencia': 292,
#   'total_tempo_permanencia_emergencia_hr': 607,
#   'pacientes_emergencia_nivel2': 90,
#   'pacientes_emergencia_nivel3': 52,
#   'tempo_total_emergencia_nivel2_min': 389,
#   'tempo_total_emergencia_nivel3_min': 2376,
#   'total_cirurgias_limpas': 107,
#   'cirurgias_com_antibiotico': 49,
#   'total_cirurgias_limpas_anterior': 112,
#   'total_infeccoes': 1,
#   'ui_neo_cvc_dia': 205,
#   'ui_neo_infec': 6,
#   'uti_neo_cvc_dia': 438,
#   'uti_neo_infec': 9,
#   'ui_pedi_cvc_dia': 261,
#   'ui_pedi_infec': 2,
#   'uti_pedi_cvc_dia': 401,
#   'uti_pedi_infec': 1,
#   'ui_ad_cvc_dia': 474,
#   'ui_ad_infec': 4,
#   'uti_ad_cvc_dia': 271,
#   'uti_ad_infec': 10,
#   'ui_neo_cvd_dia': 188,
#   'ui_neo_itu': 2,
#   'uti_neo_cvd_dia': 213,
#   'uti_neo_itu': 6,
#   'ui_pedi_cvd_dia': 284,
#   'ui_pedi_itu': 5,
#   'uti_pedi_cvd_dia': 237,
#   'uti_pedi_itu': 10,
#   'ui_ad_cvd_dia': 265,
#   'ui_ad_itu': 3,
#   'uti_ad_cvd_dia': 235,
#   'uti_ad_itu': 7,
#   'cli_total_pacientes': 152,
#   'cli_profilaxia': 133,
#   'cir_orto_total_pacientes': 165,
#   'cir_orto_profilaxia': 149,
# ...
#   'cir_neo_tardio_saidas': 255,
#   'cir_neo_tardio_obitos': 9,
#   'cir_neo_tardio_pacientes_dia': 568,
#   'cir_pedi_saidas': 164,
#   'cir_pedi_obitos': 6,
#   'cir_pedi_pacientes_dia': 716,
#   'cir_ad_saidas': 258,
#   'cir_ad_obitos': 15,
#   'cir_ad_pacientes_dia': 737,
#   'cir_idoso_saidas': 245,
#   'cir_idoso_obitos': 30,
#   'cir_idoso_pacientes_dia': 588,
#   'total_pacientes_emergencia': 142,
#   'total_tempo_permanencia_emergencia_hr': 436,
#   'pacientes_emergencia_nivel2': 28,
#   'pacientes_emergencia_nivel3': 114,
#   'tempo_total_emergencia_nivel2_min': 402,
#   'tempo_total_emergencia_nivel3_min': 1808,
#   'total_cirurgias_limpas': 61,
#   'cirurgias_com_antibiotico': 48,
#   'total_cirurgias_limpas_anterior': 90,
#   'total_infeccoes': 1,
#   'ui_neo_cvc_dia': 357,
#   'ui_neo_infec': 5,
#   'uti_neo_cvc_dia': 266,
#   'uti_neo_infec': 3,
#   'ui_pedi_cvc_dia': 357,
#   'ui_pedi_infec': 0,
#   'uti_pedi_cvc_dia': 420,
#   'uti_pedi_infec': 4,
#   'ui_ad_cvc_dia': 260,
#   'ui_ad_infec': 1,
#   'uti_ad_cvc_dia': 287,
#   'uti_ad_infec': 3,
#   'ui_neo_cvd_dia': 129,
#   'ui_neo_itu': 7,
#   'uti_neo_cvd_dia': 194,
#   'uti_neo_itu': 5,
#   'ui_pedi_cvd_dia': 212,
#   'ui_pedi_itu': 8,
#   'uti_pedi_cvd_dia': 293,
#   'uti_pedi_itu': 1,
#   'ui_ad_cvd_dia': 296,
#   'ui_ad_itu': 6,
#   'uti_ad_cvd_dia': 205,
#   'uti_ad_itu': 1,
#   'cli_total_pacientes': 170,
#   'cli_profilaxia': 48,
#   'cir_orto_total_pacientes': 72,
#   'cir_orto_profilaxia': 41,
#   'cir_nao_orto_total_pacientes': 132,
#   'cir_nao_orto_profilaxia': 116,
#   'quedas_com_dano': 3,
#   'eventos_sentinela': 1},
#  {'organization_id': {'$oid': '6745d7d93f4e39e161319576'},
#   'year': 2024,
#   'month': 7,
#   'partos_vaginais': 82,
#   'partos_cesareos': 61,
#   'saidas_clinicas_anterior': 461,
#   'saidas_cirurgicas_anterior': 278,
#   'reinternacoes_clinicas': 13,
#   'reinternacoes_cirurgicas': 21,
#   'pacientes_dia': 756,
#   'pcr_eventos': 4,
#   'cli_neo_precoce_saidas': 143,
#   'cli_neo_precoce_obitos': 24,
#   'cli_neo_precoce_pacientes_dia': 568,
#   'cli_neo_tardio_saidas': 168,
#   'cli_neo_tardio_obitos': 21,
#   'cli_neo_tardio_pacientes_dia': 956,
#   'cli_pedi_saidas': 277,
#   'cli_pedi_obitos': 8,
#   'cli_pedi_pacientes_dia': 546,
#   'cli_ad_saidas': 128,
#   'cli_ad_obitos': 2,
#   'cli_ad_pacientes_dia': 660,
#   'cli_idoso_saidas': 115,
#   'cli_idoso_obitos': 25,
#   'cli_idoso_pacientes_dia': 819,
#   'cir_neo_precoce_saidas': 107,
#   'cir_neo_precoce_obitos': 29,
#   'cir_neo_precoce_pacientes_dia': 888,
#   'cir_neo_tardio_saidas': 188,
#   'cir_neo_tardio_obitos': 11,
#   'cir_neo_tardio_pacientes_dia': 991,
#   'cir_pedi_saidas': 227,
#   'cir_pedi_obitos': 6,
#   'cir_pedi_pacientes_dia': 915,
#   'cir_ad_saidas': 254,
#   'cir_ad_obitos': 25,
#   'cir_ad_pacientes_dia': 573,
#   'cir_idoso_saidas': 170,
#   'cir_idoso_obitos': 25,
#   'cir_idoso_pacientes_dia': 756,
#   'total_pacientes_emergencia': 117,
#   'total_tempo_permanencia_emergencia_hr': 748,
#   'pacientes_emergencia_nivel2': 88,
#   'pacientes_emergencia_nivel3': 138,
#   'tempo_total_emergencia_nivel2_min': 431,
#   'tempo_total_emergencia_nivel3_min': 2988,
#   'total_cirurgias_limpas': 120,
#   'cirurgias_com_antibiotico': 86,
#   'total_cirurgias_limpas_anterior': 123,
#   'total_infeccoes': 5,
#   'ui_neo_cvc_dia': 427,
#   'ui_neo_infec': 10,
#   'uti_neo_cvc_dia': 221,
#   'uti_neo_infec': 5,
#   'ui_pedi_cvc_dia': 402,
#   'ui_pedi_infec': 8,
#   'uti_pedi_cvc_dia': 478,
#   'uti_pedi_infec': 5,
#   'ui_ad_cvc_dia': 253,
#   'ui_ad_infec': 7,
#   'uti_ad_cvc_dia': 475,
#   'uti_ad_infec': 5,
#   'ui_neo_cvd_dia': 57,
#   'ui_neo_itu': 5,
#   'uti_neo_cvd_dia': 58,
#   'uti_neo_itu': 6,
#   'ui_pedi_cvd_dia': 212,
#   'ui_pedi_itu': 0,
#   'uti_pedi_cvd_dia': 105,
#   'uti_pedi_itu': 3,
#   'ui_ad_cvd_dia': 132,
#   'ui_ad_itu': 9,
#   'uti_ad_cvd_dia': 86,
#   'uti_ad_itu': 4,
#   'cli_total_pacientes': 175,
#   'cli_profilaxia': 159,
#   'cir_orto_total_pacientes': 111,
#   'cir_orto_profilaxia': 56,
#   'cir_nao_orto_total_pacientes': 172,
#   'cir_nao_orto_profilaxia': 105,
#   'quedas_com_dano': 6,
#   'eventos_sentinela': 1},
#  {'organization_id': {'$oid': '6745d7d93f4e39e161319576'},
#   'year': 2024,
#   'month': 8,
#   'partos_vaginais': 123,
#   'partos_cesareos': 99,
#   'saidas_clinicas_anterior': 430,
#   'saidas_cirurgicas_anterior': 321,
#   'reinternacoes_clinicas': 22,
#   'reinternacoes_cirurgicas': 25,
#   'pacientes_dia': 739,
#   'pcr_eventos': 4,
#   'cli_neo_precoce_saidas': 265,
#   'cli_neo_precoce_obitos': 18,
#   'cli_neo_precoce_pacientes_dia': 737,
#   'cli_neo_tardio_saidas': 264,
#   'cli_neo_tardio_obitos': 28,
#   'cli_neo_tardio_pacientes_dia': 931,
#   'cli_pedi_saidas': 250,
#   'cli_pedi_obitos': 30,
#   'cli_pedi_pacientes_dia': 696,
#   'cli_ad_saidas': 257,
#   'cli_ad_obitos': 13,
#   'cli_ad_pacientes_dia': 640,
#   'cli_idoso_saidas': 210,
#   'cli_idoso_obitos': 8,
#   'cli_idoso_pacientes_dia': 985,
#   'cir_neo_precoce_saidas': 193,
#   'cir_neo_precoce_obitos': 28,
#   'cir_neo_precoce_pacientes_dia': 587,
#   'cir_neo_tardio_saidas': 244,
#   'cir_neo_tardio_obitos': 28,
#   'cir_neo_tardio_pacientes_dia': 938,
#   'cir_pedi_saidas': 148,
#   'cir_pedi_obitos': 30,
#   'cir_pedi_pacientes_dia': 711,
#   'cir_ad_saidas': 234,
#   'cir_ad_obitos': 30,
#   'cir_ad_pacientes_dia': 965,
#   'cir_idoso_saidas': 277,
#   'cir_idoso_obitos': 14,
#   'cir_idoso_pacientes_dia': 739,
#   'total_pacientes_emergencia': 157,
#   'total_tempo_permanencia_emergencia_hr': 842,
#   'pacientes_emergencia_nivel2': 100,
#   'pacientes_emergencia_nivel3': 58,
#   'tempo_total_emergencia_nivel2_min': 503,
#   'tempo_total_emergencia_nivel3_min': 2684,
#   'total_cirurgias_limpas': 87,
#   'cirurgias_com_antibiotico': 49,
#   'total_cirurgias_limpas_anterior': 79,
#   'total_infeccoes': 2,
#   'ui_neo_cvc_dia': 267,
#   'ui_neo_infec': 2,
#   'uti_neo_cvc_dia': 318,
#   'uti_neo_infec': 1,
#   'ui_pedi_cvc_dia': 252,
#   'ui_pedi_infec': 1,
#   'uti_pedi_cvc_dia': 368,
#   'uti_pedi_infec': 1,
#   'ui_ad_cvc_dia': 283,
#   'ui_ad_infec': 1,
#   'uti_ad_cvc_dia': 435,
#   'uti_ad_infec': 1,
#   'ui_neo_cvd_dia': 55,
#   'ui_neo_itu': 0,
#   'uti_neo_cvd_dia': 183,
#   'uti_neo_itu': 3,
#   'ui_pedi_cvd_dia': 173,
#   'ui_pedi_itu': 10,
#   'uti_pedi_cvd_dia': 106,
#   'uti_pedi_itu': 6,
#   'ui_ad_cvd_dia': 105,
#   'ui_ad_itu': 3,
#   'uti_ad_cvd_dia': 270,
#   'uti_ad_itu': 0,
#   'cli_total_pacientes': 132,
#   'cli_profilaxia': 110,
#   'cir_orto_total_pacientes': 122,
#   'cir_orto_profilaxia': 119,
#   'cir_nao_orto_total_pacientes': 172,
#   'cir_nao_orto_profilaxia': 95,
#   'quedas_com_dano': 5,
#   'eventos_sentinela': 5},
#  {'organization_id': {'$oid': '6745d7d93f4e39e161319576'},
#   'year': 2024,
#   'month': 9,
#   'partos_vaginais': 123,
#   'partos_cesareos': 84,
#   'saidas_clinicas_anterior': 528,
#   'saidas_cirurgicas_anterior': 298,
#   'reinternacoes_clinicas': 35,
#   'reinternacoes_cirurgicas': 12,
#   'pacientes_dia': 693,
#   'pcr_eventos': 4,
#   'cli_neo_precoce_saidas': 175,
#   'cli_neo_precoce_obitos': 19,
#   'cli_neo_precoce_pacientes_dia': 678,
#   'cli_neo_tardio_saidas': 245,
#   'cli_neo_tardio_obitos': 17,
#   'cli_neo_tardio_pacientes_dia': 523,
#   'cli_pedi_saidas': 256,
#   'cli_pedi_obitos': 1,
#   'cli_pedi_pacientes_dia': 743,
#   'cli_ad_saidas': 260,
#   'cli_ad_obitos': 27,
#   'cli_ad_pacientes_dia': 948,
#   'cli_idoso_saidas': 102,
#   'cli_idoso_obitos': 2,
#   'cli_idoso_pacientes_dia': 962,
#   'cir_neo_precoce_saidas': 232,
#   'cir_neo_precoce_obitos': 28,
#   'cir_neo_precoce_pacientes_dia': 835,
#   'cir_neo_tardio_saidas': 125,
#   'cir_neo_tardio_obitos': 23,
#   'cir_neo_tardio_pacientes_dia': 808,
#   'cir_pedi_saidas': 222,
#   'cir_pedi_obitos': 29,
#   'cir_pedi_pacientes_dia': 529,
#   'cir_ad_saidas': 263,
#   'cir_ad_obitos': 16,
#   'cir_ad_pacientes_dia': 682,
#   'cir_idoso_saidas': 186,
#   'cir_idoso_obitos': 24,
#   'cir_idoso_pacientes_dia': 693,
#   'total_pacientes_emergencia': 156,
#   'total_tempo_permanencia_emergencia_hr': 622,
#   'pacientes_emergencia_nivel2': 75,
#   'pacientes_emergencia_nivel3': 51,
#   'tempo_total_emergencia_nivel2_min': 475,
#   'tempo_total_emergencia_nivel3_min': 2817,
#   'total_cirurgias_limpas': 147,
#   'cirurgias_com_antibiotico': 106,
#   'total_cirurgias_limpas_anterior': 101,
#   'total_infeccoes': 5,
#   'ui_neo_cvc_dia': 471,
#   'ui_neo_infec': 2,
#   'uti_neo_cvc_dia': 266,
#   'uti_neo_infec': 2,
#   'ui_pedi_cvc_dia': 312,
#   'ui_pedi_infec': 9,
#   'uti_pedi_cvc_dia': 407,
#   'uti_pedi_infec': 0,
#   'ui_ad_cvc_dia': 472,
#   'ui_ad_infec': 10,
#   'uti_ad_cvc_dia': 360,
#   'uti_ad_infec': 3,
#   'ui_neo_cvd_dia': 66,
#   'ui_neo_itu': 8,
#   'uti_neo_cvd_dia': 128,
#   'uti_neo_itu': 6,
#   'ui_pedi_cvd_dia': 183,
#   'ui_pedi_itu': 5,
#   'uti_pedi_cvd_dia': 197,
#   'uti_pedi_itu': 9,
#   'ui_ad_cvd_dia': 210,
#   'ui_ad_itu': 6,
#   'uti_ad_cvd_dia': 266,
#   'uti_ad_itu': 0,
#   'cli_total_pacientes': 128,
#   'cli_profilaxia': 128,
#   'cir_orto_total_pacientes': 158,
#   'cir_orto_profilaxia': 82,
#   'cir_nao_orto_total_pacientes': 153,
#   'cir_nao_orto_profilaxia': 105,
#   'quedas_com_dano': 2,
#   'eventos_sentinela': 4},
#  {'organization_id': {'$oid': '6745d7d93f4e39e161319576'},
#   'year': 2024,
#   'month': 10,
#   'partos_vaginais': 61,
#   'partos_cesareos': 87,
#   'saidas_clinicas_anterior': 482,
#   'saidas_cirurgicas_anterior': 262,
#   'reinternacoes_clinicas': 12,
#   'reinternacoes_cirurgicas': 27,
#   'pacientes_dia': 522,
#   'pcr_eventos': 0,
#   'cli_neo_precoce_saidas': 290,
#   'cli_neo_precoce_obitos': 8,
#   'cli_neo_precoce_pacientes_dia': 952,
#   'cli_neo_tardio_saidas': 134,
#   'cli_neo_tardio_obitos': 11,
#   'cli_neo_tardio_pacientes_dia': 842,
#   'cli_pedi_saidas': 160,
#   'cli_pedi_obitos': 27,
#   'cli_pedi_pacientes_dia': 865,
#   'cli_ad_saidas': 174,
#   'cli_ad_obitos': 16,
#   'cli_ad_pacientes_dia': 901,
#   'cli_idoso_saidas': 247,
#   'cli_idoso_obitos': 28,
#   'cli_idoso_pacientes_dia': 551,
#   'cir_neo_precoce_saidas': 128,
#   'cir_neo_precoce_obitos': 23,
#   'cir_neo_precoce_pacientes_dia': 554,
#   'cir_neo_tardio_saidas': 229,
#   'cir_neo_tardio_obitos': 4,
#   'cir_neo_tardio_pacientes_dia': 588,
#   'cir_pedi_saidas': 151,
#   'cir_pedi_obitos': 10,
#   'cir_pedi_pacientes_dia': 561,
#   'cir_ad_saidas': 138,
#   'cir_ad_obitos': 21,
#   'cir_ad_pacientes_dia': 640,
#   'cir_idoso_saidas': 199,
#   'cir_idoso_obitos': 30,
#   'cir_idoso_pacientes_dia': 522,
#   'total_pacientes_emergencia': 260,
#   'total_tempo_permanencia_emergencia_hr': 514,
#   'pacientes_emergencia_nivel2': 25,
#   'pacientes_emergencia_nivel3': 77,
#   'tempo_total_emergencia_nivel2_min': 528,
#   'tempo_total_emergencia_nivel3_min': 1691,
#   'total_cirurgias_limpas': 145,
#   'cirurgias_com_antibiotico': 126,
#   'total_cirurgias_limpas_anterior': 146,
#   'total_infeccoes': 0,
#   'ui_neo_cvc_dia': 458,
#   'ui_neo_infec': 9,
#   'uti_neo_cvc_dia': 313,
#   'uti_neo_infec': 8,
#   'ui_pedi_cvc_dia': 242,
#   'ui_pedi_infec': 6,
#   'uti_pedi_cvc_dia': 282,
#   'uti_pedi_infec': 7,
#   'ui_ad_cvc_dia': 317,
#   'ui_ad_infec': 4,
#   'uti_ad_cvc_dia': 283,
#   'uti_ad_infec': 6,
#   'ui_neo_cvd_dia': 269,
#   'ui_neo_itu': 8,
#   'uti_neo_cvd_dia': 143,
#   'uti_neo_itu': 9,
#   'ui_pedi_cvd_dia': 194,
#   'ui_pedi_itu': 3,
#   'uti_pedi_cvd_dia': 56,
#   'uti_pedi_itu': 5,
#   'ui_ad_cvd_dia': 175,
#   'ui_ad_itu': 3,
#   'uti_ad_cvd_dia': 156,
#   'uti_ad_itu': 0,
#   'cli_total_pacientes': 101,
#   'cli_profilaxia': 56,
#   'cir_orto_total_pacientes': 126,
#   'cir_orto_profilaxia': 112,
#   'cir_nao_orto_total_pacientes': 187,
#   'cir_nao_orto_profilaxia': 126,
#   'quedas_com_dano': 5,
#   'eventos_sentinela': 0},
#  {'organization_id': {'$oid': '6745d7d93f4e39e161319576'},
#   'year': 2024,
#   'month': 11,
#   'partos_vaginais': 144,
#   'partos_cesareos': 74,
#   'saidas_clinicas_anterior': 490,
#   'saidas_cirurgicas_anterior': 297,
#   'reinternacoes_clinicas': 36,
#   'reinternacoes_cirurgicas': 22,
#   'pacientes_dia': 995,
#   'pcr_eventos': 3,
#   'cli_neo_precoce_saidas': 112,
#   'cli_neo_precoce_obitos': 29,
#   'cli_neo_precoce_pacientes_dia': 833,
#   'cli_neo_tardio_saidas': 104,
#   'cli_neo_tardio_obitos': 30,
#   'cli_neo_tardio_pacientes_dia': 919,
#   'cli_pedi_saidas': 128,
#   'cli_pedi_obitos': 12,
#   'cli_pedi_pacientes_dia': 533,
#   'cli_ad_saidas': 253,
#   'cli_ad_obitos': 7,
#   'cli_ad_pacientes_dia': 565,
#   'cli_idoso_saidas': 296,
#   'cli_idoso_obitos': 23,
#   'cli_idoso_pacientes_dia': 826,
#   'cir_neo_precoce_saidas': 285,
#   'cir_neo_precoce_obitos': 21,
#   'cir_neo_precoce_pacientes_dia': 897,
#   'cir_neo_tardio_saidas': 286,
#   'cir_neo_tardio_obitos': 6,
#   'cir_neo_tardio_pacientes_dia': 615,
#   'cir_pedi_saidas': 294,
#   'cir_pedi_obitos': 14,
#   'cir_pedi_pacientes_dia': 528,
#   'cir_ad_saidas': 210,
#   'cir_ad_obitos': 7,
#   'cir_ad_pacientes_dia': 590,
#   'cir_idoso_saidas': 287,
#   'cir_idoso_obitos': 26,
#   'cir_idoso_pacientes_dia': 995,
#   'total_pacientes_emergencia': 150,
#   'total_tempo_permanencia_emergencia_hr': 626,
#   'pacientes_emergencia_nivel2': 46,
#   'pacientes_emergencia_nivel3': 95,
#   'tempo_total_emergencia_nivel2_min': 393,
#   'tempo_total_emergencia_nivel3_min': 1740,
#   'total_cirurgias_limpas': 57,
#   'cirurgias_com_antibiotico': 42,
#   'total_cirurgias_limpas_anterior': 117,
#   'total_infeccoes': 2,
#   'ui_neo_cvc_dia': 244,
#   'ui_neo_infec': 8,
#   'uti_neo_cvc_dia': 263,
#   'uti_neo_infec': 6,
#   'ui_pedi_cvc_dia': 419,
#   'ui_pedi_infec': 9,
#   'uti_pedi_cvc_dia': 333,
#   'uti_pedi_infec': 5,
#   'ui_ad_cvc_dia': 314,
#   'ui_ad_infec': 4,
#   'uti_ad_cvc_dia': 212,
#   'uti_ad_infec': 1,
#   'ui_neo_cvd_dia': 188,
#   'ui_neo_itu': 5,
#   'uti_neo_cvd_dia': 248,
#   'uti_neo_itu': 10,
#   'ui_pedi_cvd_dia': 183,
#   'ui_pedi_itu': 6,
#   'uti_pedi_cvd_dia': 181,
#   'uti_pedi_itu': 10,
#   'ui_ad_cvd_dia': 116,
#   'ui_ad_itu': 0,
#   'uti_ad_cvd_dia': 226,
#   'uti_ad_itu': 9,
#   'cli_total_pacientes': 100,
#   'cli_profilaxia': 69,
#   'cir_orto_total_pacientes': 138,
#   'cir_orto_profilaxia': 97,
#   'cir_nao_orto_total_pacientes': 63,
#   'cir_nao_orto_profilaxia': 60,
#   'quedas_com_dano': 10,
#   'eventos_sentinela': 5},
#  {'organization_id': {'$oid': '6745d7d93f4e39e161319576'},
#   'year': 2024,
#   'month': 12,
#   'partos_vaginais': 77,
#   'partos_cesareos': 76,
#   'saidas_clinicas_anterior': 565,
#   'saidas_cirurgicas_anterior': 202,
#   'reinternacoes_clinicas': 47,
#   'reinternacoes_cirurgicas': 29,
#   'pacientes_dia': 876,
#   'pcr_eventos': 3,
#   'cli_neo_precoce_saidas': 246,
#   'cli_neo_precoce_obitos': 21,
#   'cli_neo_precoce_pacientes_dia': 793,
#   'cli_neo_tardio_saidas': 142,
#   'cli_neo_tardio_obitos': 10,
#   'cli_neo_tardio_pacientes_dia': 510,
#   'cli_pedi_saidas': 119,
#   'cli_pedi_obitos': 15,
#   'cli_pedi_pacientes_dia': 865,
#   'cli_ad_saidas': 258,
#   'cli_ad_obitos': 19,
#   'cli_ad_pacientes_dia': 535,
#   'cli_idoso_saidas': 106,
#   'cli_idoso_obitos': 22,
#   'cli_idoso_pacientes_dia': 516,
#   'cir_neo_precoce_saidas': 197,
#   'cir_neo_precoce_obitos': 16,
#   'cir_neo_precoce_pacientes_dia': 847,
#   'cir_neo_tardio_saidas': 299,
#   'cir_neo_tardio_obitos': 11,
#   'cir_neo_tardio_pacientes_dia': 617,
#   'cir_pedi_saidas': 251,
#   'cir_pedi_obitos': 11,
#   'cir_pedi_pacientes_dia': 870,
#   'cir_ad_saidas': 294,
#   'cir_ad_obitos': 4,
#   'cir_ad_pacientes_dia': 689,
#   'cir_idoso_saidas': 291,
#   'cir_idoso_obitos': 18,
#   'cir_idoso_pacientes_dia': 876,
#   'total_pacientes_emergencia': 195,
#   'total_tempo_permanencia_emergencia_hr': 850,
#   'pacientes_emergencia_nivel2': 96,
#   'pacientes_emergencia_nivel3': 84,
#   'tempo_total_emergencia_nivel2_min': 221,
#   'tempo_total_emergencia_nivel3_min': 2335,
#   'total_cirurgias_limpas': 149,
#   'cirurgias_com_antibiotico': 75,
#   'total_cirurgias_limpas_anterior': 125,
#   'total_infeccoes': 2,
#   'ui_neo_cvc_dia': 232,
#   'ui_neo_infec': 8,
#   'uti_neo_cvc_dia': 398,
#   'uti_neo_infec': 2,
#   'ui_pedi_cvc_dia': 438,
#   'ui_pedi_infec': 5,
#   'uti_pedi_cvc_dia': 424,
#   'uti_pedi_infec': 10,
#   'ui_ad_cvc_dia': 491,
#   'ui_ad_infec': 3,
#   'uti_ad_cvc_dia': 291,
#   'uti_ad_infec': 9,
#   'ui_neo_cvd_dia': 141,
#   'ui_neo_itu': 9,
#   'uti_neo_cvd_dia': 228,
#   'uti_neo_itu': 5,
#   'ui_pedi_cvd_dia': 270,
#   'ui_pedi_itu': 6,
#   'uti_pedi_cvd_dia': 120,
#   'uti_pedi_itu': 7,
#   'ui_ad_cvd_dia': 175,
#   'ui_ad_itu': 4,
#   'uti_ad_cvd_dia': 229,
#   'uti_ad_itu': 7,
#   'cli_total_pacientes': 198,
#   'cli_profilaxia': 164,
#   'cir_orto_total_pacientes': 142,
#   'cir_orto_profilaxia': 68,
#   'cir_nao_orto_total_pacientes': 137,
#   'cir_nao_orto_profilaxia': 124,
#   'quedas_com_dano': 8,
#   'eventos_sentinela': 2}]
