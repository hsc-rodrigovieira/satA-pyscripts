# %%
import pandas as pd
import random


def gerar_dados_hospitalares():
    # Configuração básica
    anos = [2023,2024]
    # meses = ["Jan", "Fev", "Mar", "Abr", "Maio", "Jun", "Jul", "Ago", "Set", "Out", "Nov", "Dez"]
    meses = list(range(1,13))
    hospitais = [{"$oid":"6745d7873f4e39e161319575"}, {"$oid":"6745d7d93f4e39e161319576"}]
    faixas_etarias = ["neo_precoce", "neo_tardio", "pedi", "ad", "idoso"]
    tipos_internacao = ["cli", "cir"]
    tipos_unidades = ["unid_int", "uti"]
    tipos_pacientes = ["cli", "cir_orto", "cir_nao_orto"]
    dados = []

    for hospital in hospitais:
        for ano in anos:
            for mes in meses:
                # Indicador 1: Taxa de partos
                partos_vaginais = random.randint(50, 150)
                partos_cesareos = random.randint(50, 100)

                # Indicador 2: Reinternações
                saidas_clinicas_anterior = random.randint(300, 600)
                saidas_cirurgicas_anterior = random.randint(200, 400)
                reinternacoes_clinicas = random.randint(10, 50)
                reinternacoes_cirurgicas = random.randint(5, 30)            

                # Indicador 3: Taxa PCR
                pacientes_dia = random.randint(4000, 6000)
                pcr_eventos = random.randint(0, 5)

                # Indicador 4: Taxa de Mortalidade
                # Indicador 5: Tempo médio de internação
                dados_estratificados = {}
                for tipo in tipos_internacao:
                    for faixa_etaria in faixas_etarias:                
                        saidas = random.randint(100, 300)
                        obitos = random.randint(1, 30)
                        pacientes_dia = random.randint(500, 1000)

                        dados_estratificados[f"{tipo}_{faixa_etaria}_saidas"] = saidas
                        dados_estratificados[f"{tipo}_{faixa_etaria}_obitos"] = obitos    
                        dados_estratificados[f"{tipo}_{faixa_etaria}_pacientes_dia"] = pacientes_dia

                # Indicador 6: Tempo médio de permanência na emergência
                total_pacientes_emergencia = random.randint(100, 300)
                total_tempo_permanencia_emergencia_hr = random.randint(300, 900)  # Em horas 

                # Indicador 7: Tempo médio de espera na emergência para 1º atendimento
                pacientes_emergencia_nivel2 = random.randint(20, 100)
                pacientes_emergencia_nivel3 = random.randint(50, 150)
                tempo_total_emergencia_nivel2_min = random.randint(200, 600)  # Em minutos
                tempo_total_emergencia_nivel3_min = random.randint(1500, 3000)  # Em minutos  

                # Indicador 8: Taxa de início de antibiótico intravenoso profilático
                total_cirurgias_limpas = random.randint(50, 150)
                cirurgias_com_antibiotico = random.randint(40, total_cirurgias_limpas)   

                # Indicador 9: Taxa de infecção de sítio cirúrgico em cirurgia limpa
                total_infeccoes = random.randint(0, 5)

                # Indicador 10: Densidade de incidência de infecção de corrente sanguínea
                dados_infeccao = {}
                for faixa in faixas_etarias:
                    for tipo in tipos_unidades:
                        cvc_dia = random.randint(200, 500)
                        infeccoes_cvc = random.randint(0, 10)                    
                        dados_infeccao[f"{tipo}_{faixa}_cvc_dia"] = cvc_dia
                        dados_infeccao[f"{tipo}_{faixa}_infec"] = infeccoes_cvc      

                # Indicador 11: ITU associada a CVD
                dados_itu = {}
                for faixa in faixas_etarias:
                    for unidade in tipos_unidades:
                        cvd_dia = random.randint(50, 300)
                        itu_cvd = random.randint(0, 10)                    
                        dados_itu[f"{unidade}_{faixa}_cvd_dia"] = cvd_dia
                        dados_itu[f"{unidade}_{faixa}_itu"] = itu_cvd                    

                # Indicador 12: Profilaxia de TEV
                dados_tev = {}
                for tipo in tipos_pacientes:
                    total_pacientes = random.randint(50, 200)
                    pacientes_profilaxia = random.randint(40, total_pacientes)
                    dados_tev[f"{tipo}_total_pacientes"] = total_pacientes
                    dados_tev[f"{tipo}_profilaxia"] = pacientes_profilaxia

                # Indicador 13: Quedas com lesão
                # pacientes_dia = random.randint(4000, 6000)
                quedas_com_dano = random.randint(0, 10)

                # Indicador 14: Eventos sentinela
                # pacientes_dia = random.randint(4000, 6000)
                eventos_sentinela = random.randint(0, 5)

                # Consolidar os dados
                dados.append({
                    "organization_id": hospital,
                    "year": ano,
                    "month": mes,
                    "partos_vaginais": partos_vaginais,
                    "partos_cesareos": partos_cesareos,
                    "saidas_clinicas_anterior": saidas_clinicas_anterior,
                    "saidas_cirurgicas_anterior": saidas_cirurgicas_anterior,
                    "reinternacoes_clinicas": reinternacoes_clinicas,
                    "reinternacoes_cirurgicas": reinternacoes_cirurgicas,  
                    "pacientes_dia": pacientes_dia,
                    "pcr_eventos": pcr_eventos,
                    **dados_estratificados,
                    "total_pacientes_emergencia": total_pacientes_emergencia,
                    "total_tempo_permanencia_emergencia_hr": total_tempo_permanencia_emergencia_hr,
                    "pacientes_emergencia_nivel2": pacientes_emergencia_nivel2,
                    "pacientes_emergencia_nivel3": pacientes_emergencia_nivel3,
                    "tempo_total_emergencia_nivel2_min": tempo_total_emergencia_nivel2_min,
                    "tempo_total_emergencia_nivel3_min": tempo_total_emergencia_nivel3_min,
                    "total_cirurgias_limpas": total_cirurgias_limpas,
                    "cirurgias_com_antibiotico": cirurgias_com_antibiotico,
                    "total_infeccoes": total_infeccoes,
                    **dados_infeccao,
                    **dados_itu,
                    **dados_tev,
                    "quedas_com_dano": quedas_com_dano,
                    "eventos_sentinela": eventos_sentinela
                })

    return pd.DataFrame(dados)

# Gerar os dados e salvar em CSV
dados_completos = gerar_dados_hospitalares()
caminho_arquivo = "dados_hospitalares_completos.csv"
dados_completos.to_csv(caminho_arquivo, index=False)

print(f"Dados gerados e salvos em: {caminho_arquivo}")
dados_completos.head()
# Out:
# Dados gerados e salvos em: dados_hospitalares_completos.csv
#                         organization_id  year  month  partos_vaginais  \
# 0  {'$oid': '6745d7873f4e39e161319575'}  2023      1              103
# 1  {'$oid': '6745d7873f4e39e161319575'}  2023      2               90
# 2  {'$oid': '6745d7873f4e39e161319575'}  2023      3               53
# 3  {'$oid': '6745d7873f4e39e161319575'}  2023      4               95
# 4  {'$oid': '6745d7873f4e39e161319575'}  2023      5              125
#
#    partos_cesareos  saidas_clinicas_anterior  saidas_cirurgicas_anterior  \
# 0               90                       453                         266
# 1               96                       473                         216
# 2               91                       500                         346
# 3               94                       459                         318
# 4               76                       406                         393
#
#    reinternacoes_clinicas  reinternacoes_cirurgicas  pacientes_dia  ...  \
# 0                      29                        18            518  ...
# 1                      36                         7            800  ...
# 2                      13                        22            611  ...
# 3                      28                         7            594  ...
# 4                      10                        18            918  ...
#
#    uti_idoso_cvd_dia  uti_idoso_itu  cli_total_pacientes  cli_profilaxia  \
# 0                272              0                  183             101
# 1                210              8                   51              43
# 2                106              6                  189              40
# 3                140              0                  161             155
# 4                146              0                  120              69
#
#    cir_orto_total_pacientes  cir_orto_profilaxia  \
# 0                       147                  126
# 1                        52                   43
# 2                        56                   44
# 3                        61                   47
# 4                        79                   77
#
#    cir_nao_orto_total_pacientes  cir_nao_orto_profilaxia  quedas_com_dano  \
# 0                            67                       44                1
# 1                           177                      121                6
# 2                            66                       55                6
# 3                           151                       82                5
# 4                            88                       86                8
#
#    eventos_sentinela
# 0                  3
# 1                  5
# 2                  2
# 3                  3
# 4                  2
#
# [5 rows x 98 columns]

# %%
import json
json.loads(dados_completos.to_json(orient='records'))
# Out:
# [{'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 1,
#   'partos_vaginais': 103,
#   'partos_cesareos': 90,
#   'saidas_clinicas_anterior': 453,
#   'saidas_cirurgicas_anterior': 266,
#   'reinternacoes_clinicas': 29,
#   'reinternacoes_cirurgicas': 18,
#   'pacientes_dia': 518,
#   'pcr_eventos': 0,
#   'cli_neo_precoce_saidas': 120,
#   'cli_neo_precoce_obitos': 25,
#   'cli_neo_precoce_pacientes_dia': 657,
#   'cli_neo_tardio_saidas': 171,
#   'cli_neo_tardio_obitos': 22,
#   'cli_neo_tardio_pacientes_dia': 870,
#   'cli_pedi_saidas': 158,
#   'cli_pedi_obitos': 9,
#   'cli_pedi_pacientes_dia': 611,
#   'cli_ad_saidas': 243,
#   'cli_ad_obitos': 6,
#   'cli_ad_pacientes_dia': 625,
#   'cli_idoso_saidas': 178,
#   'cli_idoso_obitos': 28,
#   'cli_idoso_pacientes_dia': 939,
#   'cir_neo_precoce_saidas': 109,
#   'cir_neo_precoce_obitos': 11,
#   'cir_neo_precoce_pacientes_dia': 662,
#   'cir_neo_tardio_saidas': 182,
#   'cir_neo_tardio_obitos': 27,
#   'cir_neo_tardio_pacientes_dia': 653,
#   'cir_pedi_saidas': 271,
#   'cir_pedi_obitos': 20,
#   'cir_pedi_pacientes_dia': 733,
#   'cir_ad_saidas': 239,
#   'cir_ad_obitos': 9,
#   'cir_ad_pacientes_dia': 859,
#   'cir_idoso_saidas': 237,
#   'cir_idoso_obitos': 24,
#   'cir_idoso_pacientes_dia': 518,
#   'total_pacientes_emergencia': 112,
#   'total_tempo_permanencia_emergencia_hr': 883,
#   'pacientes_emergencia_nivel2': 29,
#   'pacientes_emergencia_nivel3': 147,
#   'tempo_total_emergencia_nivel2_min': 554,
#   'tempo_total_emergencia_nivel3_min': 1787,
#   'total_cirurgias_limpas': 138,
#   'cirurgias_com_antibiotico': 78,
#   'total_infeccoes': 0,
#   'unid_int_neo_precoce_cvc_dia': 337,
#   'unid_int_neo_precoce_infec': 3,
#   'uti_neo_precoce_cvc_dia': 282,
#   'uti_neo_precoce_infec': 3,
#   'unid_int_neo_tardio_cvc_dia': 445,
#   'unid_int_neo_tardio_infec': 0,
#   'uti_neo_tardio_cvc_dia': 430,
#   'uti_neo_tardio_infec': 8,
#   'unid_int_pedi_cvc_dia': 314,
#   'unid_int_pedi_infec': 3,
#   'uti_pedi_cvc_dia': 413,
#   'uti_pedi_infec': 10,
#   'unid_int_ad_cvc_dia': 386,
#   'unid_int_ad_infec': 5,
#   'uti_ad_cvc_dia': 414,
#   'uti_ad_infec': 9,
#   'unid_int_idoso_cvc_dia': 320,
#   'unid_int_idoso_infec': 9,
#   'uti_idoso_cvc_dia': 273,
#   'uti_idoso_infec': 4,
#   'unid_int_neo_precoce_cvd_dia': 113,
#   'unid_int_neo_precoce_itu': 5,
#   'uti_neo_precoce_cvd_dia': 162,
#   'uti_neo_precoce_itu': 4,
#   'unid_int_neo_tardio_cvd_dia': 260,
#   'unid_int_neo_tardio_itu': 1,
#   'uti_neo_tardio_cvd_dia': 66,
#   'uti_neo_tardio_itu': 4,
#   'unid_int_pedi_cvd_dia': 221,
#   'unid_int_pedi_itu': 5,
#   'uti_pedi_cvd_dia': 184,
#   'uti_pedi_itu': 3,
#   'unid_int_ad_cvd_dia': 81,
#   'unid_int_ad_itu': 7,
#   'uti_ad_cvd_dia': 299,
#   'uti_ad_itu': 10,
#   'unid_int_idoso_cvd_dia': 260,
#   'unid_int_idoso_itu': 5,
#   'uti_idoso_cvd_dia': 272,
#   'uti_idoso_itu': 0,
#   'cli_total_pacientes': 183,
#   'cli_profilaxia': 101,
#   'cir_orto_total_pacientes': 147,
#   'cir_orto_profilaxia': 126,
#   'cir_nao_orto_total_pacientes': 67,
#   'cir_nao_orto_profilaxia': 44,
#   'quedas_com_dano': 1,
#   'eventos_sentinela': 3},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 2,
#   'partos_vaginais': 90,
#   'partos_cesareos': 96,
#   'saidas_clinicas_anterior': 473,
#   'saidas_cirurgicas_anterior': 216,
#   'reinternacoes_clinicas': 36,
#   'reinternacoes_cirurgicas': 7,
#   'pacientes_dia': 800,
#   'pcr_eventos': 0,
#   'cli_neo_precoce_saidas': 240,
#   'cli_neo_precoce_obitos': 13,
#   'cli_neo_precoce_pacientes_dia': 800,
#   'cli_neo_tardio_saidas': 229,
#   'cli_neo_tardio_obitos': 8,
#   'cli_neo_tardio_pacientes_dia': 572,
#   'cli_pedi_saidas': 199,
#   'cli_pedi_obitos': 21,
#   'cli_pedi_pacientes_dia': 545,
#   'cli_ad_saidas': 257,
#   'cli_ad_obitos': 23,
#   'cli_ad_pacientes_dia': 590,
#   'cli_idoso_saidas': 246,
#   'cli_idoso_obitos': 2,
#   'cli_idoso_pacientes_dia': 585,
#   'cir_neo_precoce_saidas': 287,
#   'cir_neo_precoce_obitos': 11,
#   'cir_neo_precoce_pacientes_dia': 740,
#   'cir_neo_tardio_saidas': 262,
#   'cir_neo_tardio_obitos': 14,
#   'cir_neo_tardio_pacientes_dia': 831,
#   'cir_pedi_saidas': 104,
#   'cir_pedi_obitos': 26,
#   'cir_pedi_pacientes_dia': 989,
#   'cir_ad_saidas': 112,
#   'cir_ad_obitos': 26,
#   'cir_ad_pacientes_dia': 924,
#   'cir_idoso_saidas': 154,
#   'cir_idoso_obitos': 14,
#   'cir_idoso_pacientes_dia': 800,
#   'total_pacientes_emergencia': 187,
#   'total_tempo_permanencia_emergencia_hr': 730,
#   'pacientes_emergencia_nivel2': 64,
#   'pacientes_emergencia_nivel3': 110,
#   'tempo_total_emergencia_nivel2_min': 332,
#   'tempo_total_emergencia_nivel3_min': 2708,
#   'total_cirurgias_limpas': 85,
#   'cirurgias_com_antibiotico': 71,
#   'total_infeccoes': 1,
#   'unid_int_neo_precoce_cvc_dia': 419,
#   'unid_int_neo_precoce_infec': 8,
#   'uti_neo_precoce_cvc_dia': 220,
#   'uti_neo_precoce_infec': 9,
#   'unid_int_neo_tardio_cvc_dia': 236,
#   'unid_int_neo_tardio_infec': 6,
#   'uti_neo_tardio_cvc_dia': 498,
#   'uti_neo_tardio_infec': 8,
#   'unid_int_pedi_cvc_dia': 297,
#   'unid_int_pedi_infec': 6,
#   'uti_pedi_cvc_dia': 327,
#   'uti_pedi_infec': 0,
#   'unid_int_ad_cvc_dia': 234,
#   'unid_int_ad_infec': 7,
#   'uti_ad_cvc_dia': 466,
#   'uti_ad_infec': 0,
#   'unid_int_idoso_cvc_dia': 216,
#   'unid_int_idoso_infec': 0,
#   'uti_idoso_cvc_dia': 270,
#   'uti_idoso_infec': 5,
#   'unid_int_neo_precoce_cvd_dia': 146,
#   'unid_int_neo_precoce_itu': 0,
#   'uti_neo_precoce_cvd_dia': 80,
#   'uti_neo_precoce_itu': 6,
#   'unid_int_neo_tardio_cvd_dia': 259,
#   'unid_int_neo_tardio_itu': 10,
#   'uti_neo_tardio_cvd_dia': 66,
#   'uti_neo_tardio_itu': 2,
#   'unid_int_pedi_cvd_dia': 155,
#   'unid_int_pedi_itu': 10,
#   'uti_pedi_cvd_dia': 148,
#   'uti_pedi_itu': 4,
#   'unid_int_ad_cvd_dia': 114,
#   'unid_int_ad_itu': 9,
#   'uti_ad_cvd_dia': 181,
#   'uti_ad_itu': 4,
#   'unid_int_idoso_cvd_dia': 256,
#   'unid_int_idoso_itu': 10,
#   'uti_idoso_cvd_dia': 210,
#   'uti_idoso_itu': 8,
#   'cli_total_pacientes': 51,
#   'cli_profilaxia': 43,
#   'cir_orto_total_pacientes': 52,
#   'cir_orto_profilaxia': 43,
#   'cir_nao_orto_total_pacientes': 177,
#   'cir_nao_orto_profilaxia': 121,
#   'quedas_com_dano': 6,
#   'eventos_sentinela': 5},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 3,
#   'partos_vaginais': 53,
#   'partos_cesareos': 91,
#   'saidas_clinicas_anterior': 500,
#   'saidas_cirurgicas_anterior': 346,
#   'reinternacoes_clinicas': 13,
#   'reinternacoes_cirurgicas': 22,
#   'pacientes_dia': 611,
#   'pcr_eventos': 4,
#   'cli_neo_precoce_saidas': 106,
#   'cli_neo_precoce_obitos': 17,
#   'cli_neo_precoce_pacientes_dia': 565,
#   'cli_neo_tardio_saidas': 159,
#   'cli_neo_tardio_obitos': 4,
#   'cli_neo_tardio_pacientes_dia': 590,
#   'cli_pedi_saidas': 168,
#   'cli_pedi_obitos': 4,
#   'cli_pedi_pacientes_dia': 517,
#   'cli_ad_saidas': 220,
#   'cli_ad_obitos': 8,
#   'cli_ad_pacientes_dia': 783,
#   'cli_idoso_saidas': 197,
#   'cli_idoso_obitos': 2,
#   'cli_idoso_pacientes_dia': 905,
#   'cir_neo_precoce_saidas': 274,
#   'cir_neo_precoce_obitos': 2,
#   'cir_neo_precoce_pacientes_dia': 717,
#   'cir_neo_tardio_saidas': 250,
#   'cir_neo_tardio_obitos': 17,
#   'cir_neo_tardio_pacientes_dia': 658,
#   'cir_pedi_saidas': 131,
#   'cir_pedi_obitos': 2,
#   'cir_pedi_pacientes_dia': 969,
#   'cir_ad_saidas': 289,
#   'cir_ad_obitos': 7,
#   'cir_ad_pacientes_dia': 847,
#   'cir_idoso_saidas': 163,
#   'cir_idoso_obitos': 7,
#   'cir_idoso_pacientes_dia': 611,
#   'total_pacientes_emergencia': 229,
#   'total_tempo_permanencia_emergencia_hr': 438,
#   'pacientes_emergencia_nivel2': 82,
#   'pacientes_emergencia_nivel3': 129,
#   'tempo_total_emergencia_nivel2_min': 384,
#   'tempo_total_emergencia_nivel3_min': 2263,
#   'total_cirurgias_limpas': 51,
#   'cirurgias_com_antibiotico': 50,
#   'total_infeccoes': 3,
#   'unid_int_neo_precoce_cvc_dia': 395,
#   'unid_int_neo_precoce_infec': 0,
#   'uti_neo_precoce_cvc_dia': 453,
#   'uti_neo_precoce_infec': 0,
#   'unid_int_neo_tardio_cvc_dia': 387,
#   'unid_int_neo_tardio_infec': 1,
#   'uti_neo_tardio_cvc_dia': 233,
#   'uti_neo_tardio_infec': 8,
#   'unid_int_pedi_cvc_dia': 212,
#   'unid_int_pedi_infec': 1,
#   'uti_pedi_cvc_dia': 367,
#   'uti_pedi_infec': 4,
#   'unid_int_ad_cvc_dia': 375,
#   'unid_int_ad_infec': 1,
#   'uti_ad_cvc_dia': 414,
#   'uti_ad_infec': 2,
#   'unid_int_idoso_cvc_dia': 446,
#   'unid_int_idoso_infec': 4,
#   'uti_idoso_cvc_dia': 446,
#   'uti_idoso_infec': 3,
#   'unid_int_neo_precoce_cvd_dia': 195,
#   'unid_int_neo_precoce_itu': 2,
#   'uti_neo_precoce_cvd_dia': 216,
#   'uti_neo_precoce_itu': 8,
#   'unid_int_neo_tardio_cvd_dia': 60,
#   'unid_int_neo_tardio_itu': 8,
#   'uti_neo_tardio_cvd_dia': 96,
#   'uti_neo_tardio_itu': 2,
#   'unid_int_pedi_cvd_dia': 186,
#   'unid_int_pedi_itu': 9,
#   'uti_pedi_cvd_dia': 112,
#   'uti_pedi_itu': 3,
#   'unid_int_ad_cvd_dia': 188,
#   'unid_int_ad_itu': 7,
#   'uti_ad_cvd_dia': 65,
#   'uti_ad_itu': 7,
#   'unid_int_idoso_cvd_dia': 205,
#   'unid_int_idoso_itu': 10,
#   'uti_idoso_cvd_dia': 106,
#   'uti_idoso_itu': 6,
#   'cli_total_pacientes': 189,
#   'cli_profilaxia': 40,
#   'cir_orto_total_pacientes': 56,
#   'cir_orto_profilaxia': 44,
#   'cir_nao_orto_total_pacientes': 66,
#   'cir_nao_orto_profilaxia': 55,
#   'quedas_com_dano': 6,
#   'eventos_sentinela': 2},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 4,
#   'partos_vaginais': 95,
#   'partos_cesareos': 94,
#   'saidas_clinicas_anterior': 459,
#   'saidas_cirurgicas_anterior': 318,
#   'reinternacoes_clinicas': 28,
#   'reinternacoes_cirurgicas': 7,
#   'pacientes_dia': 594,
#   'pcr_eventos': 4,
#   'cli_neo_precoce_saidas': 262,
#   'cli_neo_precoce_obitos': 4,
#   'cli_neo_precoce_pacientes_dia': 898,
#   'cli_neo_tardio_saidas': 146,
#   'cli_neo_tardio_obitos': 8,
#   'cli_neo_tardio_pacientes_dia': 768,
#   'cli_pedi_saidas': 144,
#   'cli_pedi_obitos': 17,
#   'cli_pedi_pacientes_dia': 819,
#   'cli_ad_saidas': 139,
#   'cli_ad_obitos': 17,
#   'cli_ad_pacientes_dia': 903,
#   'cli_idoso_saidas': 127,
#   'cli_idoso_obitos': 3,
#   'cli_idoso_pacientes_dia': 532,
#   'cir_neo_precoce_saidas': 163,
#   'cir_neo_precoce_obitos': 7,
#   'cir_neo_precoce_pacientes_dia': 626,
#   'cir_neo_tardio_saidas': 272,
#   'cir_neo_tardio_obitos': 1,
#   'cir_neo_tardio_pacientes_dia': 673,
#   'cir_pedi_saidas': 172,
#   'cir_pedi_obitos': 8,
#   'cir_pedi_pacientes_dia': 589,
#   'cir_ad_saidas': 142,
#   'cir_ad_obitos': 9,
#   'cir_ad_pacientes_dia': 820,
#   'cir_idoso_saidas': 257,
#   'cir_idoso_obitos': 19,
#   'cir_idoso_pacientes_dia': 594,
#   'total_pacientes_emergencia': 221,
#   'total_tempo_permanencia_emergencia_hr': 550,
#   'pacientes_emergencia_nivel2': 38,
#   'pacientes_emergencia_nivel3': 64,
#   'tempo_total_emergencia_nivel2_min': 597,
#   'tempo_total_emergencia_nivel3_min': 1729,
#   'total_cirurgias_limpas': 125,
#   'cirurgias_com_antibiotico': 107,
#   'total_infeccoes': 5,
#   'unid_int_neo_precoce_cvc_dia': 452,
#   'unid_int_neo_precoce_infec': 4,
#   'uti_neo_precoce_cvc_dia': 313,
#   'uti_neo_precoce_infec': 2,
#   'unid_int_neo_tardio_cvc_dia': 428,
#   'unid_int_neo_tardio_infec': 7,
#   'uti_neo_tardio_cvc_dia': 268,
#   'uti_neo_tardio_infec': 10,
#   'unid_int_pedi_cvc_dia': 320,
#   'unid_int_pedi_infec': 0,
#   'uti_pedi_cvc_dia': 250,
#   'uti_pedi_infec': 7,
#   'unid_int_ad_cvc_dia': 229,
#   'unid_int_ad_infec': 2,
#   'uti_ad_cvc_dia': 209,
#   'uti_ad_infec': 7,
#   'unid_int_idoso_cvc_dia': 230,
#   'unid_int_idoso_infec': 3,
#   'uti_idoso_cvc_dia': 458,
#   'uti_idoso_infec': 6,
#   'unid_int_neo_precoce_cvd_dia': 281,
#   'unid_int_neo_precoce_itu': 7,
#   'uti_neo_precoce_cvd_dia': 64,
#   'uti_neo_precoce_itu': 2,
#   'unid_int_neo_tardio_cvd_dia': 209,
#   'unid_int_neo_tardio_itu': 2,
#   'uti_neo_tardio_cvd_dia': 161,
#   'uti_neo_tardio_itu': 8,
#   'unid_int_pedi_cvd_dia': 152,
#   'unid_int_pedi_itu': 4,
#   'uti_pedi_cvd_dia': 199,
#   'uti_pedi_itu': 10,
#   'unid_int_ad_cvd_dia': 143,
#   'unid_int_ad_itu': 6,
#   'uti_ad_cvd_dia': 136,
#   'uti_ad_itu': 6,
#   'unid_int_idoso_cvd_dia': 158,
#   'unid_int_idoso_itu': 10,
#   'uti_idoso_cvd_dia': 140,
#   'uti_idoso_itu': 0,
#   'cli_total_pacientes': 161,
#   'cli_profilaxia': 155,
#   'cir_orto_total_pacientes': 61,
#   'cir_orto_profilaxia': 47,
#   'cir_nao_orto_total_pacientes': 151,
#   'cir_nao_orto_profilaxia': 82,
#   'quedas_com_dano': 5,
#   'eventos_sentinela': 3},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 5,
#   'partos_vaginais': 125,
#   'partos_cesareos': 76,
#   'saidas_clinicas_anterior': 406,
#   'saidas_cirurgicas_anterior': 393,
#   'reinternacoes_clinicas': 10,
#   'reinternacoes_cirurgicas': 18,
#   'pacientes_dia': 918,
#   'pcr_eventos': 3,
#   'cli_neo_precoce_saidas': 280,
#   'cli_neo_precoce_obitos': 14,
#   'cli_neo_precoce_pacientes_dia': 587,
#   'cli_neo_tardio_saidas': 134,
#   'cli_neo_tardio_obitos': 15,
#   'cli_neo_tardio_pacientes_dia': 763,
#   'cli_pedi_saidas': 146,
#   'cli_pedi_obitos': 26,
#   'cli_pedi_pacientes_dia': 668,
#   'cli_ad_saidas': 122,
#   'cli_ad_obitos': 7,
#   'cli_ad_pacientes_dia': 900,
#   'cli_idoso_saidas': 264,
#   'cli_idoso_obitos': 25,
#   'cli_idoso_pacientes_dia': 843,
#   'cir_neo_precoce_saidas': 172,
#   'cir_neo_precoce_obitos': 1,
#   'cir_neo_precoce_pacientes_dia': 605,
#   'cir_neo_tardio_saidas': 280,
#   'cir_neo_tardio_obitos': 20,
#   'cir_neo_tardio_pacientes_dia': 694,
#   'cir_pedi_saidas': 204,
#   'cir_pedi_obitos': 1,
#   'cir_pedi_pacientes_dia': 742,
#   'cir_ad_saidas': 140,
#   'cir_ad_obitos': 12,
#   'cir_ad_pacientes_dia': 859,
#   'cir_idoso_saidas': 152,
#   'cir_idoso_obitos': 19,
#   'cir_idoso_pacientes_dia': 918,
#   'total_pacientes_emergencia': 234,
#   'total_tempo_permanencia_emergencia_hr': 525,
#   'pacientes_emergencia_nivel2': 53,
#   'pacientes_emergencia_nivel3': 131,
#   'tempo_total_emergencia_nivel2_min': 408,
#   'tempo_total_emergencia_nivel3_min': 2429,
#   'total_cirurgias_limpas': 148,
#   'cirurgias_com_antibiotico': 96,
#   'total_infeccoes': 4,
#   'unid_int_neo_precoce_cvc_dia': 375,
#   'unid_int_neo_precoce_infec': 7,
#   'uti_neo_precoce_cvc_dia': 271,
#   'uti_neo_precoce_infec': 7,
#   'unid_int_neo_tardio_cvc_dia': 407,
#   'unid_int_neo_tardio_infec': 10,
#   'uti_neo_tardio_cvc_dia': 332,
#   'uti_neo_tardio_infec': 4,
#   'unid_int_pedi_cvc_dia': 328,
#   'unid_int_pedi_infec': 2,
#   'uti_pedi_cvc_dia': 353,
#   'uti_pedi_infec': 8,
#   'unid_int_ad_cvc_dia': 280,
#   'unid_int_ad_infec': 2,
#   'uti_ad_cvc_dia': 242,
#   'uti_ad_infec': 1,
#   'unid_int_idoso_cvc_dia': 244,
#   'unid_int_idoso_infec': 10,
#   'uti_idoso_cvc_dia': 498,
#   'uti_idoso_infec': 6,
#   'unid_int_neo_precoce_cvd_dia': 271,
#   'unid_int_neo_precoce_itu': 5,
#   'uti_neo_precoce_cvd_dia': 225,
#   'uti_neo_precoce_itu': 9,
#   'unid_int_neo_tardio_cvd_dia': 264,
#   'unid_int_neo_tardio_itu': 7,
#   'uti_neo_tardio_cvd_dia': 93,
#   'uti_neo_tardio_itu': 5,
#   'unid_int_pedi_cvd_dia': 104,
#   'unid_int_pedi_itu': 8,
#   'uti_pedi_cvd_dia': 179,
#   'uti_pedi_itu': 4,
#   'unid_int_ad_cvd_dia': 169,
#   'unid_int_ad_itu': 4,
#   'uti_ad_cvd_dia': 281,
#   'uti_ad_itu': 0,
#   'unid_int_idoso_cvd_dia': 274,
#   'unid_int_idoso_itu': 8,
#   'uti_idoso_cvd_dia': 146,
#   'uti_idoso_itu': 0,
#   'cli_total_pacientes': 120,
#   'cli_profilaxia': 69,
#   'cir_orto_total_pacientes': 79,
#   'cir_orto_profilaxia': 77,
#   'cir_nao_orto_total_pacientes': 88,
#   'cir_nao_orto_profilaxia': 86,
#   'quedas_com_dano': 8,
#   'eventos_sentinela': 2},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 6,
#   'partos_vaginais': 135,
#   'partos_cesareos': 88,
#   'saidas_clinicas_anterior': 386,
#   'saidas_cirurgicas_anterior': 314,
#   'reinternacoes_clinicas': 44,
#   'reinternacoes_cirurgicas': 22,
#   'pacientes_dia': 531,
#   'pcr_eventos': 1,
#   'cli_neo_precoce_saidas': 115,
#   'cli_neo_precoce_obitos': 29,
#   'cli_neo_precoce_pacientes_dia': 563,
#   'cli_neo_tardio_saidas': 267,
#   'cli_neo_tardio_obitos': 11,
#   'cli_neo_tardio_pacientes_dia': 841,
#   'cli_pedi_saidas': 260,
#   'cli_pedi_obitos': 10,
#   'cli_pedi_pacientes_dia': 725,
#   'cli_ad_saidas': 197,
#   'cli_ad_obitos': 22,
#   'cli_ad_pacientes_dia': 970,
#   'cli_idoso_saidas': 238,
#   'cli_idoso_obitos': 29,
#   'cli_idoso_pacientes_dia': 613,
#   'cir_neo_precoce_saidas': 279,
#   'cir_neo_precoce_obitos': 8,
#   'cir_neo_precoce_pacientes_dia': 906,
#   'cir_neo_tardio_saidas': 166,
#   'cir_neo_tardio_obitos': 12,
#   'cir_neo_tardio_pacientes_dia': 921,
#   'cir_pedi_saidas': 198,
#   'cir_pedi_obitos': 12,
#   'cir_pedi_pacientes_dia': 783,
#   'cir_ad_saidas': 295,
#   'cir_ad_obitos': 13,
#   'cir_ad_pacientes_dia': 531,
#   'cir_idoso_saidas': 257,
#   'cir_idoso_obitos': 25,
#   'cir_idoso_pacientes_dia': 531,
#   'total_pacientes_emergencia': 102,
#   'total_tempo_permanencia_emergencia_hr': 786,
#   'pacientes_emergencia_nivel2': 85,
#   'pacientes_emergencia_nivel3': 136,
#   'tempo_total_emergencia_nivel2_min': 598,
#   'tempo_total_emergencia_nivel3_min': 2976,
#   'total_cirurgias_limpas': 112,
#   'cirurgias_com_antibiotico': 67,
#   'total_infeccoes': 2,
#   'unid_int_neo_precoce_cvc_dia': 282,
#   'unid_int_neo_precoce_infec': 5,
#   'uti_neo_precoce_cvc_dia': 245,
#   'uti_neo_precoce_infec': 4,
#   'unid_int_neo_tardio_cvc_dia': 408,
#   'unid_int_neo_tardio_infec': 2,
#   'uti_neo_tardio_cvc_dia': 265,
#   'uti_neo_tardio_infec': 3,
#   'unid_int_pedi_cvc_dia': 466,
#   'unid_int_pedi_infec': 9,
#   'uti_pedi_cvc_dia': 448,
#   'uti_pedi_infec': 5,
#   'unid_int_ad_cvc_dia': 448,
#   'unid_int_ad_infec': 9,
#   'uti_ad_cvc_dia': 226,
#   'uti_ad_infec': 7,
#   'unid_int_idoso_cvc_dia': 371,
#   'unid_int_idoso_infec': 9,
#   'uti_idoso_cvc_dia': 414,
#   'uti_idoso_infec': 6,
#   'unid_int_neo_precoce_cvd_dia': 158,
#   'unid_int_neo_precoce_itu': 6,
#   'uti_neo_precoce_cvd_dia': 130,
#   'uti_neo_precoce_itu': 3,
#   'unid_int_neo_tardio_cvd_dia': 165,
#   'unid_int_neo_tardio_itu': 10,
#   'uti_neo_tardio_cvd_dia': 263,
#   'uti_neo_tardio_itu': 2,
#   'unid_int_pedi_cvd_dia': 164,
#   'unid_int_pedi_itu': 2,
#   'uti_pedi_cvd_dia': 225,
#   'uti_pedi_itu': 10,
#   'unid_int_ad_cvd_dia': 107,
#   'unid_int_ad_itu': 3,
#   'uti_ad_cvd_dia': 153,
#   'uti_ad_itu': 4,
#   'unid_int_idoso_cvd_dia': 227,
#   'unid_int_idoso_itu': 6,
#   'uti_idoso_cvd_dia': 149,
#   'uti_idoso_itu': 3,
#   'cli_total_pacientes': 163,
#   'cli_profilaxia': 75,
#   'cir_orto_total_pacientes': 124,
#   'cir_orto_profilaxia': 63,
#   'cir_nao_orto_total_pacientes': 156,
#   'cir_nao_orto_profilaxia': 55,
#   'quedas_com_dano': 7,
#   'eventos_sentinela': 0},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 7,
#   'partos_vaginais': 137,
#   'partos_cesareos': 76,
#   'saidas_clinicas_anterior': 420,
#   'saidas_cirurgicas_anterior': 396,
#   'reinternacoes_clinicas': 35,
#   'reinternacoes_cirurgicas': 30,
#   'pacientes_dia': 755,
#   'pcr_eventos': 3,
#   'cli_neo_precoce_saidas': 205,
#   'cli_neo_precoce_obitos': 1,
#   'cli_neo_precoce_pacientes_dia': 689,
#   'cli_neo_tardio_saidas': 284,
#   'cli_neo_tardio_obitos': 7,
#   'cli_neo_tardio_pacientes_dia': 631,
#   'cli_pedi_saidas': 252,
#   'cli_pedi_obitos': 7,
#   'cli_pedi_pacientes_dia': 945,
#   'cli_ad_saidas': 237,
#   'cli_ad_obitos': 28,
#   'cli_ad_pacientes_dia': 874,
#   'cli_idoso_saidas': 181,
#   'cli_idoso_obitos': 23,
#   'cli_idoso_pacientes_dia': 864,
#   'cir_neo_precoce_saidas': 224,
#   'cir_neo_precoce_obitos': 20,
#   'cir_neo_precoce_pacientes_dia': 574,
#   'cir_neo_tardio_saidas': 125,
#   'cir_neo_tardio_obitos': 16,
#   'cir_neo_tardio_pacientes_dia': 636,
#   'cir_pedi_saidas': 138,
#   'cir_pedi_obitos': 10,
#   'cir_pedi_pacientes_dia': 855,
#   'cir_ad_saidas': 155,
#   'cir_ad_obitos': 28,
#   'cir_ad_pacientes_dia': 628,
#   'cir_idoso_saidas': 248,
#   'cir_idoso_obitos': 15,
#   'cir_idoso_pacientes_dia': 755,
#   'total_pacientes_emergencia': 111,
#   'total_tempo_permanencia_emergencia_hr': 848,
#   'pacientes_emergencia_nivel2': 54,
#   'pacientes_emergencia_nivel3': 72,
#   'tempo_total_emergencia_nivel2_min': 576,
#   'tempo_total_emergencia_nivel3_min': 1657,
#   'total_cirurgias_limpas': 100,
#   'cirurgias_com_antibiotico': 96,
#   'total_infeccoes': 4,
#   'unid_int_neo_precoce_cvc_dia': 481,
#   'unid_int_neo_precoce_infec': 8,
#   'uti_neo_precoce_cvc_dia': 500,
#   'uti_neo_precoce_infec': 2,
#   'unid_int_neo_tardio_cvc_dia': 333,
#   'unid_int_neo_tardio_infec': 3,
#   'uti_neo_tardio_cvc_dia': 237,
#   'uti_neo_tardio_infec': 3,
#   'unid_int_pedi_cvc_dia': 395,
#   'unid_int_pedi_infec': 3,
#   'uti_pedi_cvc_dia': 346,
#   'uti_pedi_infec': 0,
#   'unid_int_ad_cvc_dia': 368,
#   'unid_int_ad_infec': 3,
#   'uti_ad_cvc_dia': 226,
#   'uti_ad_infec': 5,
#   'unid_int_idoso_cvc_dia': 477,
#   'unid_int_idoso_infec': 3,
#   'uti_idoso_cvc_dia': 490,
#   'uti_idoso_infec': 2,
#   'unid_int_neo_precoce_cvd_dia': 272,
#   'unid_int_neo_precoce_itu': 3,
#   'uti_neo_precoce_cvd_dia': 87,
#   'uti_neo_precoce_itu': 4,
#   'unid_int_neo_tardio_cvd_dia': 93,
#   'unid_int_neo_tardio_itu': 2,
#   'uti_neo_tardio_cvd_dia': 227,
#   'uti_neo_tardio_itu': 5,
#   'unid_int_pedi_cvd_dia': 66,
#   'unid_int_pedi_itu': 5,
#   'uti_pedi_cvd_dia': 98,
#   'uti_pedi_itu': 7,
#   'unid_int_ad_cvd_dia': 96,
#   'unid_int_ad_itu': 7,
#   'uti_ad_cvd_dia': 269,
#   'uti_ad_itu': 1,
#   'unid_int_idoso_cvd_dia': 181,
#   'unid_int_idoso_itu': 3,
#   'uti_idoso_cvd_dia': 72,
#   'uti_idoso_itu': 3,
#   'cli_total_pacientes': 195,
#   'cli_profilaxia': 138,
#   'cir_orto_total_pacientes': 51,
#   'cir_orto_profilaxia': 46,
#   'cir_nao_orto_total_pacientes': 183,
#   'cir_nao_orto_profilaxia': 48,
#   'quedas_com_dano': 8,
#   'eventos_sentinela': 2},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 8,
#   'partos_vaginais': 126,
#   'partos_cesareos': 62,
#   'saidas_clinicas_anterior': 335,
#   'saidas_cirurgicas_anterior': 391,
#   'reinternacoes_clinicas': 27,
#   'reinternacoes_cirurgicas': 17,
#   'pacientes_dia': 756,
#   'pcr_eventos': 0,
#   'cli_neo_precoce_saidas': 135,
#   'cli_neo_precoce_obitos': 20,
#   'cli_neo_precoce_pacientes_dia': 990,
#   'cli_neo_tardio_saidas': 237,
#   'cli_neo_tardio_obitos': 12,
#   'cli_neo_tardio_pacientes_dia': 812,
#   'cli_pedi_saidas': 100,
#   'cli_pedi_obitos': 19,
#   'cli_pedi_pacientes_dia': 689,
#   'cli_ad_saidas': 148,
#   'cli_ad_obitos': 29,
#   'cli_ad_pacientes_dia': 689,
#   'cli_idoso_saidas': 272,
#   'cli_idoso_obitos': 10,
#   'cli_idoso_pacientes_dia': 501,
#   'cir_neo_precoce_saidas': 223,
#   'cir_neo_precoce_obitos': 14,
#   'cir_neo_precoce_pacientes_dia': 974,
#   'cir_neo_tardio_saidas': 155,
#   'cir_neo_tardio_obitos': 8,
#   'cir_neo_tardio_pacientes_dia': 742,
#   'cir_pedi_saidas': 140,
#   'cir_pedi_obitos': 30,
#   'cir_pedi_pacientes_dia': 660,
#   'cir_ad_saidas': 198,
#   'cir_ad_obitos': 2,
#   'cir_ad_pacientes_dia': 631,
#   'cir_idoso_saidas': 151,
#   'cir_idoso_obitos': 4,
#   'cir_idoso_pacientes_dia': 756,
#   'total_pacientes_emergencia': 162,
#   'total_tempo_permanencia_emergencia_hr': 574,
#   'pacientes_emergencia_nivel2': 63,
#   'pacientes_emergencia_nivel3': 56,
#   'tempo_total_emergencia_nivel2_min': 582,
#   'tempo_total_emergencia_nivel3_min': 2502,
#   'total_cirurgias_limpas': 115,
#   'cirurgias_com_antibiotico': 58,
#   'total_infeccoes': 4,
#   'unid_int_neo_precoce_cvc_dia': 203,
#   'unid_int_neo_precoce_infec': 9,
#   'uti_neo_precoce_cvc_dia': 454,
#   'uti_neo_precoce_infec': 7,
#   'unid_int_neo_tardio_cvc_dia': 437,
#   'unid_int_neo_tardio_infec': 0,
#   'uti_neo_tardio_cvc_dia': 278,
#   'uti_neo_tardio_infec': 7,
#   'unid_int_pedi_cvc_dia': 211,
#   'unid_int_pedi_infec': 5,
#   'uti_pedi_cvc_dia': 206,
#   'uti_pedi_infec': 1,
#   'unid_int_ad_cvc_dia': 333,
#   'unid_int_ad_infec': 1,
#   'uti_ad_cvc_dia': 291,
#   'uti_ad_infec': 4,
#   'unid_int_idoso_cvc_dia': 216,
#   'unid_int_idoso_infec': 1,
#   'uti_idoso_cvc_dia': 237,
#   'uti_idoso_infec': 7,
#   'unid_int_neo_precoce_cvd_dia': 51,
#   'unid_int_neo_precoce_itu': 6,
#   'uti_neo_precoce_cvd_dia': 146,
#   'uti_neo_precoce_itu': 4,
#   'unid_int_neo_tardio_cvd_dia': 103,
#   'unid_int_neo_tardio_itu': 5,
#   'uti_neo_tardio_cvd_dia': 237,
#   'uti_neo_tardio_itu': 4,
#   'unid_int_pedi_cvd_dia': 108,
#   'unid_int_pedi_itu': 3,
#   'uti_pedi_cvd_dia': 198,
#   'uti_pedi_itu': 3,
#   'unid_int_ad_cvd_dia': 263,
#   'unid_int_ad_itu': 7,
#   'uti_ad_cvd_dia': 134,
#   'uti_ad_itu': 9,
#   'unid_int_idoso_cvd_dia': 155,
#   'unid_int_idoso_itu': 7,
#   'uti_idoso_cvd_dia': 69,
#   'uti_idoso_itu': 4,
#   'cli_total_pacientes': 130,
#   'cli_profilaxia': 56,
#   'cir_orto_total_pacientes': 115,
#   'cir_orto_profilaxia': 45,
#   'cir_nao_orto_total_pacientes': 96,
#   'cir_nao_orto_profilaxia': 86,
#   'quedas_com_dano': 3,
#   'eventos_sentinela': 2},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 9,
#   'partos_vaginais': 76,
#   'partos_cesareos': 95,
#   'saidas_clinicas_anterior': 557,
#   'saidas_cirurgicas_anterior': 250,
#   'reinternacoes_clinicas': 34,
#   'reinternacoes_cirurgicas': 12,
#   'pacientes_dia': 728,
#   'pcr_eventos': 4,
#   'cli_neo_precoce_saidas': 267,
#   'cli_neo_precoce_obitos': 15,
#   'cli_neo_precoce_pacientes_dia': 566,
#   'cli_neo_tardio_saidas': 258,
#   'cli_neo_tardio_obitos': 11,
#   'cli_neo_tardio_pacientes_dia': 585,
#   'cli_pedi_saidas': 107,
#   'cli_pedi_obitos': 5,
#   'cli_pedi_pacientes_dia': 856,
#   'cli_ad_saidas': 198,
#   'cli_ad_obitos': 2,
#   'cli_ad_pacientes_dia': 692,
#   'cli_idoso_saidas': 290,
#   'cli_idoso_obitos': 26,
#   'cli_idoso_pacientes_dia': 697,
#   'cir_neo_precoce_saidas': 141,
#   'cir_neo_precoce_obitos': 9,
#   'cir_neo_precoce_pacientes_dia': 682,
#   'cir_neo_tardio_saidas': 142,
#   'cir_neo_tardio_obitos': 16,
#   'cir_neo_tardio_pacientes_dia': 573,
#   'cir_pedi_saidas': 140,
#   'cir_pedi_obitos': 18,
#   'cir_pedi_pacientes_dia': 840,
#   'cir_ad_saidas': 157,
#   'cir_ad_obitos': 10,
#   'cir_ad_pacientes_dia': 505,
#   'cir_idoso_saidas': 105,
#   'cir_idoso_obitos': 10,
#   'cir_idoso_pacientes_dia': 728,
#   'total_pacientes_emergencia': 229,
#   'total_tempo_permanencia_emergencia_hr': 875,
#   'pacientes_emergencia_nivel2': 90,
#   'pacientes_emergencia_nivel3': 138,
#   'tempo_total_emergencia_nivel2_min': 319,
#   'tempo_total_emergencia_nivel3_min': 1546,
#   'total_cirurgias_limpas': 86,
#   'cirurgias_com_antibiotico': 84,
#   'total_infeccoes': 2,
#   'unid_int_neo_precoce_cvc_dia': 428,
#   'unid_int_neo_precoce_infec': 2,
#   'uti_neo_precoce_cvc_dia': 463,
#   'uti_neo_precoce_infec': 6,
#   'unid_int_neo_tardio_cvc_dia': 279,
#   'unid_int_neo_tardio_infec': 4,
#   'uti_neo_tardio_cvc_dia': 242,
#   'uti_neo_tardio_infec': 7,
#   'unid_int_pedi_cvc_dia': 368,
#   'unid_int_pedi_infec': 10,
#   'uti_pedi_cvc_dia': 462,
#   'uti_pedi_infec': 4,
#   'unid_int_ad_cvc_dia': 451,
#   'unid_int_ad_infec': 8,
#   'uti_ad_cvc_dia': 445,
#   'uti_ad_infec': 1,
#   'unid_int_idoso_cvc_dia': 297,
#   'unid_int_idoso_infec': 9,
#   'uti_idoso_cvc_dia': 334,
#   'uti_idoso_infec': 1,
#   'unid_int_neo_precoce_cvd_dia': 68,
#   'unid_int_neo_precoce_itu': 3,
#   'uti_neo_precoce_cvd_dia': 192,
#   'uti_neo_precoce_itu': 9,
#   'unid_int_neo_tardio_cvd_dia': 204,
#   'unid_int_neo_tardio_itu': 4,
#   'uti_neo_tardio_cvd_dia': 171,
#   'uti_neo_tardio_itu': 2,
#   'unid_int_pedi_cvd_dia': 115,
#   'unid_int_pedi_itu': 2,
#   'uti_pedi_cvd_dia': 50,
#   'uti_pedi_itu': 4,
#   'unid_int_ad_cvd_dia': 88,
#   'unid_int_ad_itu': 0,
#   'uti_ad_cvd_dia': 280,
#   'uti_ad_itu': 9,
#   'unid_int_idoso_cvd_dia': 207,
#   'unid_int_idoso_itu': 2,
#   'uti_idoso_cvd_dia': 174,
#   'uti_idoso_itu': 9,
#   'cli_total_pacientes': 81,
#   'cli_profilaxia': 52,
#   'cir_orto_total_pacientes': 71,
#   'cir_orto_profilaxia': 52,
#   'cir_nao_orto_total_pacientes': 157,
#   'cir_nao_orto_profilaxia': 49,
#   'quedas_com_dano': 1,
#   'eventos_sentinela': 1},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 10,
#   'partos_vaginais': 88,
#   'partos_cesareos': 89,
#   'saidas_clinicas_anterior': 347,
#   'saidas_cirurgicas_anterior': 272,
#   'reinternacoes_clinicas': 32,
#   'reinternacoes_cirurgicas': 29,
#   'pacientes_dia': 623,
#   'pcr_eventos': 0,
#   'cli_neo_precoce_saidas': 148,
#   'cli_neo_precoce_obitos': 16,
#   'cli_neo_precoce_pacientes_dia': 608,
#   'cli_neo_tardio_saidas': 225,
#   'cli_neo_tardio_obitos': 2,
#   'cli_neo_tardio_pacientes_dia': 971,
#   'cli_pedi_saidas': 277,
#   'cli_pedi_obitos': 14,
#   'cli_pedi_pacientes_dia': 919,
#   'cli_ad_saidas': 125,
#   'cli_ad_obitos': 3,
#   'cli_ad_pacientes_dia': 977,
#   'cli_idoso_saidas': 277,
#   'cli_idoso_obitos': 1,
#   'cli_idoso_pacientes_dia': 950,
#   'cir_neo_precoce_saidas': 125,
#   'cir_neo_precoce_obitos': 14,
#   'cir_neo_precoce_pacientes_dia': 728,
#   'cir_neo_tardio_saidas': 111,
#   'cir_neo_tardio_obitos': 25,
#   'cir_neo_tardio_pacientes_dia': 944,
#   'cir_pedi_saidas': 145,
#   'cir_pedi_obitos': 22,
#   'cir_pedi_pacientes_dia': 566,
#   'cir_ad_saidas': 299,
#   'cir_ad_obitos': 7,
#   'cir_ad_pacientes_dia': 652,
#   'cir_idoso_saidas': 157,
#   'cir_idoso_obitos': 20,
#   'cir_idoso_pacientes_dia': 623,
#   'total_pacientes_emergencia': 295,
#   'total_tempo_permanencia_emergencia_hr': 660,
#   'pacientes_emergencia_nivel2': 24,
#   'pacientes_emergencia_nivel3': 130,
#   'tempo_total_emergencia_nivel2_min': 326,
#   'tempo_total_emergencia_nivel3_min': 1764,
#   'total_cirurgias_limpas': 68,
#   'cirurgias_com_antibiotico': 44,
#   'total_infeccoes': 2,
#   'unid_int_neo_precoce_cvc_dia': 267,
#   'unid_int_neo_precoce_infec': 9,
#   'uti_neo_precoce_cvc_dia': 231,
#   'uti_neo_precoce_infec': 7,
#   'unid_int_neo_tardio_cvc_dia': 270,
#   'unid_int_neo_tardio_infec': 9,
#   'uti_neo_tardio_cvc_dia': 303,
#   'uti_neo_tardio_infec': 2,
#   'unid_int_pedi_cvc_dia': 435,
#   'unid_int_pedi_infec': 10,
#   'uti_pedi_cvc_dia': 406,
#   'uti_pedi_infec': 9,
#   'unid_int_ad_cvc_dia': 319,
#   'unid_int_ad_infec': 3,
#   'uti_ad_cvc_dia': 377,
#   'uti_ad_infec': 8,
#   'unid_int_idoso_cvc_dia': 411,
#   'unid_int_idoso_infec': 3,
#   'uti_idoso_cvc_dia': 371,
#   'uti_idoso_infec': 8,
#   'unid_int_neo_precoce_cvd_dia': 267,
#   'unid_int_neo_precoce_itu': 5,
#   'uti_neo_precoce_cvd_dia': 125,
#   'uti_neo_precoce_itu': 8,
#   'unid_int_neo_tardio_cvd_dia': 142,
#   'unid_int_neo_tardio_itu': 7,
#   'uti_neo_tardio_cvd_dia': 145,
#   'uti_neo_tardio_itu': 6,
#   'unid_int_pedi_cvd_dia': 277,
#   'unid_int_pedi_itu': 1,
#   'uti_pedi_cvd_dia': 147,
#   'uti_pedi_itu': 10,
#   'unid_int_ad_cvd_dia': 51,
#   'unid_int_ad_itu': 7,
#   'uti_ad_cvd_dia': 192,
#   'uti_ad_itu': 4,
#   'unid_int_idoso_cvd_dia': 126,
#   'unid_int_idoso_itu': 2,
#   'uti_idoso_cvd_dia': 283,
#   'uti_idoso_itu': 9,
#   'cli_total_pacientes': 57,
#   'cli_profilaxia': 55,
#   'cir_orto_total_pacientes': 188,
#   'cir_orto_profilaxia': 98,
#   'cir_nao_orto_total_pacientes': 157,
#   'cir_nao_orto_profilaxia': 148,
#   'quedas_com_dano': 8,
#   'eventos_sentinela': 2},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 11,
#   'partos_vaginais': 57,
#   'partos_cesareos': 65,
#   'saidas_clinicas_anterior': 360,
#   'saidas_cirurgicas_anterior': 324,
#   'reinternacoes_clinicas': 28,
#   'reinternacoes_cirurgicas': 10,
#   'pacientes_dia': 871,
#   'pcr_eventos': 4,
#   'cli_neo_precoce_saidas': 270,
#   'cli_neo_precoce_obitos': 4,
#   'cli_neo_precoce_pacientes_dia': 847,
#   'cli_neo_tardio_saidas': 202,
#   'cli_neo_tardio_obitos': 23,
#   'cli_neo_tardio_pacientes_dia': 796,
#   'cli_pedi_saidas': 205,
#   'cli_pedi_obitos': 2,
#   'cli_pedi_pacientes_dia': 705,
#   'cli_ad_saidas': 222,
#   'cli_ad_obitos': 24,
#   'cli_ad_pacientes_dia': 887,
#   'cli_idoso_saidas': 148,
#   'cli_idoso_obitos': 4,
#   'cli_idoso_pacientes_dia': 965,
#   'cir_neo_precoce_saidas': 176,
#   'cir_neo_precoce_obitos': 28,
#   'cir_neo_precoce_pacientes_dia': 807,
#   'cir_neo_tardio_saidas': 140,
#   'cir_neo_tardio_obitos': 10,
#   'cir_neo_tardio_pacientes_dia': 509,
#   'cir_pedi_saidas': 279,
#   'cir_pedi_obitos': 3,
#   'cir_pedi_pacientes_dia': 532,
#   'cir_ad_saidas': 166,
#   'cir_ad_obitos': 25,
#   'cir_ad_pacientes_dia': 533,
#   'cir_idoso_saidas': 176,
#   'cir_idoso_obitos': 9,
#   'cir_idoso_pacientes_dia': 871,
#   'total_pacientes_emergencia': 287,
#   'total_tempo_permanencia_emergencia_hr': 649,
#   'pacientes_emergencia_nivel2': 26,
#   'pacientes_emergencia_nivel3': 80,
#   'tempo_total_emergencia_nivel2_min': 346,
#   'tempo_total_emergencia_nivel3_min': 1733,
#   'total_cirurgias_limpas': 123,
#   'cirurgias_com_antibiotico': 99,
#   'total_infeccoes': 0,
#   'unid_int_neo_precoce_cvc_dia': 203,
#   'unid_int_neo_precoce_infec': 0,
#   'uti_neo_precoce_cvc_dia': 368,
#   'uti_neo_precoce_infec': 0,
#   'unid_int_neo_tardio_cvc_dia': 499,
#   'unid_int_neo_tardio_infec': 0,
#   'uti_neo_tardio_cvc_dia': 426,
#   'uti_neo_tardio_infec': 6,
#   'unid_int_pedi_cvc_dia': 318,
#   'unid_int_pedi_infec': 2,
#   'uti_pedi_cvc_dia': 339,
#   'uti_pedi_infec': 0,
#   'unid_int_ad_cvc_dia': 480,
#   'unid_int_ad_infec': 7,
#   'uti_ad_cvc_dia': 457,
#   'uti_ad_infec': 4,
#   'unid_int_idoso_cvc_dia': 473,
#   'unid_int_idoso_infec': 3,
#   'uti_idoso_cvc_dia': 423,
#   'uti_idoso_infec': 8,
#   'unid_int_neo_precoce_cvd_dia': 225,
#   'unid_int_neo_precoce_itu': 4,
#   'uti_neo_precoce_cvd_dia': 52,
#   'uti_neo_precoce_itu': 2,
#   'unid_int_neo_tardio_cvd_dia': 65,
#   'unid_int_neo_tardio_itu': 6,
#   'uti_neo_tardio_cvd_dia': 182,
#   'uti_neo_tardio_itu': 2,
#   'unid_int_pedi_cvd_dia': 245,
#   'unid_int_pedi_itu': 5,
#   'uti_pedi_cvd_dia': 115,
#   'uti_pedi_itu': 3,
#   'unid_int_ad_cvd_dia': 235,
#   'unid_int_ad_itu': 10,
#   'uti_ad_cvd_dia': 272,
#   'uti_ad_itu': 7,
#   'unid_int_idoso_cvd_dia': 157,
#   'unid_int_idoso_itu': 8,
#   'uti_idoso_cvd_dia': 273,
#   'uti_idoso_itu': 10,
#   'cli_total_pacientes': 74,
#   'cli_profilaxia': 52,
#   'cir_orto_total_pacientes': 167,
#   'cir_orto_profilaxia': 150,
#   'cir_nao_orto_total_pacientes': 126,
#   'cir_nao_orto_profilaxia': 87,
#   'quedas_com_dano': 3,
#   'eventos_sentinela': 3},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2023,
#   'month': 12,
#   'partos_vaginais': 115,
#   'partos_cesareos': 94,
#   'saidas_clinicas_anterior': 399,
#   'saidas_cirurgicas_anterior': 296,
#   'reinternacoes_clinicas': 15,
#   'reinternacoes_cirurgicas': 23,
#   'pacientes_dia': 905,
#   'pcr_eventos': 4,
#   'cli_neo_precoce_saidas': 281,
#   'cli_neo_precoce_obitos': 17,
#   'cli_neo_precoce_pacientes_dia': 891,
#   'cli_neo_tardio_saidas': 107,
#   'cli_neo_tardio_obitos': 4,
#   'cli_neo_tardio_pacientes_dia': 751,
#   'cli_pedi_saidas': 180,
#   'cli_pedi_obitos': 26,
#   'cli_pedi_pacientes_dia': 889,
#   'cli_ad_saidas': 134,
#   'cli_ad_obitos': 1,
#   'cli_ad_pacientes_dia': 984,
#   'cli_idoso_saidas': 102,
#   'cli_idoso_obitos': 4,
#   'cli_idoso_pacientes_dia': 975,
#   'cir_neo_precoce_saidas': 175,
#   'cir_neo_precoce_obitos': 19,
#   'cir_neo_precoce_pacientes_dia': 730,
#   'cir_neo_tardio_saidas': 152,
#   'cir_neo_tardio_obitos': 13,
#   'cir_neo_tardio_pacientes_dia': 773,
#   'cir_pedi_saidas': 132,
#   'cir_pedi_obitos': 8,
#   'cir_pedi_pacientes_dia': 632,
#   'cir_ad_saidas': 261,
#   'cir_ad_obitos': 26,
#   'cir_ad_pacientes_dia': 581,
#   'cir_idoso_saidas': 266,
#   'cir_idoso_obitos': 7,
#   'cir_idoso_pacientes_dia': 905,
#   'total_pacientes_emergencia': 236,
#   'total_tempo_permanencia_emergencia_hr': 447,
#   'pacientes_emergencia_nivel2': 38,
#   'pacientes_emergencia_nivel3': 58,
#   'tempo_total_emergencia_nivel2_min': 244,
#   'tempo_total_emergencia_nivel3_min': 2580,
#   'total_cirurgias_limpas': 61,
#   'cirurgias_com_antibiotico': 51,
#   'total_infeccoes': 4,
#   'unid_int_neo_precoce_cvc_dia': 427,
#   'unid_int_neo_precoce_infec': 10,
#   'uti_neo_precoce_cvc_dia': 347,
#   'uti_neo_precoce_infec': 4,
#   'unid_int_neo_tardio_cvc_dia': 399,
#   'unid_int_neo_tardio_infec': 10,
#   'uti_neo_tardio_cvc_dia': 273,
#   'uti_neo_tardio_infec': 1,
#   'unid_int_pedi_cvc_dia': 304,
#   'unid_int_pedi_infec': 7,
#   'uti_pedi_cvc_dia': 304,
#   'uti_pedi_infec': 2,
#   'unid_int_ad_cvc_dia': 208,
#   'unid_int_ad_infec': 9,
#   'uti_ad_cvc_dia': 452,
#   'uti_ad_infec': 6,
#   'unid_int_idoso_cvc_dia': 496,
#   'unid_int_idoso_infec': 2,
#   'uti_idoso_cvc_dia': 421,
#   'uti_idoso_infec': 1,
#   'unid_int_neo_precoce_cvd_dia': 149,
#   'unid_int_neo_precoce_itu': 8,
#   'uti_neo_precoce_cvd_dia': 162,
#   'uti_neo_precoce_itu': 1,
#   'unid_int_neo_tardio_cvd_dia': 177,
#   'unid_int_neo_tardio_itu': 10,
#   'uti_neo_tardio_cvd_dia': 185,
#   'uti_neo_tardio_itu': 10,
#   'unid_int_pedi_cvd_dia': 124,
#   'unid_int_pedi_itu': 9,
#   'uti_pedi_cvd_dia': 133,
#   'uti_pedi_itu': 4,
#   'unid_int_ad_cvd_dia': 164,
#   'unid_int_ad_itu': 9,
#   'uti_ad_cvd_dia': 223,
#   'uti_ad_itu': 6,
#   'unid_int_idoso_cvd_dia': 87,
#   'unid_int_idoso_itu': 6,
#   'uti_idoso_cvd_dia': 141,
#   'uti_idoso_itu': 9,
#   'cli_total_pacientes': 70,
#   'cli_profilaxia': 53,
#   'cir_orto_total_pacientes': 189,
#   'cir_orto_profilaxia': 159,
#   'cir_nao_orto_total_pacientes': 182,
#   'cir_nao_orto_profilaxia': 153,
#   'quedas_com_dano': 2,
#   'eventos_sentinela': 1},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2024,
#   'month': 1,
#   'partos_vaginais': 91,
#   'partos_cesareos': 75,
#   'saidas_clinicas_anterior': 487,
#   'saidas_cirurgicas_anterior': 346,
#   'reinternacoes_clinicas': 37,
#   'reinternacoes_cirurgicas': 30,
#   'pacientes_dia': 955,
#   'pcr_eventos': 0,
#   'cli_neo_precoce_saidas': 259,
#   'cli_neo_precoce_obitos': 18,
#   'cli_neo_precoce_pacientes_dia': 831,
#   'cli_neo_tardio_saidas': 193,
#   'cli_neo_tardio_obitos': 21,
#   'cli_neo_tardio_pacientes_dia': 655,
#   'cli_pedi_saidas': 133,
#   'cli_pedi_obitos': 29,
#   'cli_pedi_pacientes_dia': 711,
#   'cli_ad_saidas': 185,
#   'cli_ad_obitos': 8,
#   'cli_ad_pacientes_dia': 625,
#   'cli_idoso_saidas': 163,
#   'cli_idoso_obitos': 11,
#   'cli_idoso_pacientes_dia': 661,
#   'cir_neo_precoce_saidas': 288,
#   'cir_neo_precoce_obitos': 2,
#   'cir_neo_precoce_pacientes_dia': 735,
#   'cir_neo_tardio_saidas': 106,
#   'cir_neo_tardio_obitos': 26,
#   'cir_neo_tardio_pacientes_dia': 930,
#   'cir_pedi_saidas': 299,
#   'cir_pedi_obitos': 9,
#   'cir_pedi_pacientes_dia': 516,
#   'cir_ad_saidas': 118,
#   'cir_ad_obitos': 28,
#   'cir_ad_pacientes_dia': 516,
#   'cir_idoso_saidas': 168,
#   'cir_idoso_obitos': 13,
#   'cir_idoso_pacientes_dia': 955,
#   'total_pacientes_emergencia': 210,
#   'total_tempo_permanencia_emergencia_hr': 469,
#   'pacientes_emergencia_nivel2': 84,
#   'pacientes_emergencia_nivel3': 63,
#   'tempo_total_emergencia_nivel2_min': 313,
#   'tempo_total_emergencia_nivel3_min': 1842,
#   'total_cirurgias_limpas': 67,
#   'cirurgias_com_antibiotico': 66,
#   'total_infeccoes': 2,
#   'unid_int_neo_precoce_cvc_dia': 248,
#   'unid_int_neo_precoce_infec': 8,
#   'uti_neo_precoce_cvc_dia': 248,
#   'uti_neo_precoce_infec': 5,
#   'unid_int_neo_tardio_cvc_dia': 237,
#   'unid_int_neo_tardio_infec': 7,
#   'uti_neo_tardio_cvc_dia': 367,
#   'uti_neo_tardio_infec': 5,
#   'unid_int_pedi_cvc_dia': 423,
#   'unid_int_pedi_infec': 5,
#   'uti_pedi_cvc_dia': 357,
#   'uti_pedi_infec': 1,
#   'unid_int_ad_cvc_dia': 275,
#   'unid_int_ad_infec': 6,
#   'uti_ad_cvc_dia': 233,
#   'uti_ad_infec': 3,
#   'unid_int_idoso_cvc_dia': 498,
#   'unid_int_idoso_infec': 6,
#   'uti_idoso_cvc_dia': 298,
#   'uti_idoso_infec': 3,
#   'unid_int_neo_precoce_cvd_dia': 99,
#   'unid_int_neo_precoce_itu': 7,
#   'uti_neo_precoce_cvd_dia': 156,
#   'uti_neo_precoce_itu': 5,
#   'unid_int_neo_tardio_cvd_dia': 239,
#   'unid_int_neo_tardio_itu': 10,
#   'uti_neo_tardio_cvd_dia': 97,
#   'uti_neo_tardio_itu': 5,
#   'unid_int_pedi_cvd_dia': 276,
#   'unid_int_pedi_itu': 0,
#   'uti_pedi_cvd_dia': 74,
#   'uti_pedi_itu': 8,
#   'unid_int_ad_cvd_dia': 136,
#   'unid_int_ad_itu': 3,
#   'uti_ad_cvd_dia': 190,
#   'uti_ad_itu': 1,
#   'unid_int_idoso_cvd_dia': 157,
#   'unid_int_idoso_itu': 0,
#   'uti_idoso_cvd_dia': 167,
#   'uti_idoso_itu': 9,
#   'cli_total_pacientes': 71,
#   'cli_profilaxia': 45,
#   'cir_orto_total_pacientes': 105,
#   'cir_orto_profilaxia': 78,
#   'cir_nao_orto_total_pacientes': 174,
#   'cir_nao_orto_profilaxia': 165,
#   'quedas_com_dano': 0,
#   'eventos_sentinela': 0},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2024,
#   'month': 2,
#   'partos_vaginais': 72,
#   'partos_cesareos': 79,
#   'saidas_clinicas_anterior': 563,
#   'saidas_cirurgicas_anterior': 245,
#   'reinternacoes_clinicas': 32,
#   'reinternacoes_cirurgicas': 13,
#   'pacientes_dia': 544,
#   'pcr_eventos': 5,
#   'cli_neo_precoce_saidas': 141,
#   'cli_neo_precoce_obitos': 14,
#   'cli_neo_precoce_pacientes_dia': 677,
#   'cli_neo_tardio_saidas': 175,
#   'cli_neo_tardio_obitos': 4,
#   'cli_neo_tardio_pacientes_dia': 745,
#   'cli_pedi_saidas': 188,
#   'cli_pedi_obitos': 20,
#   'cli_pedi_pacientes_dia': 925,
#   'cli_ad_saidas': 251,
#   'cli_ad_obitos': 2,
#   'cli_ad_pacientes_dia': 789,
#   'cli_idoso_saidas': 177,
#   'cli_idoso_obitos': 10,
#   'cli_idoso_pacientes_dia': 550,
#   'cir_neo_precoce_saidas': 106,
#   'cir_neo_precoce_obitos': 3,
#   'cir_neo_precoce_pacientes_dia': 950,
#   'cir_neo_tardio_saidas': 125,
#   'cir_neo_tardio_obitos': 24,
#   'cir_neo_tardio_pacientes_dia': 735,
#   'cir_pedi_saidas': 185,
#   'cir_pedi_obitos': 14,
#   'cir_pedi_pacientes_dia': 756,
#   'cir_ad_saidas': 136,
#   'cir_ad_obitos': 11,
#   'cir_ad_pacientes_dia': 524,
#   'cir_idoso_saidas': 164,
#   'cir_idoso_obitos': 10,
#   'cir_idoso_pacientes_dia': 544,
#   'total_pacientes_emergencia': 277,
#   'total_tempo_permanencia_emergencia_hr': 899,
#   'pacientes_emergencia_nivel2': 20,
#   'pacientes_emergencia_nivel3': 83,
#   'tempo_total_emergencia_nivel2_min': 369,
#   'tempo_total_emergencia_nivel3_min': 2602,
#   'total_cirurgias_limpas': 66,
#   'cirurgias_com_antibiotico': 49,
#   'total_infeccoes': 2,
#   'unid_int_neo_precoce_cvc_dia': 358,
#   'unid_int_neo_precoce_infec': 6,
#   'uti_neo_precoce_cvc_dia': 258,
#   'uti_neo_precoce_infec': 9,
#   'unid_int_neo_tardio_cvc_dia': 494,
#   'unid_int_neo_tardio_infec': 6,
#   'uti_neo_tardio_cvc_dia': 266,
#   'uti_neo_tardio_infec': 3,
#   'unid_int_pedi_cvc_dia': 494,
#   'unid_int_pedi_infec': 7,
#   'uti_pedi_cvc_dia': 482,
#   'uti_pedi_infec': 6,
#   'unid_int_ad_cvc_dia': 476,
#   'unid_int_ad_infec': 1,
#   'uti_ad_cvc_dia': 430,
#   'uti_ad_infec': 1,
#   'unid_int_idoso_cvc_dia': 358,
#   'unid_int_idoso_infec': 9,
#   'uti_idoso_cvc_dia': 319,
#   'uti_idoso_infec': 9,
#   'unid_int_neo_precoce_cvd_dia': 61,
#   'unid_int_neo_precoce_itu': 6,
#   'uti_neo_precoce_cvd_dia': 271,
#   'uti_neo_precoce_itu': 9,
#   'unid_int_neo_tardio_cvd_dia': 182,
#   'unid_int_neo_tardio_itu': 2,
#   'uti_neo_tardio_cvd_dia': 268,
#   'uti_neo_tardio_itu': 9,
#   'unid_int_pedi_cvd_dia': 274,
#   'unid_int_pedi_itu': 4,
#   'uti_pedi_cvd_dia': 274,
#   'uti_pedi_itu': 6,
#   'unid_int_ad_cvd_dia': 261,
#   'unid_int_ad_itu': 2,
#   'uti_ad_cvd_dia': 226,
#   'uti_ad_itu': 1,
#   'unid_int_idoso_cvd_dia': 52,
#   'unid_int_idoso_itu': 8,
#   'uti_idoso_cvd_dia': 134,
#   'uti_idoso_itu': 7,
#   'cli_total_pacientes': 84,
#   'cli_profilaxia': 74,
#   'cir_orto_total_pacientes': 173,
#   'cir_orto_profilaxia': 108,
#   'cir_nao_orto_total_pacientes': 116,
#   'cir_nao_orto_profilaxia': 60,
#   'quedas_com_dano': 6,
#   'eventos_sentinela': 4},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2024,
#   'month': 3,
#   'partos_vaginais': 53,
#   'partos_cesareos': 98,
#   'saidas_clinicas_anterior': 389,
#   'saidas_cirurgicas_anterior': 372,
#   'reinternacoes_clinicas': 27,
#   'reinternacoes_cirurgicas': 15,
#   'pacientes_dia': 538,
#   'pcr_eventos': 0,
#   'cli_neo_precoce_saidas': 130,
#   'cli_neo_precoce_obitos': 26,
#   'cli_neo_precoce_pacientes_dia': 735,
#   'cli_neo_tardio_saidas': 158,
#   'cli_neo_tardio_obitos': 20,
#   'cli_neo_tardio_pacientes_dia': 824,
#   'cli_pedi_saidas': 174,
#   'cli_pedi_obitos': 23,
#   'cli_pedi_pacientes_dia': 840,
#   'cli_ad_saidas': 176,
#   'cli_ad_obitos': 8,
#   'cli_ad_pacientes_dia': 811,
#   'cli_idoso_saidas': 185,
#   'cli_idoso_obitos': 20,
#   'cli_idoso_pacientes_dia': 690,
#   'cir_neo_precoce_saidas': 105,
#   'cir_neo_precoce_obitos': 22,
#   'cir_neo_precoce_pacientes_dia': 581,
#   'cir_neo_tardio_saidas': 180,
#   'cir_neo_tardio_obitos': 22,
#   'cir_neo_tardio_pacientes_dia': 500,
#   'cir_pedi_saidas': 159,
#   'cir_pedi_obitos': 14,
#   'cir_pedi_pacientes_dia': 903,
#   'cir_ad_saidas': 139,
#   'cir_ad_obitos': 6,
#   'cir_ad_pacientes_dia': 591,
#   'cir_idoso_saidas': 126,
#   'cir_idoso_obitos': 25,
#   'cir_idoso_pacientes_dia': 538,
#   'total_pacientes_emergencia': 226,
#   'total_tempo_permanencia_emergencia_hr': 606,
#   'pacientes_emergencia_nivel2': 31,
#   'pacientes_emergencia_nivel3': 66,
#   'tempo_total_emergencia_nivel2_min': 433,
#   'tempo_total_emergencia_nivel3_min': 2212,
#   'total_cirurgias_limpas': 147,
#   'cirurgias_com_antibiotico': 136,
#   'total_infeccoes': 0,
#   'unid_int_neo_precoce_cvc_dia': 396,
#   'unid_int_neo_precoce_infec': 3,
#   'uti_neo_precoce_cvc_dia': 464,
#   'uti_neo_precoce_infec': 1,
#   'unid_int_neo_tardio_cvc_dia': 422,
#   'unid_int_neo_tardio_infec': 0,
#   'uti_neo_tardio_cvc_dia': 329,
#   'uti_neo_tardio_infec': 3,
#   'unid_int_pedi_cvc_dia': 450,
#   'unid_int_pedi_infec': 0,
#   'uti_pedi_cvc_dia': 381,
#   'uti_pedi_infec': 7,
#   'unid_int_ad_cvc_dia': 461,
#   'unid_int_ad_infec': 5,
#   'uti_ad_cvc_dia': 336,
#   'uti_ad_infec': 7,
#   'unid_int_idoso_cvc_dia': 260,
#   'unid_int_idoso_infec': 10,
#   'uti_idoso_cvc_dia': 460,
#   'uti_idoso_infec': 3,
#   'unid_int_neo_precoce_cvd_dia': 53,
#   'unid_int_neo_precoce_itu': 5,
#   'uti_neo_precoce_cvd_dia': 212,
#   'uti_neo_precoce_itu': 5,
#   'unid_int_neo_tardio_cvd_dia': 186,
#   'unid_int_neo_tardio_itu': 8,
#   'uti_neo_tardio_cvd_dia': 142,
#   'uti_neo_tardio_itu': 2,
#   'unid_int_pedi_cvd_dia': 157,
#   'unid_int_pedi_itu': 0,
#   'uti_pedi_cvd_dia': 91,
#   'uti_pedi_itu': 3,
#   'unid_int_ad_cvd_dia': 287,
#   'unid_int_ad_itu': 10,
#   'uti_ad_cvd_dia': 172,
#   'uti_ad_itu': 4,
#   'unid_int_idoso_cvd_dia': 199,
#   'unid_int_idoso_itu': 3,
#   'uti_idoso_cvd_dia': 252,
#   'uti_idoso_itu': 2,
#   'cli_total_pacientes': 139,
#   'cli_profilaxia': 86,
#   'cir_orto_total_pacientes': 135,
#   'cir_orto_profilaxia': 46,
#   'cir_nao_orto_total_pacientes': 120,
#   'cir_nao_orto_profilaxia': 107,
#   'quedas_com_dano': 6,
#   'eventos_sentinela': 5},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2024,
#   'month': 4,
#   'partos_vaginais': 118,
#   'partos_cesareos': 75,
#   'saidas_clinicas_anterior': 384,
#   'saidas_cirurgicas_anterior': 276,
#   'reinternacoes_clinicas': 23,
#   'reinternacoes_cirurgicas': 9,
#   'pacientes_dia': 902,
#   'pcr_eventos': 2,
#   'cli_neo_precoce_saidas': 152,
#   'cli_neo_precoce_obitos': 26,
#   'cli_neo_precoce_pacientes_dia': 702,
#   'cli_neo_tardio_saidas': 298,
#   'cli_neo_tardio_obitos': 1,
#   'cli_neo_tardio_pacientes_dia': 640,
#   'cli_pedi_saidas': 286,
#   'cli_pedi_obitos': 7,
#   'cli_pedi_pacientes_dia': 769,
#   'cli_ad_saidas': 111,
#   'cli_ad_obitos': 21,
#   'cli_ad_pacientes_dia': 592,
#   'cli_idoso_saidas': 117,
#   'cli_idoso_obitos': 19,
#   'cli_idoso_pacientes_dia': 883,
#   'cir_neo_precoce_saidas': 300,
#   'cir_neo_precoce_obitos': 5,
#   'cir_neo_precoce_pacientes_dia': 761,
#   'cir_neo_tardio_saidas': 201,
#   'cir_neo_tardio_obitos': 29,
#   'cir_neo_tardio_pacientes_dia': 854,
#   'cir_pedi_saidas': 133,
#   'cir_pedi_obitos': 14,
#   'cir_pedi_pacientes_dia': 562,
#   'cir_ad_saidas': 218,
#   'cir_ad_obitos': 4,
#   'cir_ad_pacientes_dia': 789,
#   'cir_idoso_saidas': 296,
#   'cir_idoso_obitos': 8,
#   'cir_idoso_pacientes_dia': 902,
#   'total_pacientes_emergencia': 275,
#   'total_tempo_permanencia_emergencia_hr': 695,
#   'pacientes_emergencia_nivel2': 83,
#   'pacientes_emergencia_nivel3': 59,
#   'tempo_total_emergencia_nivel2_min': 315,
#   'tempo_total_emergencia_nivel3_min': 1541,
#   'total_cirurgias_limpas': 113,
#   'cirurgias_com_antibiotico': 85,
#   'total_infeccoes': 5,
#   'unid_int_neo_precoce_cvc_dia': 242,
#   'unid_int_neo_precoce_infec': 5,
#   'uti_neo_precoce_cvc_dia': 344,
#   'uti_neo_precoce_infec': 4,
#   'unid_int_neo_tardio_cvc_dia': 406,
#   'unid_int_neo_tardio_infec': 0,
#   'uti_neo_tardio_cvc_dia': 384,
#   'uti_neo_tardio_infec': 5,
#   'unid_int_pedi_cvc_dia': 389,
#   'unid_int_pedi_infec': 5,
#   'uti_pedi_cvc_dia': 442,
#   'uti_pedi_infec': 0,
#   'unid_int_ad_cvc_dia': 389,
#   'unid_int_ad_infec': 2,
#   'uti_ad_cvc_dia': 475,
#   'uti_ad_infec': 1,
#   'unid_int_idoso_cvc_dia': 323,
#   'unid_int_idoso_infec': 8,
#   'uti_idoso_cvc_dia': 446,
#   'uti_idoso_infec': 4,
#   'unid_int_neo_precoce_cvd_dia': 53,
#   'unid_int_neo_precoce_itu': 7,
#   'uti_neo_precoce_cvd_dia': 176,
#   'uti_neo_precoce_itu': 7,
#   'unid_int_neo_tardio_cvd_dia': 254,
#   'unid_int_neo_tardio_itu': 1,
#   'uti_neo_tardio_cvd_dia': 191,
#   'uti_neo_tardio_itu': 9,
#   'unid_int_pedi_cvd_dia': 204,
#   'unid_int_pedi_itu': 8,
#   'uti_pedi_cvd_dia': 219,
#   'uti_pedi_itu': 0,
#   'unid_int_ad_cvd_dia': 50,
#   'unid_int_ad_itu': 6,
#   'uti_ad_cvd_dia': 272,
#   'uti_ad_itu': 4,
#   'unid_int_idoso_cvd_dia': 277,
#   'unid_int_idoso_itu': 10,
#   'uti_idoso_cvd_dia': 121,
#   'uti_idoso_itu': 7,
#   'cli_total_pacientes': 82,
#   'cli_profilaxia': 78,
#   'cir_orto_total_pacientes': 176,
#   'cir_orto_profilaxia': 112,
#   'cir_nao_orto_total_pacientes': 74,
#   'cir_nao_orto_profilaxia': 44,
#   'quedas_com_dano': 0,
#   'eventos_sentinela': 1},
#  {'organization_id': {'$oid': '6745d7873f4e39e161319575'},
#   'year': 2024,
#   'month': 5,
#   'partos_vaginais': 137,
#   'partos_cesareos': 54,
#   'saidas_clinicas_anterior': 524,
#   'saidas_cirurgicas_anterior': 360,
# ...
#   'unid_int_ad_cvc_dia': 228,
#   'unid_int_ad_infec': 0,
#   'uti_ad_cvc_dia': 227,
#   'uti_ad_infec': 5,
#   'unid_int_idoso_cvc_dia': 466,
#   'unid_int_idoso_infec': 9,
#   'uti_idoso_cvc_dia': 209,
#   'uti_idoso_infec': 4,
#   'unid_int_neo_precoce_cvd_dia': 268,
#   'unid_int_neo_precoce_itu': 10,
#   'uti_neo_precoce_cvd_dia': 251,
#   'uti_neo_precoce_itu': 10,
#   'unid_int_neo_tardio_cvd_dia': 183,
#   'unid_int_neo_tardio_itu': 0,
#   'uti_neo_tardio_cvd_dia': 173,
#   'uti_neo_tardio_itu': 0,
#   'unid_int_pedi_cvd_dia': 175,
#   'unid_int_pedi_itu': 3,
#   'uti_pedi_cvd_dia': 115,
#   'uti_pedi_itu': 2,
#   'unid_int_ad_cvd_dia': 271,
#   'unid_int_ad_itu': 9,
#   'uti_ad_cvd_dia': 64,
#   'uti_ad_itu': 5,
#   'unid_int_idoso_cvd_dia': 132,
#   'unid_int_idoso_itu': 5,
#   'uti_idoso_cvd_dia': 225,
#   'uti_idoso_itu': 0,
#   'cli_total_pacientes': 92,
#   'cli_profilaxia': 69,
#   'cir_orto_total_pacientes': 99,
#   'cir_orto_profilaxia': 67,
#   'cir_nao_orto_total_pacientes': 80,
#   'cir_nao_orto_profilaxia': 54,
#   'quedas_com_dano': 9,
#   'eventos_sentinela': 4},
#  {'organization_id': {'$oid': '6745d7d93f4e39e161319576'},
#   'year': 2024,
#   'month': 8,
#   'partos_vaginais': 66,
#   'partos_cesareos': 83,
#   'saidas_clinicas_anterior': 375,
#   'saidas_cirurgicas_anterior': 383,
#   'reinternacoes_clinicas': 39,
#   'reinternacoes_cirurgicas': 11,
#   'pacientes_dia': 531,
#   'pcr_eventos': 0,
#   'cli_neo_precoce_saidas': 300,
#   'cli_neo_precoce_obitos': 16,
#   'cli_neo_precoce_pacientes_dia': 987,
#   'cli_neo_tardio_saidas': 300,
#   'cli_neo_tardio_obitos': 19,
#   'cli_neo_tardio_pacientes_dia': 567,
#   'cli_pedi_saidas': 282,
#   'cli_pedi_obitos': 29,
#   'cli_pedi_pacientes_dia': 530,
#   'cli_ad_saidas': 167,
#   'cli_ad_obitos': 9,
#   'cli_ad_pacientes_dia': 763,
#   'cli_idoso_saidas': 254,
#   'cli_idoso_obitos': 29,
#   'cli_idoso_pacientes_dia': 941,
#   'cir_neo_precoce_saidas': 248,
#   'cir_neo_precoce_obitos': 28,
#   'cir_neo_precoce_pacientes_dia': 517,
#   'cir_neo_tardio_saidas': 292,
#   'cir_neo_tardio_obitos': 11,
#   'cir_neo_tardio_pacientes_dia': 565,
#   'cir_pedi_saidas': 245,
#   'cir_pedi_obitos': 30,
#   'cir_pedi_pacientes_dia': 596,
#   'cir_ad_saidas': 166,
#   'cir_ad_obitos': 15,
#   'cir_ad_pacientes_dia': 881,
#   'cir_idoso_saidas': 295,
#   'cir_idoso_obitos': 10,
#   'cir_idoso_pacientes_dia': 531,
#   'total_pacientes_emergencia': 269,
#   'total_tempo_permanencia_emergencia_hr': 847,
#   'pacientes_emergencia_nivel2': 27,
#   'pacientes_emergencia_nivel3': 145,
#   'tempo_total_emergencia_nivel2_min': 222,
#   'tempo_total_emergencia_nivel3_min': 2259,
#   'total_cirurgias_limpas': 91,
#   'cirurgias_com_antibiotico': 75,
#   'total_infeccoes': 5,
#   'unid_int_neo_precoce_cvc_dia': 239,
#   'unid_int_neo_precoce_infec': 9,
#   'uti_neo_precoce_cvc_dia': 279,
#   'uti_neo_precoce_infec': 3,
#   'unid_int_neo_tardio_cvc_dia': 342,
#   'unid_int_neo_tardio_infec': 1,
#   'uti_neo_tardio_cvc_dia': 328,
#   'uti_neo_tardio_infec': 9,
#   'unid_int_pedi_cvc_dia': 253,
#   'unid_int_pedi_infec': 4,
#   'uti_pedi_cvc_dia': 201,
#   'uti_pedi_infec': 8,
#   'unid_int_ad_cvc_dia': 426,
#   'unid_int_ad_infec': 3,
#   'uti_ad_cvc_dia': 226,
#   'uti_ad_infec': 10,
#   'unid_int_idoso_cvc_dia': 412,
#   'unid_int_idoso_infec': 7,
#   'uti_idoso_cvc_dia': 210,
#   'uti_idoso_infec': 5,
#   'unid_int_neo_precoce_cvd_dia': 152,
#   'unid_int_neo_precoce_itu': 3,
#   'uti_neo_precoce_cvd_dia': 234,
#   'uti_neo_precoce_itu': 5,
#   'unid_int_neo_tardio_cvd_dia': 244,
#   'unid_int_neo_tardio_itu': 1,
#   'uti_neo_tardio_cvd_dia': 77,
#   'uti_neo_tardio_itu': 10,
#   'unid_int_pedi_cvd_dia': 147,
#   'unid_int_pedi_itu': 9,
#   'uti_pedi_cvd_dia': 74,
#   'uti_pedi_itu': 3,
#   'unid_int_ad_cvd_dia': 158,
#   'unid_int_ad_itu': 7,
#   'uti_ad_cvd_dia': 168,
#   'uti_ad_itu': 1,
#   'unid_int_idoso_cvd_dia': 226,
#   'unid_int_idoso_itu': 8,
#   'uti_idoso_cvd_dia': 192,
#   'uti_idoso_itu': 7,
#   'cli_total_pacientes': 106,
#   'cli_profilaxia': 51,
#   'cir_orto_total_pacientes': 101,
#   'cir_orto_profilaxia': 101,
#   'cir_nao_orto_total_pacientes': 162,
#   'cir_nao_orto_profilaxia': 77,
#   'quedas_com_dano': 7,
#   'eventos_sentinela': 4},
#  {'organization_id': {'$oid': '6745d7d93f4e39e161319576'},
#   'year': 2024,
#   'month': 9,
#   'partos_vaginais': 77,
#   'partos_cesareos': 93,
#   'saidas_clinicas_anterior': 597,
#   'saidas_cirurgicas_anterior': 374,
#   'reinternacoes_clinicas': 21,
#   'reinternacoes_cirurgicas': 27,
#   'pacientes_dia': 525,
#   'pcr_eventos': 3,
#   'cli_neo_precoce_saidas': 123,
#   'cli_neo_precoce_obitos': 27,
#   'cli_neo_precoce_pacientes_dia': 828,
#   'cli_neo_tardio_saidas': 270,
#   'cli_neo_tardio_obitos': 9,
#   'cli_neo_tardio_pacientes_dia': 532,
#   'cli_pedi_saidas': 232,
#   'cli_pedi_obitos': 14,
#   'cli_pedi_pacientes_dia': 763,
#   'cli_ad_saidas': 197,
#   'cli_ad_obitos': 23,
#   'cli_ad_pacientes_dia': 669,
#   'cli_idoso_saidas': 244,
#   'cli_idoso_obitos': 25,
#   'cli_idoso_pacientes_dia': 730,
#   'cir_neo_precoce_saidas': 280,
#   'cir_neo_precoce_obitos': 10,
#   'cir_neo_precoce_pacientes_dia': 973,
#   'cir_neo_tardio_saidas': 265,
#   'cir_neo_tardio_obitos': 9,
#   'cir_neo_tardio_pacientes_dia': 755,
#   'cir_pedi_saidas': 105,
#   'cir_pedi_obitos': 25,
#   'cir_pedi_pacientes_dia': 673,
#   'cir_ad_saidas': 110,
#   'cir_ad_obitos': 22,
#   'cir_ad_pacientes_dia': 845,
#   'cir_idoso_saidas': 293,
#   'cir_idoso_obitos': 9,
#   'cir_idoso_pacientes_dia': 525,
#   'total_pacientes_emergencia': 164,
#   'total_tempo_permanencia_emergencia_hr': 731,
#   'pacientes_emergencia_nivel2': 57,
#   'pacientes_emergencia_nivel3': 106,
#   'tempo_total_emergencia_nivel2_min': 214,
#   'tempo_total_emergencia_nivel3_min': 1602,
#   'total_cirurgias_limpas': 123,
#   'cirurgias_com_antibiotico': 95,
#   'total_infeccoes': 4,
#   'unid_int_neo_precoce_cvc_dia': 381,
#   'unid_int_neo_precoce_infec': 4,
#   'uti_neo_precoce_cvc_dia': 318,
#   'uti_neo_precoce_infec': 10,
#   'unid_int_neo_tardio_cvc_dia': 200,
#   'unid_int_neo_tardio_infec': 0,
#   'uti_neo_tardio_cvc_dia': 434,
#   'uti_neo_tardio_infec': 2,
#   'unid_int_pedi_cvc_dia': 449,
#   'unid_int_pedi_infec': 0,
#   'uti_pedi_cvc_dia': 392,
#   'uti_pedi_infec': 9,
#   'unid_int_ad_cvc_dia': 267,
#   'unid_int_ad_infec': 8,
#   'uti_ad_cvc_dia': 323,
#   'uti_ad_infec': 7,
#   'unid_int_idoso_cvc_dia': 450,
#   'unid_int_idoso_infec': 6,
#   'uti_idoso_cvc_dia': 463,
#   'uti_idoso_infec': 4,
#   'unid_int_neo_precoce_cvd_dia': 161,
#   'unid_int_neo_precoce_itu': 1,
#   'uti_neo_precoce_cvd_dia': 156,
#   'uti_neo_precoce_itu': 2,
#   'unid_int_neo_tardio_cvd_dia': 110,
#   'unid_int_neo_tardio_itu': 5,
#   'uti_neo_tardio_cvd_dia': 233,
#   'uti_neo_tardio_itu': 4,
#   'unid_int_pedi_cvd_dia': 103,
#   'unid_int_pedi_itu': 8,
#   'uti_pedi_cvd_dia': 109,
#   'uti_pedi_itu': 9,
#   'unid_int_ad_cvd_dia': 207,
#   'unid_int_ad_itu': 1,
#   'uti_ad_cvd_dia': 168,
#   'uti_ad_itu': 5,
#   'unid_int_idoso_cvd_dia': 294,
#   'unid_int_idoso_itu': 7,
#   'uti_idoso_cvd_dia': 155,
#   'uti_idoso_itu': 8,
#   'cli_total_pacientes': 196,
#   'cli_profilaxia': 124,
#   'cir_orto_total_pacientes': 165,
#   'cir_orto_profilaxia': 163,
#   'cir_nao_orto_total_pacientes': 73,
#   'cir_nao_orto_profilaxia': 45,
#   'quedas_com_dano': 3,
#   'eventos_sentinela': 2},
#  {'organization_id': {'$oid': '6745d7d93f4e39e161319576'},
#   'year': 2024,
#   'month': 10,
#   'partos_vaginais': 119,
#   'partos_cesareos': 93,
#   'saidas_clinicas_anterior': 425,
#   'saidas_cirurgicas_anterior': 245,
#   'reinternacoes_clinicas': 29,
#   'reinternacoes_cirurgicas': 27,
#   'pacientes_dia': 741,
#   'pcr_eventos': 5,
#   'cli_neo_precoce_saidas': 199,
#   'cli_neo_precoce_obitos': 16,
#   'cli_neo_precoce_pacientes_dia': 912,
#   'cli_neo_tardio_saidas': 195,
#   'cli_neo_tardio_obitos': 15,
#   'cli_neo_tardio_pacientes_dia': 554,
#   'cli_pedi_saidas': 196,
#   'cli_pedi_obitos': 4,
#   'cli_pedi_pacientes_dia': 909,
#   'cli_ad_saidas': 141,
#   'cli_ad_obitos': 23,
#   'cli_ad_pacientes_dia': 573,
#   'cli_idoso_saidas': 247,
#   'cli_idoso_obitos': 3,
#   'cli_idoso_pacientes_dia': 599,
#   'cir_neo_precoce_saidas': 115,
#   'cir_neo_precoce_obitos': 20,
#   'cir_neo_precoce_pacientes_dia': 903,
#   'cir_neo_tardio_saidas': 122,
#   'cir_neo_tardio_obitos': 21,
#   'cir_neo_tardio_pacientes_dia': 859,
#   'cir_pedi_saidas': 115,
#   'cir_pedi_obitos': 16,
#   'cir_pedi_pacientes_dia': 566,
#   'cir_ad_saidas': 164,
#   'cir_ad_obitos': 23,
#   'cir_ad_pacientes_dia': 737,
#   'cir_idoso_saidas': 231,
#   'cir_idoso_obitos': 25,
#   'cir_idoso_pacientes_dia': 741,
#   'total_pacientes_emergencia': 241,
#   'total_tempo_permanencia_emergencia_hr': 836,
#   'pacientes_emergencia_nivel2': 37,
#   'pacientes_emergencia_nivel3': 110,
#   'tempo_total_emergencia_nivel2_min': 388,
#   'tempo_total_emergencia_nivel3_min': 2112,
#   'total_cirurgias_limpas': 94,
#   'cirurgias_com_antibiotico': 80,
#   'total_infeccoes': 5,
#   'unid_int_neo_precoce_cvc_dia': 217,
#   'unid_int_neo_precoce_infec': 8,
#   'uti_neo_precoce_cvc_dia': 401,
#   'uti_neo_precoce_infec': 2,
#   'unid_int_neo_tardio_cvc_dia': 373,
#   'unid_int_neo_tardio_infec': 7,
#   'uti_neo_tardio_cvc_dia': 402,
#   'uti_neo_tardio_infec': 7,
#   'unid_int_pedi_cvc_dia': 492,
#   'unid_int_pedi_infec': 4,
#   'uti_pedi_cvc_dia': 449,
#   'uti_pedi_infec': 2,
#   'unid_int_ad_cvc_dia': 386,
#   'unid_int_ad_infec': 6,
#   'uti_ad_cvc_dia': 424,
#   'uti_ad_infec': 8,
#   'unid_int_idoso_cvc_dia': 231,
#   'unid_int_idoso_infec': 0,
#   'uti_idoso_cvc_dia': 323,
#   'uti_idoso_infec': 9,
#   'unid_int_neo_precoce_cvd_dia': 261,
#   'unid_int_neo_precoce_itu': 7,
#   'uti_neo_precoce_cvd_dia': 168,
#   'uti_neo_precoce_itu': 7,
#   'unid_int_neo_tardio_cvd_dia': 148,
#   'unid_int_neo_tardio_itu': 6,
#   'uti_neo_tardio_cvd_dia': 160,
#   'uti_neo_tardio_itu': 10,
#   'unid_int_pedi_cvd_dia': 281,
#   'unid_int_pedi_itu': 2,
#   'uti_pedi_cvd_dia': 86,
#   'uti_pedi_itu': 10,
#   'unid_int_ad_cvd_dia': 88,
#   'unid_int_ad_itu': 2,
#   'uti_ad_cvd_dia': 158,
#   'uti_ad_itu': 0,
#   'unid_int_idoso_cvd_dia': 136,
#   'unid_int_idoso_itu': 5,
#   'uti_idoso_cvd_dia': 231,
#   'uti_idoso_itu': 9,
#   'cli_total_pacientes': 197,
#   'cli_profilaxia': 69,
#   'cir_orto_total_pacientes': 199,
#   'cir_orto_profilaxia': 172,
#   'cir_nao_orto_total_pacientes': 65,
#   'cir_nao_orto_profilaxia': 57,
#   'quedas_com_dano': 1,
#   'eventos_sentinela': 2},
#  {'organization_id': {'$oid': '6745d7d93f4e39e161319576'},
#   'year': 2024,
#   'month': 11,
#   'partos_vaginais': 109,
#   'partos_cesareos': 77,
#   'saidas_clinicas_anterior': 473,
#   'saidas_cirurgicas_anterior': 288,
#   'reinternacoes_clinicas': 35,
#   'reinternacoes_cirurgicas': 15,
#   'pacientes_dia': 502,
#   'pcr_eventos': 1,
#   'cli_neo_precoce_saidas': 153,
#   'cli_neo_precoce_obitos': 9,
#   'cli_neo_precoce_pacientes_dia': 913,
#   'cli_neo_tardio_saidas': 257,
#   'cli_neo_tardio_obitos': 14,
#   'cli_neo_tardio_pacientes_dia': 768,
#   'cli_pedi_saidas': 139,
#   'cli_pedi_obitos': 21,
#   'cli_pedi_pacientes_dia': 503,
#   'cli_ad_saidas': 224,
#   'cli_ad_obitos': 18,
#   'cli_ad_pacientes_dia': 794,
#   'cli_idoso_saidas': 193,
#   'cli_idoso_obitos': 6,
#   'cli_idoso_pacientes_dia': 563,
#   'cir_neo_precoce_saidas': 133,
#   'cir_neo_precoce_obitos': 10,
#   'cir_neo_precoce_pacientes_dia': 736,
#   'cir_neo_tardio_saidas': 207,
#   'cir_neo_tardio_obitos': 10,
#   'cir_neo_tardio_pacientes_dia': 589,
#   'cir_pedi_saidas': 132,
#   'cir_pedi_obitos': 4,
#   'cir_pedi_pacientes_dia': 798,
#   'cir_ad_saidas': 131,
#   'cir_ad_obitos': 19,
#   'cir_ad_pacientes_dia': 667,
#   'cir_idoso_saidas': 155,
#   'cir_idoso_obitos': 29,
#   'cir_idoso_pacientes_dia': 502,
#   'total_pacientes_emergencia': 249,
#   'total_tempo_permanencia_emergencia_hr': 368,
#   'pacientes_emergencia_nivel2': 39,
#   'pacientes_emergencia_nivel3': 99,
#   'tempo_total_emergencia_nivel2_min': 537,
#   'tempo_total_emergencia_nivel3_min': 2000,
#   'total_cirurgias_limpas': 88,
#   'cirurgias_com_antibiotico': 72,
#   'total_infeccoes': 3,
#   'unid_int_neo_precoce_cvc_dia': 278,
#   'unid_int_neo_precoce_infec': 10,
#   'uti_neo_precoce_cvc_dia': 435,
#   'uti_neo_precoce_infec': 6,
#   'unid_int_neo_tardio_cvc_dia': 230,
#   'unid_int_neo_tardio_infec': 6,
#   'uti_neo_tardio_cvc_dia': 302,
#   'uti_neo_tardio_infec': 4,
#   'unid_int_pedi_cvc_dia': 412,
#   'unid_int_pedi_infec': 8,
#   'uti_pedi_cvc_dia': 423,
#   'uti_pedi_infec': 4,
#   'unid_int_ad_cvc_dia': 205,
#   'unid_int_ad_infec': 6,
#   'uti_ad_cvc_dia': 475,
#   'uti_ad_infec': 5,
#   'unid_int_idoso_cvc_dia': 299,
#   'unid_int_idoso_infec': 5,
#   'uti_idoso_cvc_dia': 422,
#   'uti_idoso_infec': 4,
#   'unid_int_neo_precoce_cvd_dia': 136,
#   'unid_int_neo_precoce_itu': 9,
#   'uti_neo_precoce_cvd_dia': 211,
#   'uti_neo_precoce_itu': 10,
#   'unid_int_neo_tardio_cvd_dia': 93,
#   'unid_int_neo_tardio_itu': 10,
#   'uti_neo_tardio_cvd_dia': 78,
#   'uti_neo_tardio_itu': 1,
#   'unid_int_pedi_cvd_dia': 96,
#   'unid_int_pedi_itu': 3,
#   'uti_pedi_cvd_dia': 91,
#   'uti_pedi_itu': 8,
#   'unid_int_ad_cvd_dia': 59,
#   'unid_int_ad_itu': 2,
#   'uti_ad_cvd_dia': 170,
#   'uti_ad_itu': 4,
#   'unid_int_idoso_cvd_dia': 236,
#   'unid_int_idoso_itu': 2,
#   'uti_idoso_cvd_dia': 300,
#   'uti_idoso_itu': 2,
#   'cli_total_pacientes': 121,
#   'cli_profilaxia': 51,
#   'cir_orto_total_pacientes': 191,
#   'cir_orto_profilaxia': 60,
#   'cir_nao_orto_total_pacientes': 87,
#   'cir_nao_orto_profilaxia': 69,
#   'quedas_com_dano': 5,
#   'eventos_sentinela': 5},
#  {'organization_id': {'$oid': '6745d7d93f4e39e161319576'},
#   'year': 2024,
#   'month': 12,
#   'partos_vaginais': 135,
#   'partos_cesareos': 52,
#   'saidas_clinicas_anterior': 578,
#   'saidas_cirurgicas_anterior': 382,
#   'reinternacoes_clinicas': 26,
#   'reinternacoes_cirurgicas': 20,
#   'pacientes_dia': 648,
#   'pcr_eventos': 2,
#   'cli_neo_precoce_saidas': 128,
#   'cli_neo_precoce_obitos': 10,
#   'cli_neo_precoce_pacientes_dia': 708,
#   'cli_neo_tardio_saidas': 175,
#   'cli_neo_tardio_obitos': 7,
#   'cli_neo_tardio_pacientes_dia': 974,
#   'cli_pedi_saidas': 182,
#   'cli_pedi_obitos': 20,
#   'cli_pedi_pacientes_dia': 984,
#   'cli_ad_saidas': 267,
#   'cli_ad_obitos': 20,
#   'cli_ad_pacientes_dia': 583,
#   'cli_idoso_saidas': 211,
#   'cli_idoso_obitos': 20,
#   'cli_idoso_pacientes_dia': 918,
#   'cir_neo_precoce_saidas': 206,
#   'cir_neo_precoce_obitos': 30,
#   'cir_neo_precoce_pacientes_dia': 959,
#   'cir_neo_tardio_saidas': 157,
#   'cir_neo_tardio_obitos': 14,
#   'cir_neo_tardio_pacientes_dia': 762,
#   'cir_pedi_saidas': 211,
#   'cir_pedi_obitos': 11,
#   'cir_pedi_pacientes_dia': 628,
#   'cir_ad_saidas': 151,
#   'cir_ad_obitos': 4,
#   'cir_ad_pacientes_dia': 692,
#   'cir_idoso_saidas': 158,
#   'cir_idoso_obitos': 21,
#   'cir_idoso_pacientes_dia': 648,
#   'total_pacientes_emergencia': 206,
#   'total_tempo_permanencia_emergencia_hr': 600,
#   'pacientes_emergencia_nivel2': 84,
#   'pacientes_emergencia_nivel3': 76,
#   'tempo_total_emergencia_nivel2_min': 263,
#   'tempo_total_emergencia_nivel3_min': 2197,
#   'total_cirurgias_limpas': 120,
#   'cirurgias_com_antibiotico': 120,
#   'total_infeccoes': 5,
#   'unid_int_neo_precoce_cvc_dia': 306,
#   'unid_int_neo_precoce_infec': 2,
#   'uti_neo_precoce_cvc_dia': 224,
#   'uti_neo_precoce_infec': 7,
#   'unid_int_neo_tardio_cvc_dia': 286,
#   'unid_int_neo_tardio_infec': 6,
#   'uti_neo_tardio_cvc_dia': 235,
#   'uti_neo_tardio_infec': 9,
#   'unid_int_pedi_cvc_dia': 369,
#   'unid_int_pedi_infec': 7,
#   'uti_pedi_cvc_dia': 248,
#   'uti_pedi_infec': 6,
#   'unid_int_ad_cvc_dia': 222,
#   'unid_int_ad_infec': 3,
#   'uti_ad_cvc_dia': 439,
#   'uti_ad_infec': 6,
#   'unid_int_idoso_cvc_dia': 219,
#   'unid_int_idoso_infec': 4,
#   'uti_idoso_cvc_dia': 496,
#   'uti_idoso_infec': 0,
#   'unid_int_neo_precoce_cvd_dia': 79,
#   'unid_int_neo_precoce_itu': 10,
#   'uti_neo_precoce_cvd_dia': 243,
#   'uti_neo_precoce_itu': 6,
#   'unid_int_neo_tardio_cvd_dia': 259,
#   'unid_int_neo_tardio_itu': 10,
#   'uti_neo_tardio_cvd_dia': 61,
#   'uti_neo_tardio_itu': 2,
#   'unid_int_pedi_cvd_dia': 128,
#   'unid_int_pedi_itu': 9,
#   'uti_pedi_cvd_dia': 293,
#   'uti_pedi_itu': 4,
#   'unid_int_ad_cvd_dia': 141,
#   'unid_int_ad_itu': 10,
#   'uti_ad_cvd_dia': 229,
#   'uti_ad_itu': 1,
#   'unid_int_idoso_cvd_dia': 254,
#   'unid_int_idoso_itu': 2,
#   'uti_idoso_cvd_dia': 57,
#   'uti_idoso_itu': 0,
#   'cli_total_pacientes': 107,
#   'cli_profilaxia': 64,
#   'cir_orto_total_pacientes': 96,
#   'cir_orto_profilaxia': 61,
#   'cir_nao_orto_total_pacientes': 124,
#   'cir_nao_orto_profilaxia': 120,
#   'quedas_com_dano': 4,
#   'eventos_sentinela': 3}]
